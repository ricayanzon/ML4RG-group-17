# %%
import torch
from collections import Counter
from collections import defaultdict
from torch_geometric.data import HeteroData

# %%
graph_path_name = "graph_biobert_50_dim"

# %%
data = torch.load(f"../graphs/{graph_path_name}.pt", weights_only=False)
print(data)
# Out:
# Data(
#   x=[3908, 57],
#   edge_index=[2, 8360],
#   edge_attr=[8360, 13],
#   node_names=[3908],
#   node_to_idx={
#     LOC100507600=0,
#     miR-663b=1,
#     miR-34c=2,
#     CAMTA1=3,
#     SMARCA1=4,
#     NEDD4L=5,
#     miR-193a-5p=6,
#     Uc003xsl.1=7,
#     miR-125a=8,
#     SANT1=9,
#     miR-184=10,
#     AGPS=11,
#     CCNG2=12,
#     TCAM1P-004=13,
#     HMGB1=14,
#     CST3=15,
#     miR-10a=16,
#     miR-204-3p=17,
#     ST8SIA4=18,
#     TNFSF11=19,
#     GOLM1=20,
#     miR-493-3p=21,
#     GAPLINC=22,
#     miR-384=23,
#     PIP4K2B=24,
#     CCR7=25,
#     NDC80=26,
#     lncRNA 00312=27,
#     SLC16A1-AS1=28,
#     NSG1=29,
#     TPTEP1=30,
#     HDAC1=31,
#     NEXN-AS1=32,
#     GSC-DT=33,
#     Gm15290=34,
#     NR2F1-AS1=35,
#     miR-106a-5p=36,
#     GLCC1=37,
#     RAB9A=38,
#     CASC15=39,
#     TYMS=40,
#     MAPK=41,
#     SKP2=42,
#     LERFS=43,
#     Lnc-NA=44,
#     PLCD3-OT1=45,
#     LINC00504=46,
#     TAL1=47,
#     lncRNA®CCDC6=48,
#     TALAM1=49,
#     ROCK2=50,
#     CCR2=51,
#     KDM1B=52,
#     CTNND2=53,
#     SMC1A=54,
#     RUNX2=55,
#     NOTCH2=56,
#     TCL1A=57,
#     GATA1=58,
#     MIR1246=59,
#     XBP1s=60,
#     COPDA1=61,
#     miR-590-5p=62,
#     PPP1R1A=63,
#     TRIP13=64,
#     LINC00115=65,
#     ACTA2=66,
#     lncRNA-PE=67,
#     miRNA-21=68,
#     let-7=69,
#     TIE1=70,
#     TBX5-AS1:2=71,
#     KLF3-AS1=72,
#     MANF=73,
#     NTM=74,
#     RUNX3=75,
#     lnc-ob1=76,
#     IPO7=77,
#     HCG11=78,
#     SPAG5=79,
#     VLDLR-AS1=80,
#     MIR503HG=81,
#     miR-185-5p=82,
#     KDM1A=83,
#     MIR627=84,
#     MYLK-AS1=85,
#     PEBP1=86,
#     BCL9=87,
#     miR-372=88,
#     miR-200a-3p=89,
#     CBL=90,
#     RAD54B=91,
#     PARP9=92,
#     SMC2=93,
#     SUV39H1=94,
#     LINC00477=95,
#     TCONS_00016233=96,
#     RMRP=97,
#     EPB41L4A-AS1=98,
#     LCTS5=99,
#     WNT6=100,
#     p-p44=101,
#     LINC01605=102,
#     NRSN2-AS1=103,
#     PPP1CA=104,
#     WNT2A=105,
#     AF113014=106,
#     OIP5-AS1=107,
#     THAP1=108,
#     NSUN2=109,
#     LAMC2=110,
#     EHD2=111,
#     miR-377-3p=112,
#     BOK-AS1=113,
#     JAG1=114,
#     IFN-¶À1=115,
#     PRKX=116,
#     miR-320a=117,
#     SOCS3=118,
#     KRT17=119,
#     OLA1P2=120,
#     SPYR4-IT1=121,
#     PIWIL4=122,
#     linc-UFC1=123,
#     HOXC8=124,
#     MYBBP1A=125,
#     LNC-HZ01=126,
#     HHIP=127,
#     miR-942=128,
#     CDC23=129,
#     RP11-84C13.1=130,
#     DDX5=131,
#     NEAT1=132,
#     MBNL3=133,
#     LINC00161=134,
#     CRP=135,
#     DIRC3=136,
#     miR-99a-5p=137,
#     MT1JP=138,
#     DACH1=139,
#     SUSAJ1=140,
#     miR-17-3p=141,
#     LINC00261=142,
#     RPA1=143,
#     MAP3K20-AS1=144,
#     E2F3=145,
#     hsa-miR-204-5p=146,
#     CPT1A=147,
#     CFL1=148,
#     Unigene56159=149,
#     CD209=150,
#     ERBB2=151,
#     APF=152,
#     TRPS1=153,
#     JMJD6=154,
#     DHX36=155,
#     MCM6=156,
#     PLK3=157,
#     CHRAC1=158,
#     AFAP1-AS2=159,
#     GCLC=160,
#     NUSAP1=161,
#     IkBalpha=162,
#     BLNK=163,
#     lncRNA-SARCC=164,
#     TRAF5=165,
#     TP53COR1=166,
#     miR-126-3p=167,
#     miR-137=168,
#     RLIM=169,
#     LINC01278=170,
#     BRCA2=171,
#     LTBP3=172,
#     CERNA1=173,
#     LINC00320=174,
#     ASPM=175,
#     HNRNPH3=176,
#     miR-3666=177,
#     FADS1=178,
#     LINC01018=179,
#     circPVT1=180,
#     LNCOC1=181,
#     AK002107=182,
#     TSHR=183,
#     FOXL1=184,
#     ORF50=185,
#     lncRNA-Glu=186,
#     SKA1=187,
#     lncOGFRP1=188,
#     LINC00528=189,
#     MYOSLID=190,
#     HNRNPA1=191,
#     SNHG6=192,
#     ANGPT1=193,
#     MIR17=194,
#     miR-18a=195,
#     ISG=196,
#     CCR5=197,
#     miR-4677-3p=198,
#     PTTG3P=199,
#     ERICD=200,
#     IFITM1=201,
#     Wnt-5a=202,
#     SMYD3=203,
#     miR-195-5p=204,
#     SFMBT2=205,
#     HOXC13-AS=206,
#     SPP1=207,
#     RRM1=208,
#     NR4A1=209,
#     PRKG1=210,
#     miR-194-5p=211,
#     PI3KR3=212,
#     CARM1=213,
#     MYL9=214,
#     OCT1=215,
#     TG2-lncRNA=216,
#     LINC00475=217,
#     LINC00667=218,
#     REG¶√=219,
#     HTRA3=220,
#     ERG=221,
#     LncDACH1=222,
#     THSD7A=223,
#     USP36=224,
#     IL24=225,
#     MIR422A=226,
#     PDGFRA=227,
#     JARID2=228,
#     miR-29c-3p=229,
#     PLAU=230,
#     miR-1=231,
#     ENSG00000231881=232,
#     NONHSAT009986=233,
#     RP11=234,
#     TINCR=235,
#     PPP1R13B-DT=236,
#     BORG=237,
#     SCARNA10=238,
#     DCST1-AS1=239,
#     GLS=240,
#     TDG=241,
#     p-EGFR=242,
#     AJAP1=243,
#     NR3C2=244,
#     SMILR=245,
#     LINC01342=246,
#     TLR8-AS1=247,
#     PGK1P2=248,
#     PENG=249,
#     GREM1=250,
#     miR-4701-5p=251,
#     RAB11A=252,
#     CXCR4=253,
#     SNHG20=254,
#     AK022798=255,
#     DSCAM-AS1=256,
#     LINC00659=257,
#     miR-30c-5p=258,
#     miR-34c-5p=259,
#     ACTN4=260,
#     BX357664=261,
#     LINC00673=262,
#     TRPM2-AS=263,
#     UBA6-DT=264,
#     ZFAS2=265,
#     miR-193a-3p=266,
#     miR-20b-3p=267,
#     GATA6=268,
#     RAB11B-AS1=269,
#     MMPs=270,
#     IL17A=271,
#     LncRNA-SRA1=272,
#     miR-205-5p=273,
#     PCAT18=274,
#     SNHG18=275,
#     ATG7=276,
#     PCDH10=277,
#     BECN1=278,
#     BAG1=279,
#     PIK3R3=280,
#     NANOG=281,
#     LYAR=282,
#     SENP1=283,
#     TNF=284,
#     SND1-IT1=285,
#     APOM=286,
#     MTK-1=287,
#     TMPOP2=288,
#     LINC01419=289,
#     P2X7R=290,
#     SH3PXD2A-AS1=291,
#     MSC-AS1=292,
#     miR-340-5p=293,
#     ADAM19=294,
#     LINC02023=295,
#     miR-330-5p=296,
#     miR-224-3p=297,
#     FOXO4=298,
#     MIR302A=299,
#     FMR1=300,
#     NRCP=301,
#     miR-519d-3p=302,
#     EZR-AS1=303,
#     DLX6=304,
#     RSU1P2=305,
#     CD47=306,
#     ERBIN=307,
#     LINC00519=308,
#     BPY2C=309,
#     RAB1B=310,
#     TP53=311,
#     CDC34=312,
#     miR-423-5p=313,
#     LINC00324=314,
#     NFIA=315,
#     lnc-BAZ2B=316,
#     USP22=317,
#     miR-335-5p=318,
#     FMNL2=319,
#     GLI2=320,
#     FOXA1=321,
#     MEG8=322,
#     HOXD10=323,
#     sPLA2=324,
#     DLG1-AS1=325,
#     ABCE1=326,
#     LINC00974=327,
#     GSTP1P1=328,
#     NONHSAT143692.2=329,
#     ASB16-AS1=330,
#     CCR5AS=331,
#     CASP2=332,
#     CDH5=333,
#     miR-195=334,
#     PPP1R10=335,
#     miR-130b=336,
#     MIR4443=337,
#     PWAR6=338,
#     TRIM25=339,
#     Caspase9=340,
#     CA3-AS1=341,
#     GPI=342,
#     AK058003=343,
#     CREB=344,
#     CHUK=345,
#     TNKS2=346,
#     LOC285194=347,
#     HORAS5=348,
#     lncRNA-Unigene56159=349,
#     S100P=350,
#     E2F6=351,
#     miR-140-5p=352,
#     BCL2L11=353,
#     LncHDAC2=354,
#     AKT1=355,
#     LAMC1=356,
#     SEC61G=357,
#     IL-21R=358,
#     LINC01134=359,
#     LINC00470=360,
#     MIR133B=361,
#     SSATX=362,
#     PI4P=363,
#     miR-190a=364,
#     TPTE2P1=365,
#     TUSC7=366,
#     ANXA10=367,
#     GAS6-DT=368,
#     ZNF710-AS1-202=369,
#     OTUD6B-AS1=370,
#     Cyclin E1=371,
#     ISL1=372,
#     MRLN=373,
#     EGFL7=374,
#     GPC6=375,
#     CASC2=376,
#     miR-142-3p=377,
#     miR-20b-5p=378,
#     GSTM3TV2=379,
#     ACSL1=380,
#     OCT4-PG1=381,
#     SNHG5=382,
#     CPEB4=383,
#     lncRNA-14327.1=384,
#     CDKN3A=385,
#     PSMC3=386,
#     MUC1-C=387,
#     Ki-67=388,
#     CFAP251=389,
#     LC3II=390,
#     PCDHB5=391,
#     RB1CC1=392,
#     NONHSAT141924=393,
#     AP1G1=394,
#     ATP7A=395,
#     sONE=396,
#     LINC00299=397,
#     CCNE1=398,
#     CYCSP5=399,
#     ATXN8OS=400,
#     CBLL1=401,
#     KLF8=402,
#     LNCNEF=403,
#     NHEG1=404,
#     LNC000093=405,
#     miR-200b=406,
#     PAK4=407,
#     CBX3=408,
#     p-ERK=409,
#     TAC1=410,
#     RAB23=411,
#     RACK1=412,
#     TBX5=413,
#     FKBP9P1=414,
#     NCAPG=415,
#     LMO4=416,
#     miR-15a/15b/16=417,
#     CNR1=418,
#     let-7a=419,
#     COL1A1=420,
#     MARCKSL1=421,
#     PNPLA2=422,
#     ZRANB2=423,
#     CIR=424,
#     HOPX=425,
#     miR-223-5p=426,
#     KIF4A=427,
#     AC010789.1=428,
#     AC132217.4=429,
#     PEBP1P2=430,
#     ZNF596=431,
#     Mirt2=432,
#     A2M-AS1=433,
#     AC016745.3=434,
#     TMPO-AS1=435,
#     miR-141-3p=436,
#     RBAT1=437,
#     lncGALM=438,
#     SLC2A1=439,
#     TBX2=440,
#     RAB34=441,
#     LINC00619=442,
#     AK039862=443,
#     FLOT1=444,
#     miR-203=445,
#     DIO3OS=446,
#     NQO1=447,
#     NPTN-IT1=448,
#     RELA=449,
#     FAT4=450,
#     PGAM1=451,
#     ACVR2B=452,
#     GPNCA=453,
#     WFDC21P=454,
#     ILF3-DT=455,
#     PFKFB2=456,
#     HOXA11-AS=457,
#     RP11-395G23.3=458,
#     NCKAP1L=459,
#     CR594175=460,
#     LY6E-DT=461,
#     TNFAIP3=462,
#     EPHA2=463,
#     DNAJC3-DT=464,
#     TPT1=465,
#     miR-491-5p=466,
#     SLC26A2=467,
#     SOX2-OT=468,
#     IL18=469,
#     OSMR=470,
#     COMMD6=471,
#     SLCO4A1-AS1=472,
#     lncAPP=473,
#     CCND2=474,
#     LINC01503=475,
#     PRR11=476,
#     PKP2=477,
#     TPX2=478,
#     XLOC-00846=479,
#     DCXR-DT=480,
#     XLOC_000647=481,
#     miR-30b-3p=482,
#     POSTN=483,
#     CASC7=484,
#     CDCP1=485,
#     SFRP2=486,
#     GIT2=487,
#     MIR497HG=488,
#     LATS1=489,
#     AGGF1=490,
#     PSMG3-AS1=491,
#     miR-375-3p=492,
#     BCL11A=493,
#     ERLNC1=494,
#     ATG4B=495,
#     TRPM7=496,
#     G6PD=497,
#     lncRNAuc001.dgp.1=498,
#     AC091729.7=499,
#     CRYBG3=500,
#     IKBKB=501,
#     IGF2=502,
#     miR-125b-1=503,
#     TUBA1A=504,
#     SUMO1P3=505,
#     BRCA1=506,
#     NALT1=507,
#     MDR1=508,
#     CCNB2=509,
#     AGER-1=510,
#     MIR506=511,
#     Lnc-SNHG1=512,
#     CLOCK=513,
#     DAPK1=514,
#     miR-190=515,
#     LINC01234=516,
#     PKMYT1AR=517,
#     WDFY3-AS2=518,
#     miR-383-5p=519,
#     LINC02882=520,
#     podocin=521,
#     LINC00176=522,
#     CCNE2=523,
#     MICA=524,
#     miR-590-3p=525,
#     p-JNK=526,
#     circ_0029589=527,
#     miR-337-3p=528,
#     GALNT7=529,
#     TCL6=530,
#     LMCD1-AS1=531,
#     miR-7-5P=532,
#     C1QBP=533,
#     miR-197-3p=534,
#     FILNC1=535,
#     17beta-E2=536,
#     LINC02835=537,
#     MIR504=538,
#     USP4=539,
#     MIR539=540,
#     TCONS_00004099=541,
#     GCM1=542,
#     DUSP5=543,
#     GABARAPL2=544,
#     OTUD7B=545,
#     PROX1=546,
#     IGFL1=547,
#     TCONS_00026907=548,
#     AP1S2=549,
#     miR-939=550,
#     PRAM1=551,
#     LINC000607=552,
#     GPER1=553,
#     LINC01089=554,
#     CLMAT3=555,
#     IMP3=556,
#     SIN3A=557,
#     HSPB1=558,
#     PRC1=559,
#     PLA2G4A=560,
#     miR-613=561,
#     miR-126=562,
#     STK4=563,
#     miR-196a-5p=564,
#     DE5RT=565,
#     LINC01619=566,
#     NELL2=567,
#     SNX9=568,
#     LINC01305=569,
#     TROJAN=570,
#     SNAI2=571,
#     lnc-IL7R=572,
#     MANCR=573,
#     Tensin1=574,
#     ATP4B=575,
#     HDAC7=576,
#     TGFbetaR1=577,
#     ERP29=578,
#     radixin=579,
#     ITPR1=580,
#     miR-520a-3p=581,
#     KDM2A=582,
#     RYR2=583,
#     miR-106b-5p=584,
#     BRWD1=585,
#     VGF=586,
#     STAT3=587,
#     POU2F1=588,
#     miR-18a-5p=589,
#     KCNC4=590,
#     COL4A2=591,
#     ENO1=592,
#     MIR1972-1=593,
#     SEMA3B=594,
#     FGFR3=595,
#     RBFOX2=596,
#     HLA-DRB1=597,
#     WIF1=598,
#     LOC101928316=599,
#     LINC00458=600,
#     SMARCB1=601,
#     HIX003209=602,
#     miR-508-5p=603,
#     DDN-AS1=604,
#     RPL34=605,
#     CKS1B=606,
#     GPR39=607,
#     lnc-ATB=608,
#     MIR646=609,
#     CBX5=610,
#     DIAPH1=611,
#     PCA3=612,
#     miR-495=613,
#     STK11=614,
#     ZFX=615,
#     RP5-1024C24.1=616,
#     MIR222=617,
#     K6=618,
#     DNAJB6=619,
#     SCARNA13=620,
#     ZCCHC12=621,
#     ACTA2-AS1=622,
#     SRSF1=623,
#     LncRNA-HGBC=624,
#     LINC01551=625,
#     Gm44593=626,
#     LINC01133=627,
#     PTBP1=628,
#     lncRNA-PRLB=629,
#     DINOL=630,
#     MIR210HG=631,
#     RP11-279C4.1=632,
#     LC3-II=633,
#     PLK4=634,
#     PPP2R2A=635,
#     IQGAP1=636,
#     STK39=637,
#     AF119895=638,
#     Linc8087=639,
#     FZD3=640,
#     ITGB2-AS1=641,
#     GBP1=642,
#     SOD2=643,
#     SYNE1-AS1=644,
#     MKRN3=645,
#     LINC00672=646,
#     ARAP1-AS1=647,
#     PPP1R13L=648,
#     TWIST1=649,
#     FLOT2=650,
#     lncRNA 430945=651,
#     PCDHA1=652,
#     INPP5D=653,
#     MMP-15=654,
#     CSF2=655,
#     LOC100507144=656,
#     HAND2-AS1=657,
#     STAT5A=658,
#     CASP1=659,
#     miR-485-5p=660,
#     SOCS2-AS1=661,
#     NKX2-1-AS1=662,
#     TERRA=663,
#     TP53TG1=664,
#     DUXAP9-206=665,
#     DKK 1.00=666,
#     PDK4=667,
#     NONHSAG045500=668,
#     miR-520c-3p=669,
#     LINC02381=670,
#     PDE4D=671,
#     MIR143=672,
#     CDKN2A=673,
#     HHIP<U+2011>AS1=674,
#     IGKJ2-MALLP2=675,
#     ITIH4-AS1=676,
#     MAP1LC3A=677,
#     SLC7A11-AS1=678,
#     FTH1P3=679,
#     TSLP=680,
#     miR-200=681,
#     MIR21=682,
#     TCF4=683,
#     PTTG1=684,
#     MCL1=685,
#     miR-20a-5p=686,
#     TP73=687,
#     TUBA4B=688,
#     KLF6=689,
#     CYCS=690,
#     HYOU1-AS=691,
#     uc.38=692,
#     THBS1=693,
#     MIR675=694,
#     RANBP2=695,
#     TMPRSS11E=696,
#     FKBP1A=697,
#     BLACAT1=698,
#     p-JAK=699,
#     BRMS1L=700,
#     UGP2=701,
#     RP11-86H7.1=702,
#     ET-1=703,
#     ABL1=704,
#     MACC1=705,
#     ESM1=706,
#     DICER1-AS1=707,
#     BCL2L2=708,
#     LINC00536=709,
#     HAR2A=710,
#     CLDN2=711,
#     TERT=712,
#     OIP5=713,
#     HAVCR2=714,
#     UCC=715,
#     FN1=716,
#     IGSF9B=717,
#     PCAT7=718,
#     PSMB8-AS1=719,
#     miR-133a=720,
#     CENPE=721,
#     NOTCH4=722,
#     MIR2467=723,
#     CDK6=724,
#     GLUD1=725,
#     SNCAIP=726,
#     miR-148a-3p=727,
#     PPARA=728,
#     CDC20=729,
#     PTK2=730,
#     MAPK3=731,
#     TRAF6=732,
#     KMT2C=733,
#     LINC00941=734,
#     lncRNA-numb=735,
#     KLK12=736,
#     LINC01857=737,
#     DIRAS3=738,
#     MGMT=739,
#     TCF3=740,
#     NXF3=741,
#     MIR221=742,
#     hsa-miR-197-3p=743,
#     EPHA1=744,
#     LINC00922=745,
#     E2F7=746,
#     p-CREB=747,
#     STAT1=748,
#     E2F1=749,
#     PWRN1=750,
#     RAD21=751,
#     PTPN2=752,
#     PCAT19=753,
#     CPT11=754,
#     SNAI1=755,
#     LINC02041=756,
#     HELLS=757,
#     NKILA=758,
#     LINC00612=759,
#     CASC2c=760,
#     HOXC6=761,
#     miR-448=762,
#     SPNS2=763,
#     LMTK3=764,
#     ATG14=765,
#     miR-194=766,
#     STC1=767,
#     TPM1=768,
#     miR-141=769,
#     TRAF3=770,
#     CDK14=771,
#     FGD5-AS1=772,
#     LOC646616=773,
#     LOC101927746=774,
#     NOB1=775,
#     NBAT1=776,
#     FOXD3=777,
#     SHMT2=778,
#     IRF1-AS=779,
#     RPL34-DT=780,
#     miR-211-3p=781,
#     EIF4B=782,
#     ENST00000602558.1=783,
#     ATG3=784,
#     SOX7=785,
#     Col II=786,
#     MIR874=787,
#     EPEL=788,
#     SNX16=789,
#     LRIG2=790,
#     E4F1=791,
#     DCLK1=792,
#     GCSAM=793,
#     PTPRF=794,
#     LINC00312=795,
#     SENEBLOC=796,
#     CRLS1=797,
#     lnc-Sox5=798,
#     lnc-AL445665.1-4=799,
#     ARAP1-AS2=800,
#     MIR7-3HG=801,
#     MIR122=802,
#     TFDP1=803,
#     RHEB=804,
#     LINC00483=805,
#     FAM225B=806,
#     HMOX1=807,
#     Hsp4=808,
#     FOS=809,
#     MIR590=810,
#     PRR34-AS1=811,
#     KDM4C=812,
#     TRIM8=813,
#     PKC¶∆=814,
#     MIR924HG=815,
#     C2orf92=816,
#     PAX8<U+2011>AS1:28=817,
#     RAPSN=818,
#     HOXC-AS1=819,
#     FOXC2-AS1=820,
#     PAX8-AS1=821,
#     TNRC6C-AS1=822,
#     ZBTB2=823,
#     NONRATG019935.2=824,
#     SRC-1=825,
#     HATAIR=826,
#     GEHT1=827,
#     miR-323b-5p=828,
#     GRK2=829,
#     PBX3=830,
#     STAT6=831,
#     EMP1=832,
#     EED=833,
#     MIR1244-1=834,
#     PSEN1=835,
#     MAGI1-IT1=836,
#     CCAT1-L=837,
#     PTBP3=838,
#     MLKL=839,
#     CDK13=840,
#     GSK3¶¬=841,
#     SLIT2=842,
#     LNCBRM=843,
#     ABL2=844,
#     IL11=845,
#     MUC6=846,
#     miR-204-5p=847,
#     ATOH1=848,
#     KIF3B=849,
#     SNCA=850,
#     ATF4=851,
#     YWHAE=852,
#     miR-221=853,
#     SNORA7A=854,
#     LNCOG=855,
#     AND2-AS1=856,
#     W42=857,
#     KIF23=858,
#     AC096664.3=859,
#     P65=860,
#     TRIM65=861,
#     RP11-476D10.1=862,
#     BACE1-AS=863,
#     RAB10=864,
#     WNT2B=865,
#     GFPT1=866,
#     RIPK1=867,
#     WWP1=868,
#     HSPA7=869,
#     LINC01006=870,
#     MRUL=871,
#     PSMD9=872,
#     RP11-340F14.6=873,
#     HLA-G=874,
#     miR<U+2011>34c=875,
#     FADD=876,
#     FOXA2=877,
#     LINC00554=878,
#     CYB5R2=879,
#     IFIT2=880,
#     TIMM50=881,
#     RAB5B=882,
#     miR-200b-3p=883,
#     E2F4=884,
#     RAC2=885,
#     DCP1A=886,
#     S100A11=887,
#     MIR647=888,
#     u50535=889,
#     CYP26B1=890,
#     miR-411-3p=891,
#     LRPPRC=892,
#     TLX1=893,
#     FOXN2=894,
#     LINC01152=895,
#     KAT2A=896,
#     MIR570HG=897,
#     SPRY4-IT1=898,
#     Snai=899,
#     FBP1=900,
#     MIR454=901,
#     LncRNA-Y5=902,
#     HK2=903,
#     Lnc-EGFR=904,
#     PCAT1=905,
#     CDKN1A=906,
#     miR-144=907,
#     CD80=908,
#     LNC00312=909,
#     PDE10A=910,
#     SIRT3=911,
#     PARD3=912,
#     CSDE1=913,
#     ATG16L1=914,
#     RBG2=915,
#     SNHG7=916,
#     S100A1=917,
#     LDC1P=918,
#     WiNTRLINC1=919,
#     PA2G4=920,
#     PRMT1=921,
#     RNF38=922,
#     lncRNA625=923,
#     AGPAT2=924,
#     MIR127=925,
#     NCK1=926,
#     SHH=927,
#     integrinbeta1=928,
#     EGF=929,
#     EGR4=930,
#     miR-296-5p=931,
#     MED12/HMGA2=932,
#     Hmrhl=933,
#     GSR=934,
#     miR-190a-5p=935,
#     IL10=936,
#     LINC01232=937,
#     ARID1B=938,
#     MSH5=939,
#     TNFRSF1B=940,
#     SPRY2=941,
#     miR-183-5p=942,
#     GCASPC=943,
#     RCCD1=944,
#     LINC01149=945,
#     MUC5AC=946,
#     SP3=947,
#     MAPKAPK5-AS1=948,
#     miR181a-5p=949,
#     NLK=950,
#     SREBF2=951,
#     TP73-AS1=952,
#     PAK1=953,
#     KDM7A-DT=954,
#     PART1=955,
#     lncBCAS1-4_1=956,
#     Girdin=957,
#     TLR2=958,
#     DRAIC=959,
#     MTA3=960,
#     miR-24=961,
#     PINK1-AS=962,
#     MMP-8=963,
#     NFKBIA=964,
#     FGFR1=965,
#     MX1=966,
#     CaMKII¶ƒ=967,
#     PDPN=968,
#     IGF2BP2=969,
#     CTBP1=970,
#     HIF1A-AS1=971,
#     LINC01061=972,
#     SPRY4=973,
#     EBF3=974,
#     LSINCT5=975,
#     miR-513b-5p=976,
#     TGFBR1=977,
#     SIK1=978,
#     RP11-789C1.1=979,
#     miR-20a=980,
#     ST8SIA6-AS1=981,
#     miR-15b-5p=982,
#     GSTM3=983,
#     CRNDE=984,
#     BCL2L1=985,
#     SMO=986,
#     BCAR4=987,
#     miR-200a=988,
#     SMG1=989,
#     Pim-1=990,
#     MAP2K1=991,
#     TMEM238L=992,
#     SCUBE2=993,
#     miR-101-3p=994,
#     LINC01287=995,
#     TANAR=996,
#     RPL35=997,
#     CRYAA=998,
#     YAF2=999,
#     FOXD2-AS1=1000,
#     CELF1=1001,
#     AGR2=1002,
#     LINC01123=1003,
#     XLOC_008466=1004,
#     PRKAG1=1005,
#     MALAT1=1006,
#     PAK2=1007,
#     SOCS6=1008,
#     CYTH3=1009,
#     ZRANB1=1010,
#     C5orf66-AS1=1011,
#     EPIST=1012,
#     MXD1=1013,
#     HMGA2-AS1=1014,
#     MIR23C=1015,
#     TGFbeta2-AS1=1016,
#     miR©\221=1017,
#     CDCA3=1018,
#     CARD8=1019,
#     PYCR1=1020,
#     NKIRAS2=1021,
#     FHL1=1022,
#     PFKFB3=1023,
#     LINC00628=1024,
#     TET=1025,
#     MIR484=1026,
#     CREB3=1027,
#     CDC5L=1028,
#     LINC01116=1029,
#     SATB2-AS1=1030,
#     BC032469=1031,
#     EIF5AL1=1032,
#     METAP1=1033,
#     BDNF=1034,
#     ADAM17=1035,
#     EIF4EBP1=1036,
#     CBLB=1037,
#     ERBB4=1038,
#     miR-7=1039,
#     MROCKI=1040,
#     ARAP1=1041,
#     SCAT1=1042,
#     ZNF710=1043,
#     LncHOXA10=1044,
#     CDKN2B=1045,
#     SPHK2=1046,
#     LINC01446=1047,
#     ABCG2=1048,
#     miR-185=1049,
#     LncCCAT1=1050,
#     LGMNP1=1051,
#     ST3GAL6-AS1=1052,
#     SHOX2=1053,
#     PRSS8=1054,
#     ALDOA=1055,
#     PRKDC=1056,
#     p50=1057,
#     miR-576-5p=1058,
#     CDCA7=1059,
#     BNIP3=1060,
#     FOXD1=1061,
#     LBX2-AS1=1062,
#     p-PI3K=1063,
#     AFF1=1064,
#     MVIH=1065,
#     SOX21-AS1=1066,
#     CGRP=1067,
#     miR-382-5p=1068,
#     PACERR=1069,
#     SCARNA2=1070,
#     PRKAB1=1071,
#     BMPR1A=1072,
#     RP11-361F15.2=1073,
#     TYKRIL=1074,
#     PDK1=1075,
#     GCLM=1076,
#     NONHSAT112228.2=1077,
#     KCND2=1078,
#     WEE1=1079,
#     PHF6=1080,
#     MTDH=1081,
#     ENST00000413528=1082,
#     CXCL14=1083,
#     miR-148b=1084,
#     MIR193A=1085,
#     LINC00707=1086,
#     NPHS1=1087,
#     SNHG17=1088,
#     AKR1B1=1089,
#     XIST=1090,
#     DLGAP1-AS2=1091,
#     lncR-D63785=1092,
#     MAGEA9=1093,
#     RAB4B-EGLN2=1094,
#     ACTG1P25=1095,
#     miR-155=1096,
#     CALCOCO1=1097,
#     LEF1=1098,
#     DDX3X=1099,
#     RGS3=1100,
#     miR-1285-3p=1101,
#     EZH2=1102,
#     HDAC4=1103,
#     MYCBP=1104,
#     PLSCR4=1105,
#     RPP25=1106,
#     Lnc-EPIC1=1107,
#     miR-211=1108,
#     p15=1109,
#     miR-214-3p=1110,
#     COL1A2=1111,
#     ACP5=1112,
#     SNCG=1113,
#     SLAIN2=1114,
#     FOSL2=1115,
#     INSM1=1116,
#     WEE2-AS1=1117,
#     PFN1=1118,
#     OPCML=1119,
#     LncRNATCF7=1120,
#     RNA00887=1121,
#     RAMS11=1122,
#     WT1-AS=1123,
#     HNRNPH1=1124,
#     HEIH=1125,
#     LINC01303=1126,
#     Claudin-2=1127,
#     MIR197=1128,
#     CDC14A=1129,
#     ZNF205-AS1=1130,
#     miR-7-5p=1131,
#     FAM99A=1132,
#     FUT6=1133,
#     LncRNA-OBFC2A=1134,
#     ADAM9=1135,
#     HOXBLINC=1136,
#     GATA3=1137,
#     FBXW8=1138,
#     TMEM18=1139,
#     p62=1140,
#     SNHG12=1141,
#     CDCA4=1142,
#     YY1=1143,
#     MTUS1=1144,
#     USP39=1145,
#     n384546=1146,
#     miR-146b-5p=1147,
#     RAD51-AS1=1148,
#     TASR=1149,
#     AP2¶√=1150,
#     CHRF=1151,
#     CHRNB2=1152,
#     miR-615-5p=1153,
#     FGF13=1154,
#     NASP=1155,
#     RAC3=1156,
#     H3K27=1157,
#     TWIST2=1158,
#     miR-150=1159,
#     LIN28A=1160,
#     LINC00976=1161,
#     LINC02200=1162,
#     BCL2=1163,
#     lncRNA-5657=1164,
#     NR026833.1=1165,
#     EEF1A1=1166,
#     APOBEC3B=1167,
#     TESC=1168,
#     PRAF2=1169,
#     PDCD4=1170,
#     GOT1=1171,
#     RGS4=1172,
#     LIN7A=1173,
#     SAMMSON=1174,
#     USF1=1175,
#     MIR141=1176,
#     TFAM=1177,
#     ERK=1178,
#     UCP2=1179,
#     SMOC1=1180,
#     miR-149-5p=1181,
#     MIR29B1=1182,
#     LINC02862=1183,
#     miR-335=1184,
#     OAS3=1185,
#     RHOC=1186,
#     LINC02582=1187,
#     Capsase9=1188,
#     CCL21=1189,
#     SOX11=1190,
#     NFE2L1=1191,
#     PCSK9=1192,
#     NBR2=1193,
#     LINC00459=1194,
#     PAXIP1-DT=1195,
#     CPEB3=1196,
#     CDYL=1197,
#     ETS2=1198,
#     LNCDQ=1199,
#     FOXC1=1200,
#     MATN1-AS1=1201,
#     KCNMA1-AS1=1202,
#     NBDY=1203,
#     miR-27a=1204,
#     MBD1=1205,
#     miR-19=1206,
#     IQANK1=1207,
#     ACLY=1208,
#     lncRNA-ENST00000411554=1209,
#     LAYN=1210,
#     SOX8=1211,
#     SLEAR=1212,
#     FAM87A=1213,
#     BTG3-AS1=1214,
#     MS4A1=1215,
#     GREP1=1216,
#     Linc-00313=1217,
#     E-selectin=1218,
#     LNCSRLR=1219,
#     miR-203a=1220,
#     miR-125a-5p=1221,
#     VOPP1=1222,
#     ZNF217=1223,
#     linc-223=1224,
#     MELTF=1225,
#     MIR4686=1226,
#     TCONS_00024652=1227,
#     RP11-323N12.5=1228,
#     FGF13-AS1=1229,
#     VDR=1230,
#     FOXP2=1231,
#     LINC01385=1232,
#     MIR3690=1233,
#     miR-940=1234,
#     ESR1=1235,
#     CEP55=1236,
#     RAB11B=1237,
#     CTCF=1238,
#     LINC00222=1239,
#     miR-26a-5p=1240,
#     FASLG=1241,
#     EGR2=1242,
#     BALR-6=1243,
#     miR-147a=1244,
#     ERK1/2=1245,
#     LIN28B-AS1=1246,
#     ESRP2=1247,
#     COMMD8=1248,
#     RAB1A=1249,
#     JUNB=1250,
#     LINC00174=1251,
#     SNHG22=1252,
#     Caspase8=1253,
#     miR-542-3p=1254,
#     SIX1=1255,
#     NFAT5=1256,
#     SUB1=1257,
#     miR-574-5p=1258,
#     SCDAL=1259,
#     FAM83A-AS1=1260,
#     URRCC=1261,
#     PKM=1262,
#     CAPN7=1263,
#     FBXO22=1264,
#     LOXL1-AS=1265,
#     MIR219A1=1266,
#     SRGAP1=1267,
#     RP11-2B6.2=1268,
#     TIA1=1269,
#     LncMyoD=1270,
#     NUDT1=1271,
#     MEG3=1272,
#     FOXO1=1273,
#     LINC01433=1274,
#     BRD3OS=1275,
#     ITGA2=1276,
#     CLNK=1277,
#     PANTR1=1278,
#     HERES=1279,
#     FBXW7=1280,
#     CD2=1281,
#     TTN-AS1=1282,
#     ITGAX=1283,
#     RP11-115N4.1=1284,
#     AOC4P=1285,
#     RAF1=1286,
#     CASP8=1287,
#     miR-425-5p=1288,
#     ING3=1289,
#     CDC25A=1290,
#     uc061hsf.1=1291,
#     lnc-ABCA12-3=1292,
#     lnc-LYZ-2=1293,
#     PLXNC1=1294,
#     miR-29b=1295,
#     MIR217=1296,
#     RAB22A=1297,
#     miR-17-5p=1298,
#     COL1A1-014=1299,
#     DNMT1=1300,
#     LOXL1-AS1=1301,
#     AK093407=1302,
#     LncRNA-TWIST1=1303,
#     MAGI2=1304,
#     XLOC_006753=1305,
#     IL1R2=1306,
#     ITGAV=1307,
#     ITGB2=1308,
#     ZEB1-AS1=1309,
#     LINC01121=1310,
#     NDRG2=1311,
#     GINS2=1312,
#     SAP30-2:1=1313,
#     LRG1=1314,
#     SNHG4=1315,
#     STC2=1316,
#     PLK2=1317,
#     P38=1318,
#     NF2=1319,
#     miR-124=1320,
#     MIR205HG=1321,
#     LINC01559=1322,
#     TSPYL4=1323,
#     miR-429=1324,
#     IL12A=1325,
#     FGFR3-AS1=1326,
#     MSI2=1327,
#     RRM2=1328,
#     MIR186=1329,
#     C3orf85=1330,
#     MIR4658=1331,
#     IUR=1332,
#     MFI2=1333,
#     Cyclin A=1334,
#     AURKB=1335,
#     MIR33B=1336,
#     ITGA3=1337,
#     miR-124-3p=1338,
#     miR-101=1339,
#     ANGPT4=1340,
#     Lnc34a=1341,
#     miR-103a=1342,
#     PHACTR2-AS1=1343,
#     MYO6=1344,
#     LINC00887=1345,
#     RhoGD=1346,
#     PRECSIT=1347,
#     AKT2=1348,
#     NACC1=1349,
#     BATF3=1350,
#     SPZ1=1351,
#     VPS45=1352,
#     miR-488-3p=1353,
#     CXCL9=1354,
#     BASP1=1355,
#     SORBS2=1356,
#     ITGA4=1357,
#     SOX13=1358,
#     PCDHB17P=1359,
#     HDAC8=1360,
#     PRPS1=1361,
#     CTHRC1=1362,
#     miR-212=1363,
#     MIR211=1364,
#     CASC8=1365,
#     NFIA-AS2=1366,
#     miR-138=1367,
#     MDM2=1368,
#     XBP1=1369,
#     SFTA3=1370,
#     TGF-betaR2=1371,
#     lncRNACNN3-206=1372,
#     AK126698=1373,
#     RAS=1374,
#     miR-181a-5p=1375,
#     RAB3D=1376,
#     JUND1=1377,
#     DICER1=1378,
#     SYNCRIP=1379,
#     BIRC7=1380,
#     SNHG3=1381,
#     MAP2K4=1382,
#     LINC01354=1383,
#     Giver=1384,
#     SAMD12-AS2=1385,
#     p16=1386,
#     LPAL2=1387,
#     MIR497=1388,
#     LOC100129620=1389,
#     LUADT1=1390,
#     PCNA=1391,
#     MIR455=1392,
#     miR-374a=1393,
#     Gal-1=1394,
#     LINC01189=1395,
#     p-AKT=1396,
#     GAS6-AS1=1397,
#     NONHSAT101069=1398,
#     GLP1R=1399,
#     KDR=1400,
#     FARSA=1401,
#     EGFR,=1402,
#     HOXC-AS2=1403,
#     BISPR=1404,
#     CCNB1=1405,
#     LINP1=1406,
#     miR-324-3p=1407,
#     NFATC3=1408,
#     MIR204=1409,
#     SERPINE1=1410,
#     SLC27A4=1411,
#     lncRSPH9-4=1412,
#     ZC3H12A=1413,
#     PSMD10=1414,
#     miR-378a-3p=1415,
#     DNMTs=1416,
#     MYLIP=1417,
#     NRF2=1418,
#     p-STAT=1419,
#     TAF1=1420,
#     miR-16-5p=1421,
#     TMPO=1422,
#     CamK-A=1423,
#     FEZF1-AS1=1424,
#     TOB1-AS1=1425,
#     FOXQ1=1426,
#     PDZK1=1427,
#     C1QB=1428,
#     SRSF7=1429,
#     ROMO1=1430,
#     PFI=1431,
#     miR-199a-5p=1432,
#     RNF144B=1433,
#     ANXA2=1434,
#     MGP=1435,
#     CCDC80=1436,
#     MAPK6=1437,
#     JAK=1438,
#     TSC1=1439,
#     FLT1=1440,
#     LINRIS=1441,
#     LINC00908=1442,
#     CERNA2=1443,
#     MIR361=1444,
#     miR-458-5p=1445,
#     CASC21=1446,
#     LINC00460=1447,
#     CK1¶≈=1448,
#     ELFN1-AS1=1449,
#     TCONS_00034812=1450,
#     NLRX1=1451,
#     ISM1=1452,
#     MIR499B=1453,
#     SET=1454,
#     MPPED2=1455,
#     BRI3=1456,
#     LINC01260=1457,
#     AK001796=1458,
#     PCAT14=1459,
#     FOSL1=1460,
#     YY1AP1=1461,
#     miR-34a=1462,
#     miR-27a-3p=1463,
#     NOD2=1464,
#     miR-130a=1465,
#     KPNA3=1466,
#     SNHG16=1467,
#     RBM33=1468,
#     MIR31HG=1469,
#     HBX=1470,
#     LINC00630=1471,
#     PIAS3=1472,
#     MRCCAT1=1473,
#     DUSP1=1474,
#     MIR381=1475,
#     LINC00462=1476,
#     CSNK1E=1477,
#     DGCR8=1478,
#     NECAB3=1479,
#     FERRE=1480,
#     SREBF1=1481,
#     LINC01579=1482,
#     miR-192=1483,
#     LINC00973=1484,
#     MIR99AHG=1485,
#     GDF6=1486,
#     Foxa3a=1487,
#     MAPK14=1488,
#     let-7c=1489,
#     BX647187=1490,
#     IGF2BP3=1491,
#     TNFRSF10A=1492,
#     PABPC1=1493,
#     TSLD8=1494,
#     PLEKHO2=1495,
#     CYTOR=1496,
#     BRD4=1497,
#     miR-3200=1498,
#     RAPIA=1499,
#     POU6F2-AS2=1500,
#     ECM1=1501,
#     LRP2BP=1502,
#     RP11-838N2.4=1503,
#     MIR607=1504,
#     KIF20A=1505,
#     THAP7-AS2=1506,
#     NETO2=1507,
#     HAGLR=1508,
#     DEDD=1509,
#     LINC-ROR=1510,
#     CAMP=1511,
#     lncRNA-CTS=1512,
#     IRX5=1513,
#     CCR6=1514,
#     RP11-190D6.2=1515,
#     ADAMTS9-AS2=1516,
#     linc-cdh4-2=1517,
#     VIM-AS1=1518,
#     CAIF=1519,
#     ASMTL-AS1=1520,
#     VASP=1521,
#     PNCTR=1522,
#     LAMTOR5=1523,
#     lncRNA-LOWEG=1524,
#     LOC646329=1525,
#     fibronectin=1526,
#     FZD7=1527,
#     LOC728196=1528,
#     NFAT=1529,
#     COG7=1530,
#     FUS=1531,
#     NCAPG2=1532,
#     AGO1=1533,
#     DYRK2=1534,
#     DKK 3.00=1535,
#     NFKBIB=1536,
#     MITF-SOX10=1537,
#     SFN=1538,
#     circ-PSEN1=1539,
#     NOP58=1540,
#     PPM1A-AS=1541,
#     miR-128=1542,
#     KDM5C=1543,
#     TLN1=1544,
#     RP11-1094M14.8=1545,
#     MIR663A=1546,
#     SPI1=1547,
#     DNMT3B=1548,
#     AURKA=1549,
#     WT1=1550,
#     LINC00589=1551,
#     Lnc-Myd88=1552,
#     TMEM220-AS1=1553,
#     RAB14=1554,
#     LINC00858=1555,
#     TTTY15=1556,
#     CCAT2=1557,
#     miR-449a=1558,
#     miR-218-5p=1559,
#     LCAT1=1560,
#     KLF7=1561,
#     UBXN1=1562,
#     LUNAR1=1563,
#     CircZNF609=1564,
#     BAX=1565,
#     NEAT1_2=1566,
#     SIM2=1567,
#     GATD3=1568,
#     LMO3=1569,
#     CXCL11=1570,
#     CPEB1=1571,
#     NOTCH1=1572,
#     miR-650=1573,
#     PHB2=1574,
#     WNT1A=1575,
#     PSMA3-AS1=1576,
#     CEBPA=1577,
#     MET=1578,
#     RET=1579,
#     FRMD6=1580,
#     SSTR5=1581,
#     MIR421=1582,
#     Lnc00908=1583,
#     LINC00346=1584,
#     SPHK1=1585,
#     lncRNA2448-11=1586,
#     has-miR-485-5p=1587,
#     MROS-1=1588,
#     DALIR=1589,
#     PBX1=1590,
#     MIR496=1591,
#     Cyclin D1=1592,
#     EGR1=1593,
#     EIF4A3=1594,
#     AK055347=1595,
#     PAFAH1B1=1596,
#     RAB5C=1597,
#     EGFR=1598,
#     MYCNOS-01=1599,
#     miR<U+2011>16=1600,
#     uc.339=1601,
#     PD-L1-lnc=1602,
#     LPAR3=1603,
#     FAF1=1604,
#     let-7b=1605,
#     WNT11=1606,
#     LIFR-AS1=1607,
#     MRPL23-AS1=1608,
#     MELK=1609,
#     UPF1=1610,
#     APTR=1611,
#     PANDAR=1612,
#     FOXO3=1613,
#     NR2F2-AS1=1614,
#     UBE2CP3-001=1615,
#     VIM-AS2=1616,
#     ARC=1617,
#     MIR182=1618,
#     GAS8-AS1=1619,
#     FOXP4-AS1=1620,
#     miR-1254=1621,
#     RGS1=1622,
#     MIR3182=1623,
#     MIR196B=1624,
#     LINC00221=1625,
#     TWF1=1626,
#     LGMN=1627,
#     MMP15=1628,
#     miR-133a-3p=1629,
#     LGR5=1630,
#     CCNG1=1631,
#     RUSC1-AS1=1632,
#     HOXB13=1633,
#     NONHSAT140844=1634,
#     NONHSAT113026=1635,
#     PNPO=1636,
#     SCAMP1=1637,
#     miR-3619-5p=1638,
#     BDH2=1639,
#     AQP4=1640,
#     POU3F3=1641,
#     KLF2=1642,
#     miR-26b-5p=1643,
#     miR-155-5p=1644,
#     NRON=1645,
#     CCND2-AS1=1646,
#     miR-21=1647,
#     PYCARD=1648,
#     n340790=1649,
#     EIF5A2=1650,
#     ACY1=1651,
#     EIF3J-DT=1652,
#     CREB1=1653,
#     IL-1beta=1654,
#     miR-361-5p=1655,
#     SAMD12-AS1=1656,
#     CLIC5=1657,
#     AL589986.2=1658,
#     TIMP4=1659,
#     YWHAZ=1660,
#     HOXO-AS1=1661,
#     LINC01615=1662,
#     NEU1=1663,
#     INCENP=1664,
#     TUBGCP5=1665,
#     LOC100505817=1666,
#     NONHSAT069381=1667,
#     BMI1=1668,
#     miR-513a-5p=1669,
#     TMX2-CTNND1=1670,
#     DSP=1671,
#     ATG5=1672,
#     SOS 1=1673,
#     miR-193a=1674,
#     LINC00165=1675,
#     FUNDC2P4=1676,
#     CPS1-IT1=1677,
#     PFAR=1678,
#     ASTN1=1679,
#     MIR223=1680,
#     SEPTIN6=1681,
#     NRIP1=1682,
#     MEF2A=1683,
#     YTHDF1=1684,
#     LASP1-AS=1685,
#     E7¶§N=1686,
#     CASP9=1687,
#     miR-134-5p=1688,
#     CERS6-AS1=1689,
#     E2F2=1690,
#     LINC00882=1691,
#     FRMD6-AS2=1692,
#     HSRL=1693,
#     GABPA=1694,
#     NTRK3=1695,
#     Linc-SCRG1=1696,
#     LINC00987=1697,
#     MMP©\3=1698,
#     PSPC1=1699,
#     DLST=1700,
#     RCC2=1701,
#     miR-455-3p=1702,
#     VAMP2=1703,
#     DUSP4=1704,
#     KMT2A=1705,
#     miR-29a-3p=1706,
#     LINC01555=1707,
#     KCNK3=1708,
#     HK1=1709,
#     LMX1A=1710,
#     LINC01138=1711,
#     PWAR5=1712,
#     GRIK1-AS1=1713,
#     lncRNA-135528=1714,
#     ZXF2=1715,
#     SNHG15=1716,
#     MMP13=1717,
#     PHB=1718,
#     miR-135b=1719,
#     miR-216b-5p=1720,
#     TDRG1=1721,
#     CXCL5=1722,
#     SRSF3=1723,
#     miR-23b-3p=1724,
#     FAM230B=1725,
#     TEAD4=1726,
#     p-Akt=1727,
#     PDGFB=1728,
#     BFAL1=1729,
#     miR-4301=1730,
#     LINC00844=1731,
#     HNRNPKP2=1732,
#     ULK1=1733,
#     CENPF=1734,
#     CD274=1735,
#     HNF4A-AS1=1736,
#     MIR4435-2HG=1737,
#     miR-203a-3p=1738,
#     EIF5A=1739,
#     S1PR2=1740,
#     LINC00472=1741,
#     CREB5=1742,
#     GSDME=1743,
#     JAG2=1744,
#     LRP6=1745,
#     RASL12=1746,
#     HIP1=1747,
#     NFE2L2=1748,
#     ATF3=1749,
#     LINC02303=1750,
#     DLX1=1751,
#     HOXD3=1752,
#     PINT87aa=1753,
#     GFRA1=1754,
#     PURPL=1755,
#     LINC00942=1756,
#     CALN1=1757,
#     IL-1¶¬=1758,
#     MIR608=1759,
#     JAK2=1760,
#     HMGA2=1761,
#     miR-130a-3p=1762,
#     LncRNA-HIT=1763,
#     IGFL2-AS1=1764,
#     NONO=1765,
#     miR-129=1766,
#     STAT2=1767,
#     IRAIN=1768,
#     Wnt=1769,
#     KLF15=1770,
#     KDM6B=1771,
#     AL163636.1=1772,
#     CASC19=1773,
#     PIK3R2=1774,
#     LINC0086=1775,
#     NLIPMT=1776,
#     ASCL2=1777,
#     p-p65=1778,
#     CHD1=1779,
#     miR-25-3p=1780,
#     miR-484=1781,
#     WNT3A=1782,
#     PRG1=1783,
#     PAK3=1784,
#     RP11-531A24.3=1785,
#     SEMA3B-AS1=1786,
#     ETS1=1787,
#     MMP10=1788,
#     PGR=1789,
#     EIF2AK3=1790,
#     LINC01980=1791,
#     PXN-AS1-L=1792,
#     TFAP2A=1793,
#     SMAD1=1794,
#     LINC00839=1795,
#     GPNMB=1796,
#     lnc-bc060912=1797,
#     NOS3=1798,
#     EMSLR=1799,
#     ARHGAP18=1800,
#     lnc-FANCI-2=1801,
#     B3GALT5-AS1=1802,
#     miR-451a=1803,
#     SLC8A1=1804,
#     TCONS_00023979=1805,
#     PEG10=1806,
#     AK006025=1807,
#     MIA3=1808,
#     miR-217=1809,
#     HMMR=1810,
#     MIR205=1811,
#     RP1-90L14.1=1812,
#     MAGI2-AS=1813,
#     LINC00461=1814,
#     CCAL=1815,
#     miR-214=1816,
#     LINC01352=1817,
#     RICTOR=1818,
#     LOC105375913=1819,
#     RAC1=1820,
#     PTBP2=1821,
#     BAK1=1822,
#     GDF2=1823,
#     NEDD9=1824,
#     GTSE1=1825,
#     miR-16=1826,
#     Erk=1827,
#     SRF=1828,
#     IL23A=1829,
#     LINC01355=1830,
#     BMP7=1831,
#     FABP5=1832,
#     ADPGK-AS1=1833,
#     BGLT3=1834,
#     PAK5=1835,
#     MCF2L-AS1=1836,
#     CAR10=1837,
#     SNIP1=1838,
#     MYOD1=1839,
#     EGFR-AS1=1840,
#     Clecaspase-9=1841,
#     RBM19=1842,
#     CAPNS1=1843,
#     IL21-AS1=1844,
#     PPM1H=1845,
#     HOXA9=1846,
#     PCAT6=1847,
#     NEK2=1848,
#     GIHCG=1849,
#     DLEU1=1850,
#     HSPG2=1851,
#     ZFP91=1852,
#     TRERNA1=1853,
#     IL13=1854,
#     BANCR=1855,
#     CARMN=1856,
#     RP11-713B9.1=1857,
#     RP5-857K21.7=1858,
#     DGCR5=1859,
#     MIR214=1860,
#     ABI3BP=1861,
#     TONSL-AS1=1862,
#     LRRK2=1863,
#     let-7g-5p=1864,
#     RP11-445H22.4=1865,
#     BMPR2=1866,
#     miR-489-3p=1867,
#     FBXL19-AS1=1868,
#     DSG1=1869,
#     CircFOXO3=1870,
#     HMGB3=1871,
#     METTL14=1872,
#     miRNA-155=1873,
#     KCNQ1OT1=1874,
#     ELAVL1=1875,
#     ALX4=1876,
#     FENDRR=1877,
#     SIRT1=1878,
#     CACS15=1879,
#     miR-152-3p=1880,
#     RXRA=1881,
#     SBF2-AS1=1882,
#     FAFASA-AS1=1883,
#     MCM3AP-AS1=1884,
#     EZH1=1885,
#     CDK8=1886,
#     RAX2=1887,
#     ARHGAP5-AS1=1888,
#     AGAP2-AS1=1889,
#     SLC47A2=1890,
#     HNRNPAB=1891,
#     miR-512-3p=1892,
#     FRGCA=1893,
#     VESTAR=1894,
#     LIMK1=1895,
#     hsa-miR-186-5p=1896,
#     S100A7=1897,
#     NRAD1=1898,
#     KLF3=1899,
#     BABAM2-AS1=1900,
#     APC1=1901,
#     GIAT4RA=1902,
#     PAX6=1903,
#     miR-182-5p=1904,
#     TET2=1905,
#     SCD1=1906,
#     TMEM9=1907,
#     BG981369=1908,
#     TLR10=1909,
#     ERLR=1910,
#     miR-3130-3p=1911,
#     MIR622=1912,
#     MSL2=1913,
#     NKX2-5=1914,
#     PSMD6-AS1=1915,
#     miR-548k=1916,
#     SULT1A1=1917,
#     miR-224-5p=1918,
#     IGF2BP1=1919,
#     ZBTB5=1920,
#     LINC00886=1921,
#     TLR7=1922,
#     miR-96=1923,
#     FGFR2=1924,
#     LEF1-AS1=1925,
#     LEGLTBC=1926,
#     LINC01518=1927,
#     GATA2-AS1=1928,
#     IRF1=1929,
#     PLACT1=1930,
#     FERMT2=1931,
#     AK027294=1932,
#     lnc-BMP1-1=1933,
#     miR-200c=1934,
#     MCAM=1935,
#     7SK=1936,
#     TMEM220=1937,
#     TK1=1938,
#     TFRC=1939,
#     CHD7=1940,
#     OS9=1941,
#     MIR154=1942,
#     ANKRD1=1943,
#     miR-370-3p=1944,
#     LINC00342=1945,
#     RP11-598D14.1=1946,
#     LOC100129148=1947,
#     PLAGL2=1948,
#     miR-4429=1949,
#     STAU1=1950,
#     PRC2=1951,
#     IFI27=1952,
#     VE-Cadherin=1953,
#     SLC34A2=1954,
#     miR-532-5p=1955,
#     GSKIP=1956,
#     miR-26a=1957,
#     SLC26A4-AS1=1958,
#     MAGI2-AS3=1959,
#     TIMP3=1960,
#     SCHLAP1=1961,
#     CXCL2=1962,
#     NEXN=1963,
#     KISS1=1964,
#     MIF=1965,
#     LETR1=1966,
#     KRT7-AS=1967,
#     AF339813=1968,
#     PTK2B=1969,
#     PICSAR=1970,
#     IDO1=1971,
#     HOXA5=1972,
#     SGMS1-AS1=1973,
#     ANGPTL4=1974,
#     AC016405.3=1975,
#     LINC81507=1976,
#     NR_003923=1977,
#     Caspase3=1978,
#     RP11-296A18.3=1979,
#     let-7i-5p=1980,
#     MSTO2P=1981,
#     GPC3-AS1=1982,
#     LINC02245=1983,
#     KLF12=1984,
#     SERCA2a=1985,
#     AC012213.3=1986,
#     KLF10=1987,
#     PIK3R1=1988,
#     K17=1989,
#     PFN2=1990,
#     TPI1=1991,
#     MIR451A=1992,
#     PARTICL=1993,
#     NOX1=1994,
#     NLUCAT1=1995,
#     APAF1=1996,
#     TUBB3=1997,
#     MIR15A=1998,
#     S100A10=1999,
#     WWTR1=2000,
#     DUX4=2001,
#     DPP4=2002,
#     miR-122-5p=2003,
#     lncRNA-p3134=2004,
#     SLC7A5=2005,
#     GSK-3beta=2006,
#     miR-506=2007,
#     ADH4=2008,
#     E2F=2009,
#     DLGAP1=2010,
#     TNFRSF10B=2011,
#     TIMP-3=2012,
#     PARP2=2013,
#     EPHA4=2014,
#     HIF1A=2015,
#     miR-1273e=2016,
#     DNMT3A=2017,
#     ENST00000437781.1=2018,
#     NNT-AS1=2019,
#     TGFB2=2020,
#     ARSR=2021,
#     SEMA5A=2022,
#     c-Met=2023,
#     APOC4=2024,
#     CRRL=2025,
#     EPHX1=2026,
#     AC093818.1=2027,
#     TLR3=2028,
#     miR-152=2029,
#     miR-9=2030,
#     TIF1¶¡=2031,
#     miR-30a-5p=2032,
#     DDX23=2033,
#     RN7SK=2034,
#     BHLHE40=2035,
#     MAPK1=2036,
#     LINC01126=2037,
#     CYP1A2=2038,
#     NCK1-DT=2039,
#     SLC2A5=2040,
#     XLOC_006390=2041,
#     miR-100=2042,
#     AF131217.1=2043,
#     SOX18=2044,
#     lncRNA-CTD-2108O9.1=2045,
#     LOC105369748=2046,
#     MIR1-2=2047,
#     AQP7=2048,
#     miR-376b-3p=2049,
#     LINC00210=2050,
#     LINC00665=2051,
#     LOC101927497=2052,
#     SDCBP2-AS1=2053,
#     NCAPH=2054,
#     miR-758-3p=2055,
#     GCAWKR=2056,
#     MMP11=2057,
#     vimentin=2058,
#     DHX9=2059,
#     ephrin A1=2060,
#     CCNA2=2061,
#     MEM=2062,
#     LINC00163=2063,
#     MYLI9=2064,
#     CTNNBIP1=2065,
#     SELL=2066,
#     GAS5-AS1=2067,
#     AP000439.3=2068,
#     CCL18=2069,
#     HHIP-AS1=2070,
#     PCSEAT=2071,
#     PRDM16-DT=2072,
#     LINC00520=2073,
#     miR-432=2074,
#     MED18=2075,
#     miR-149-3p=2076,
#     FAM83H-AS1=2077,
#     NDRG1-ot1=2078,
#     MDC 1.00=2079,
#     E6=2080,
#     MAPK8=2081,
#     miR-125b-2-3p=2082,
#     HEY2=2083,
#     CHAST=2084,
#     GACAT3=2085,
#     XLOC_006277=2086,
#     NR_002794=2087,
#     SYK=2088,
#     FBOX11=2089,
#     EWSAT1=2090,
#     miR-761=2091,
#     ARPP19=2092,
#     AP002754.2=2093,
#     PRAL=2094,
#     BOK=2095,
#     TCF7=2096,
#     ITGA6=2097,
#     RPS6=2098,
#     lncRNA-TTN-AS1=2099,
#     E7=2100,
#     RGS17=2101,
#     LINC01535=2102,
#     BAP1=2103,
#     Linc-smad7=2104,
#     LOC550643=2105,
#     LINC02273=2106,
#     HPDG=2107,
#     MT2A=2108,
#     PKMYT1=2109,
#     TATDN1=2110,
#     CDK4=2111,
#     miR-29b-3p=2112,
#     E-cadherin=2113,
#     SETDB1=2114,
#     circRNA_000543=2115,
#     miR-186-5p=2116,
#     Etk=2117,
#     FTX=2118,
#     PRKCZ-AS1=2119,
#     COPS7A=2120,
#     TLR8=2121,
#     H3K27me3=2122,
#     miR-1297=2123,
#     PXN-AS1=2124,
#     ABHD11-AS1=2125,
#     MIR92B=2126,
#     alpha-SMA=2127,
#     CEMIP=2128,
#     TGFB1=2129,
#     RP11-714G18.1=2130,
#     LINC00997=2131,
#     LOXL2=2132,
#     AIFM1=2133,
#     ACE2=2134,
#     EIF4G1=2135,
#     miR-125b-5p=2136,
#     lncRNA-NUTF2P3-001=2137,
#     G3BP2=2138,
#     UBA52=2139,
#     KNL1=2140,
#     PSTPIP1=2141,
#     NR2F1=2142,
#     LINC00243=2143,
#     AHDC1=2144,
#     DPP10-AS1=2145,
#     RAB3IP=2146,
#     DDX11-AS1=2147,
#     NR4A2=2148,
#     lncATB=2149,
#     CCL5=2150,
#     LINC02620=2151,
#     91H=2152,
#     CANT1=2153,
#     LINC01541=2154,
#     PFKP=2155,
#     TCF12=2156,
#     SAP30-DT=2157,
#     ciRS-7=2158,
#     miR-455-5p=2159,
#     MIR202=2160,
#     LINC00304=2161,
#     ENST00113=2162,
#     ADAMTS9-AS1=2163,
#     SYF2=2164,
#     ERRFI1=2165,
#     GADD45A=2166,
#     GPX4=2167,
#     GFI1=2168,
#     MYB=2169,
#     RAD18=2170,
#     DDX58=2171,
#     RP11-552M11.4=2172,
#     ZNF667-AS1=2173,
#     LINC00400=2174,
#     RBM5-AS1=2175,
#     RHPN1-AS1=2176,
#     SPINT1=2177,
#     ABCA1=2178,
#     CHROMR=2179,
#     miR-432-5p=2180,
#     HOMER3-AS1=2181,
#     NUAK1=2182,
#     NDRG1=2183,
#     FOXD1-AS1=2184,
#     miR-326=2185,
#     FAM30A=2186,
#     SMARCA4=2187,
#     ADAMTS9=2188,
#     miR-497-5p=2189,
#     miR-125b=2190,
#     XIC=2191,
#     GMDS-DT=2192,
#     miR-503=2193,
#     Cyclin D=2194,
#     HOXB-AS1=2195,
#     LINC02525=2196,
#     PDPK1=2197,
#     RING1=2198,
#     CARF=2199,
#     ZBTB7A=2200,
#     KCNQ1=2201,
#     miR-342-3p=2202,
#     ZNFX1=2203,
#     lncRNA-FA2H-2=2204,
#     miR-24-3p=2205,
#     BAD=2206,
#     MIR4440=2207,
#     miR-1227-5p=2208,
#     PTCH1=2209,
#     PRDX5=2210,
#     miR-424-5p=2211,
#     Vimentin=2212,
#     PBOV1=2213,
#     FYN=2214,
#     FAS-AS1=2215,
#     FBXW11=2216,
#     GRASLND=2217,
#     GLO1=2218,
#     WWOX=2219,
#     YBX1=2220,
#     miR-190a-3p=2221,
#     miR-371a-5p=2222,
#     CIP2A=2223,
#     ABC=2224,
#     BRD7=2225,
#     SLC20A1=2226,
#     BM450697=2227,
#     LBX2=2228,
#     YES1=2229,
#     DUSP7=2230,
#     MRPL39=2231,
#     EZR=2232,
#     ATXN7L3=2233,
#     BTG2=2234,
#     SHC1=2235,
#     AKAP9=2236,
#     Nestin=2237,
#     miR-130a-5p=2238,
#     GAS1RR=2239,
#     GIT1=2240,
#     let-7b-5p=2241,
#     SNORD50A=2242,
#     E-Cadherin=2243,
#     MAFG-DT=2244,
#     OTX1=2245,
#     MUC1=2246,
#     PAX5=2247,
#     MIR4319=2248,
#     THBD=2249,
#     LINC01111=2250,
#     miR-30d-5p=2251,
#     SMAD4=2252,
#     MIR140=2253,
#     Snail1/2=2254,
#     ZIC4=2255,
#     ETS1-AS1=2256,
#     miR-21-5p=2257,
#     LINC01638=2258,
#     miR-93=2259,
#     LINC00473=2260,
#     SLBP=2261,
#     loc285194=2262,
#     TSPOAP1-AS1=2263,
#     DHT=2264,
#     MIR1262=2265,
#     LL22NC03-N64E9.1=2266,
#     TRG-AS1=2267,
#     UC.134=2268,
#     LINC01436=2269,
#     NOVA=2270,
#     TFAP4=2271,
#     SNHG14=2272,
#     MTA2=2273,
#     GAS5=2274,
#     desmin=2275,
#     NFIB=2276,
#     PRDM16=2277,
#     SQSTM1=2278,
#     UICLM=2279,
#     Ahit=2280,
#     FER1L4=2281,
#     miR-1-3p=2282,
#     WDR7-7=2283,
#     LOC440173=2284,
#     FGF1=2285,
#     CDT1=2286,
#     ZIC5=2287,
#     LINC00857=2288,
#     ZEB2/CDH2=2289,
#     RP11-436H11.5=2290,
#     TARDBP=2291,
#     TGLC15=2292,
#     INO80=2293,
#     miR-222=2294,
#     TRIM24=2295,
#     DRP1=2296,
#     NRAV=2297,
#     LINC00511=2298,
#     OSER1-DT=2299,
#     COQ8B=2300,
#     GLI3=2301,
#     LINC00426=2302,
#     LINC00184=2303,
#     MAP1LC3B2=2304,
#     TPM1-AS=2305,
#     Leptin=2306,
#     LIFR=2307,
#     HULC=2308,
#     HOXA=2309,
#     DAPK2=2310,
#     PEG3=2311,
#     ZNF407-AS1=2312,
#     SOCS5=2313,
#     TFR4=2314,
#     IDH1-AS1=2315,
#     IL1R1=2316,
#     AC007271.3=2317,
#     lncRNA-AC078883.3=2318,
#     miR-328-5p=2319,
#     CARL=2320,
#     LINC00515=2321,
#     NXF1=2322,
#     miR-103=2323,
#     LINC00355=2324,
#     ENST=2325,
#     miR-200s=2326,
#     TJP1=2327,
#     lncRNA-TM1P3=2328,
#     miR-320=2329,
#     GLI1=2330,
#     ASS1=2331,
#     NUTM2A-AS1=2332,
#     AK056155=2333,
#     AIFM2=2334,
#     miR-502-3p=2335,
#     IGFBP4=2336,
#     HDAC2=2337,
#     N-cadherin=2338,
#     MDR=2339,
#     AGO2=2340,
#     JPX=2341,
#     SETD1A=2342,
#     API5=2343,
#     MTA1=2344,
#     BMF=2345,
#     SETD2=2346,
#     BAZ2B=2347,
#     TOX=2348,
#     TBILA=2349,
#     B3GNT5=2350,
#     WNT=2351,
#     TET3=2352,
#     miR7-5p=2353,
#     Ki67=2354,
#     lncRNA-BCAT1=2355,
#     LINC00689=2356,
#     GPD1L=2357,
#     AY927529=2358,
#     NRP1=2359,
#     MIR181A2HG=2360,
#     TGFbeta1=2361,
#     CASC9-1=2362,
#     HDAC5=2363,
#     LYPD3=2364,
#     miRNA-150=2365,
#     LINC00662=2366,
#     OAS2=2367,
#     PML=2368,
#     miR-145-3p=2369,
#     ZHX1=2370,
#     ACSL4=2371,
#     PPARG=2372,
#     LINC00265=2373,
#     DYRK1A=2374,
#     SLC8A1-AS1=2375,
#     IKBKG=2376,
#     cir-GLI2=2377,
#     ST7-AS1=2378,
#     JAK1=2379,
#     CAMK2N2=2380,
#     PGF=2381,
#     POU4F1=2382,
#     HOXA-AS2=2383,
#     LINC01198=2384,
#     MAP1LC3B=2385,
#     MST1P2=2386,
#     ATG12=2387,
#     LNCRNA-ATB=2388,
#     IL1RAP=2389,
#     EPAS1=2390,
#     FOXC2=2391,
#     TXNIP=2392,
#     TNFRSF21=2393,
#     PODXL=2394,
#     miR-153-3p=2395,
#     PBB12=2396,
#     OTUB1=2397,
#     miR©\222=2398,
#     NFKB1=2399,
#     MIR4516=2400,
#     HOXB2=2401,
#     JP2=2402,
#     TFAP2A-AS1=2403,
#     HEY1=2404,
#     PTCSC1=2405,
#     MLL1=2406,
#     MIR1281=2407,
#     LINC00423=2408,
#     GHR=2409,
#     MIR29C=2410,
#     DLEU2=2411,
#     IGFBP5=2412,
#     miR-338-3p=2413,
#     MIR486-1=2414,
#     PRINS=2415,
#     snaR=2416,
#     LINC01139=2417,
#     miR-196=2418,
#     BC050642=2419,
#     PRKD3=2420,
#     DKC1=2421,
#     TOB1=2422,
#     LASP1=2423,
#     NAIP=2424,
#     CDR1-AS=2425,
#     NKD2=2426,
#     JDP2=2427,
#     FERMT3=2428,
#     HNRNPK=2429,
#     CCN5=2430,
#     miR-329-3p=2431,
#     NMRAL2P=2432,
#     VCAN=2433,
#     CDK5R1=2434,
#     MTOR=2435,
#     DUXAP8=2436,
#     MIR148A=2437,
#     MAP3K11=2438,
#     LINC00467=2439,
#     MIR483=2440,
#     ARID1A=2441,
#     IL6R=2442,
#     miR-16-1-3p=2443,
#     MIR155HG=2444,
#     LINC02465=2445,
#     LNRRIL6=2446,
#     lincNMR=2447,
#     ICMT-DT=2448,
#     LAST1/2=2449,
#     LINC00668=2450,
#     lncRNA-PAICC=2451,
#     miR-145=2452,
#     FGF14-AS2=2453,
#     MIR718=2454,
#     DROSHA=2455,
#     HNF4A=2456,
#     BMP4=2457,
#     p-ERBB3=2458,
#     CDH4=2459,
#     ZBTB4=2460,
#     LINC00961=2461,
#     SHCBP1=2462,
#     IL2=2463,
#     MMP3=2464,
#     OPG=2465,
#     LINC00842=2466,
#     LATS2-AS1-001=2467,
#     miR-126-5p=2468,
#     FAM83A=2469,
#     GAS8=2470,
#     GAS1=2471,
#     BUB1=2472,
#     LIN28B=2473,
#     NLRC5=2474,
#     PDCD4-AS1=2475,
#     LDLR=2476,
#     ADAMTS1=2477,
#     PSTAR=2478,
#     DLGAP1-AS1=2479,
#     TP53INP1=2480,
#     RABL3=2481,
#     CNR2=2482,
#     SLC7A11=2483,
#     miR-129-5p=2484,
#     miR-33a=2485,
#     MCTP1-AS1=2486,
#     lnc-ELF209=2487,
#     miR-146-a=2488,
#     ANO1=2489,
#     miR-873-5p=2490,
#     CDC42=2491,
#     PVT1-214=2492,
#     miR-135a=2493,
#     MIR208A=2494,
#     BIRC3=2495,
#     MIR22HG=2496,
#     DQ786243=2497,
#     LOC90784=2498,
#     miR-300=2499,
#     p-p38MAPK=2500,
#     PILRLS=2501,
#     EBV-miR-BART6-3p=2502,
#     LINC00336=2503,
#     HEYL=2504,
#     Olfr29-ps1=2505,
#     AR=2506,
#     LINC01672=2507,
#     lncRNA-ECM=2508,
#     RCC2-AS1=2509,
#     SCIRT=2510,
#     CTBP1-DT=2511,
#     PCAT29=2512,
#     STK3=2513,
#     RTKN=2514,
#     miR-223=2515,
#     CPS1=2516,
#     MARK4=2517,
#     MIR4288=2518,
#     miR-488-5p=2519,
#     RASAL1=2520,
#     GATA3-AS1=2521,
#     GRB2=2522,
#     RECK=2523,
#     MKI67=2524,
#     NCOR2=2525,
#     DRAM1=2526,
#     GDH1=2527,
#     RPL13AP20=2528,
#     SSTR5-AS1=2529,
#     DTX3=2530,
#     PLEKHM1=2531,
#     LINC01554=2532,
#     14-3-3beta=2533,
#     TIMM8A=2534,
#     AT1R=2535,
#     E2F5=2536,
#     MTSS1=2537,
#     PLP2=2538,
#     KCNH1=2539,
#     GPAM=2540,
#     ALPK1=2541,
#     miR-365=2542,
#     PSG10P=2543,
#     LINC00173.v1=2544,
#     miR-302d-3p=2545,
#     LINC01013=2546,
#     AB209371=2547,
#     VEGFC=2548,
#     IL22RA1=2549,
#     MIR145=2550,
#     EPCAM=2551,
#     TET1=2552,
#     BCYRN1=2553,
#     ANGPT2=2554,
#     FGF2=2555,
#     ATG4D=2556,
#     LINC00847=2557,
#     TRIM52-AS1=2558,
#     MFAP2=2559,
#     PIK3CD=2560,
#     HSF2=2561,
#     HDAC3=2562,
#     DUSP6=2563,
#     IGF2BPs=2564,
#     TACR1=2565,
#     miR-593-5p=2566,
#     AC114812.8=2567,
#     VASH1=2568,
#     FAM66C=2569,
#     OR3A4P=2570,
#     HOTTIP=2571,
#     SNHG8=2572,
#     UNC5B-AS1=2573,
#     ABCC3=2574,
#     MIR5702=2575,
#     LINC01567=2576,
#     WTAP=2577,
#     UBA6=2578,
#     LEF-AS1=2579,
#     alpha-synuclein=2580,
#     RAMP2-AS1=2581,
#     DHX33=2582,
#     miR-545-5p=2583,
#     MMP7=2584,
#     EFNA1=2585,
#     KCTD20=2586,
#     CRKL=2587,
#     Moshe=2588,
#     RB1=2589,
#     MDRL=2590,
#     XLOC_001659=2591,
#     ADGRL2=2592,
#     TRIM16=2593,
#     CYC1=2594,
#     SNHG6-003=2595,
#     SMAD7=2596,
#     ARHGAP11A=2597,
#     FUT8=2598,
#     MIR760=2599,
#     MAFG=2600,
#     miR-155-3p=2601,
#     CD36=2602,
#     SOX9=2603,
#     CALML3-AS1=2604,
#     VIM-AS3=2605,
#     PHOX2A=2606,
#     DDIT3=2607,
#     AK002210=2608,
#     MIR146B=2609,
#     PNCK=2610,
#     HNRNPF=2611,
#     PCED1B-AS1=2612,
#     CCND1=2613,
#     TCF7L2=2614,
#     SOX4=2615,
#     CFL2=2616,
#     CAMTA1-DT=2617,
#     CDX2=2618,
#     AFAP1-AS1=2619,
#     CCNJ=2620,
#     PHLPP2=2621,
#     IATPR=2622,
#     IRAK1=2623,
#     RBL2=2624,
#     ARF6=2625,
#     ID2=2626,
#     ATG9B=2627,
#     miR-339-5p=2628,
#     CHAR=2629,
#     p-eNOS=2630,
#     MYH9=2631,
#     NUPR1=2632,
#     DLX6-AS1=2633,
#     KDM6A=2634,
#     HNF1A=2635,
#     AZIN2-sv=2636,
#     RP11-670E13.6=2637,
#     miR-15a-5p=2638,
#     EREG=2639,
#     MYRF=2640,
#     LncHrt=2641,
#     HDAC11=2642,
#     miR-233-3p=2643,
#     miR-193b-3p=2644,
#     MINCR=2645,
#     MaTAR25=2646,
#     miR-202-5p=2647,
#     CNN1=2648,
#     PCNAP1=2649,
#     LINC00160=2650,
#     MIR10B=2651,
#     CUL4B=2652,
#     E2F8=2653,
#     miR-135b-5p=2654,
#     CTC=2655,
#     PDK2=2656,
#     NNMT=2657,
#     DDX54=2658,
#     MIR600HG=2659,
#     FOXR2=2660,
#     LINC00114=2661,
#     PVT1=2662,
#     CCDC26=2663,
#     G3BP1=2664,
#     BRE-AS1=2665,
#     miR-182=2666,
#     WWTR1-AS1=2667,
#     TIMP2=2668,
#     SOX6=2669,
#     AC009084.3=2670,
#     PTPN6=2671,
#     MIR206=2672,
#     Lnc-ATG9B-4=2673,
#     LINC00466=2674,
#     AC123023.1=2675,
#     p-mTOR=2676,
#     MARCKS=2677,
#     HAS2-AS1=2678,
#     N-BLR=2679,
#     miR-153=2680,
#     miR-185-5=2681,
#     ARFRP1=2682,
#     LINC00485=2683,
#     Siglec-15=2684,
#     RALY=2685,
#     WWC2-AS1=2686,
#     SERPINH1=2687,
#     MAP4K3=2688,
#     MYCN=2689,
#     NUF2=2690,
#     B4GALT1-AS1=2691,
#     MBNL1-AS1=2692,
#     DCAF11=2693,
#     IQGAP3=2694,
#     circGFRA1=2695,
#     DANCR=2696,
#     HIT000218960=2697,
#     LNMICC=2698,
#     FAIM2=2699,
#     SYNJ1=2700,
#     ITCH=2701,
#     KRT19=2702,
#     COX2=2703,
#     ER¶¬=2704,
#     CLDN7=2705,
#     MIR573=2706,
#     ELL2=2707,
#     QKI-5=2708,
#     UBE2I=2709,
#     HOXA3=2710,
#     MIR708=2711,
#     CALM2=2712,
#     HIPK2=2713,
#     WDR18=2714,
#     IL6=2715,
#     LGALS1=2716,
#     PRNCR1=2717,
#     PRDX1=2718,
#     LINC01096=2719,
#     HOXA10=2720,
#     lnc-GNAT1-1=2721,
#     miR-503-5p=2722,
#     NPR 3.00=2723,
#     TRAF4=2724,
#     TEX41=2725,
#     MMP2=2726,
#     BPTF=2727,
#     PPP2CA=2728,
#     LINC01714=2729,
#     miR-105-5p=2730,
#     LINC00319=2731,
#     PRMT5=2732,
#     CST7=2733,
#     SIRT1-AS=2734,
#     AK097647=2735,
#     KRT19P3=2736,
#     FSCN1=2737,
#     WNT3=2738,
#     SOD2-OT1=2739,
#     TNFSF10=2740,
#     miR-142=2741,
#     miR-107=2742,
#     FOXO6=2743,
#     miR-181b=2744,
#     HSPA5=2745,
#     WNT4=2746,
#     SMURF1=2747,
#     SUZ12=2748,
#     NUDT19=2749,
#     RPSAP52=2750,
#     CPT1=2751,
#     ILF3=2752,
#     miR-139-5p=2753,
#     IRF4=2754,
#     COMMD3-BMI1=2755,
#     YAP/TAZ-TEADcomplex=2756,
#     ALKBH5=2757,
#     OIS1=2758,
#     MUC2=2759,
#     KTN1-AS1=2760,
#     MIR328=2761,
#     MIR1258=2762,
#     CACNA1G-AS1=2763,
#     CRCMSL=2764,
#     LINC00852=2765,
#     SRGN=2766,
#     BUB1B=2767,
#     RP11-79H23.3=2768,
#     SLC2A1-DT=2769,
#     GDF15=2770,
#     MGAT3-AS1=2771,
#     ATM=2772,
#     AKAP12=2773,
#     MMP14=2774,
#     TCF21=2775,
#     CD276=2776,
#     SLCO4A1=2777,
#     GRN=2778,
#     WNT7B=2779,
#     miR-519a=2780,
#     CDKN2C=2781,
#     MECP2=2782,
#     DONSON=2783,
#     lncRNA1403=2784,
#     CHEK1=2785,
#     H23=2786,
#     miR-545=2787,
#     ABCB1=2788,
# ...
#     TATDN3=2993,
#     NET1=2994,
#     HNRNPU=2995,
#     KIMAT1=2996,
#     HIF1A-AS4=2997,
#     UHRF1=2998,
#     ZBTB16=2999,
#     MRPS18A=3000,
#     THAP7-AS1=3001,
#     miR-544a=3002,
#     KAT2B=3003,
#     FOXCUT=3004,
#     HANR=3005,
#     PRKAR1B-AS2=3006,
#     CXCL8=3007,
#     c-MET=3008,
#     PREX2=3009,
#     REXO2=3010,
#     GASAL1=3011,
#     DACOR1=3012,
#     NPM1c+=3013,
#     TGFBI=3014,
#     ESR2=3015,
#     miR-26b=3016,
#     NLRP3=3017,
#     GNAS=3018,
#     RP11-317J10.2=3019,
#     SLNCR1=3020,
#     JUN=3021,
#     lncWDR59=3022,
#     RORA=3023,
#     PDE5A=3024,
#     RFX7=3025,
#     LOC100506178=3026,
#     RIPK3=3027,
#     MACC1-AS1=3028,
#     HNF4G=3029,
#     SMAD6=3030,
#     miR-211-5p=3031,
#     ELF1=3032,
#     HOXB7=3033,
#     MTBP=3034,
#     HSP90AA1=3035,
#     MAP3K2=3036,
#     LCAL1=3037,
#     TUB=3038,
#     SNHG1=3039,
#     SMN1=3040,
#     miR-223-3P=3041,
#     MALINC1=3042,
#     LINC00313=3043,
#     LAMB3=3044,
#     RP5-1120P11.3=3045,
#     PXN=3046,
#     SYNE3=3047,
#     LINC01118=3048,
#     YWHAH=3049,
#     miR-92a=3050,
#     LINC00240=3051,
#     NF1=3052,
#     SFPQ=3053,
#     GALNT8=3054,
#     miR-33a-5p=3055,
#     ZNF277=3056,
#     miR-301a=3057,
#     miR-23a=3058,
#     p70S6K1=3059,
#     VPS9D1-AS1=3060,
#     PLK1=3061,
#     APC=3062,
#     USP47=3063,
#     THORLNC=3064,
#     PUM2=3065,
#     miR-3667-3p=3066,
#     TRIM32=3067,
#     PUM1=3068,
#     GAPDH=3069,
#     AATBC=3070,
#     LINC00629=3071,
#     kcna3=3072,
#     LC3I=3073,
#     PAN RNA=3074,
#     TGFbetaI=3075,
#     DLK1=3076,
#     HOXC-AS3=3077,
#     IRS2=3078,
#     BCR-ABL=3079,
#     PHGDH=3080,
#     UBE3A=3081,
#     LINC01410=3082,
#     LOC105372579=3083,
#     TRF2=3084,
#     SIAH1=3085,
#     MIR544A=3086,
#     LNMAT2=3087,
#     ACOT7=3088,
#     MAP3K7=3089,
#     SIK2=3090,
#     WSPAR=3091,
#     LINC01170=3092,
#     F11-AS1=3093,
#     CUEDC2=3094,
#     NDUFA4=3095,
#     ALDH1A1=3096,
#     ARL 2.00=3097,
#     NR_023387=3098,
#     ADIPOQ=3099,
#     ROR2=3100,
#     MIR425=3101,
#     PGM5-AS1=3102,
#     miR-217-5p=3103,
#     KRAS=3104,
#     MIR365A=3105,
#     RP11-543N12.1=3106,
#     HCP5=3107,
#     T-ERK=3108,
#     RAI14=3109,
#     PRKCE=3110,
#     HK2P1=3111,
#     NOC2L-4.1=3112,
#     EMSY=3113,
#     SLC25A15=3114,
#     ZIC2=3115,
#     CASP3=3116,
#     HAS2=3117,
#     STIM1=3118,
#     SPAAR=3119,
#     TSIX=3120,
#     OLR1=3121,
#     miR-98-5p=3122,
#     MTHFR=3123,
#     CCT4=3124,
#     EIF4E-BP1=3125,
#     LINC01093=3126,
#     KIT=3127,
#     RAP2A=3128,
#     ANXA11=3129,
#     miR-148b-3p=3130,
#     MYCNOS=3131,
#     miR-122=3132,
#     LINC01606=3133,
#     MIR29B2CHG=3134,
#     NPM1=3135,
#     miR-204=3136,
#     PTGS2=3137,
#     KDM5B=3138,
#     MIR543=3139,
#     A1BG-AS1=3140,
#     RAP1B=3141,
#     ANKRD40CL=3142,
#     hsa-miR21-5p=3143,
#     GSEC=3144,
#     NRAS=3145,
#     RP11-301G19.1=3146,
#     HRAS=3147,
#     miR-199a-3p=3148,
#     DBN1=3149,
#     lnc-TSI=3150,
#     DUBR=3151,
#     KRT7=3152,
#     Clecaspase-3=3153,
#     C1QTNF3=3154,
#     KMT5A=3155,
#     INHBA=3156,
#     NTT=3157,
#     miR-362-5p=3158,
#     miR-199b-5p=3159,
#     CBX4=3160,
#     FGD5=3161,
#     LINC02418=3162,
#     BABAM2=3163,
#     KDM4A-AS1=3164,
#     DPYD=3165,
#     SEMA4C=3166,
#     CDC6=3167,
#     LINC01426=3168,
#     MSX2P1=3169,
#     OXCT1-AS1=3170,
#     linc-DYNC2H1-4=3171,
#     KLF14=3172,
#     miR-675-5p=3173,
#     IL4I1=3174,
#     TRIM44=3175,
#     PRKCQ-AS1=3176,
#     EPS8=3177,
#     miR-130b-3p=3178,
#     SMAD2=3179,
#     MMP1=3180,
#     NMU=3181,
#     MIR340=3182,
#     MRPL36=3183,
#     ROR¶√t=3184,
#     TATDN2=3185,
#     Cyclin E=3186,
#     PRUNE2=3187,
#     GSTM1=3188,
#     MAP3K1=3189,
#     RPS6KB1=3190,
#     RP11-732M18.3=3191,
#     GAS6=3192,
#     ZBTB20=3193,
#     MIR15B=3194,
#     FLNB=3195,
#     MIR183=3196,
#     CXCL10=3197,
#     HOTAIR=3198,
#     AB073614=3199,
#     MCM4=3200,
#     ELF3-AS1=3201,
#     FASN=3202,
#     miR-27b=3203,
#     EYA1=3204,
#     miR-106=3205,
#     WNK2=3206,
#     miR-22-3p=3207,
#     PICART1=3208,
#     SMAD3=3209,
#     Nrf2=3210,
#     miR-22=3211,
#     LINC01128=3212,
#     TPT1-AS1=3213,
#     BBC3=3214,
#     VDAC1=3215,
#     STYX=3216,
#     MIR592=3217,
#     ALG9=3218,
#     NT5E=3219,
#     hsa-miR-582-5p=3220,
#     LINC00173=3221,
#     RP11-468E2.5=3222,
#     SYVN1=3223,
#     WNT7A=3224,
#     GAB2=3225,
#     NFkB=3226,
#     lncHERG=3227,
#     USP44=3228,
#     Lnc-HZ08=3229,
#     USP9X=3230,
#     ACACA=3231,
#     CDKN1C=3232,
#     ATP8B=3233,
#     miR-506-3p=3234,
#     LINC01094=3235,
#     ARHGDIA=3236,
#     C2dat1=3237,
#     DLEU1-AS1=3238,
#     P4HA2=3239,
#     HILPDA=3240,
#     HCCL5=3241,
#     NPCCAT1=3242,
#     miR-330-3p=3243,
#     RFX1=3244,
#     COL6A1=3245,
#     miR<U+2011>155=3246,
#     TUSC2=3247,
#     Chaer=3248,
#     SP7=3249,
#     SKIL=3250,
#     TEAD1=3251,
#     CDKN1B=3252,
#     COL1A2-AS1=3253,
#     KPNA2=3254,
#     ITGB3=3255,
#     miR-524-5p=3256,
#     HMMR-AS1=3257,
#     FGF12-AS2=3258,
#     miR-19a=3259,
#     miR-125a-3p=3260,
#     NOTCH3=3261,
#     p120-catenin=3262,
#     ADAMTS5=3263,
#     HES1=3264,
#     CDH1=3265,
#     CRAL=3266,
#     AXL=3267,
#     miR-331-3p=3268,
#     IRF7=3269,
#     HIF1A-AS3=3270,
#     WDR5=3271,
#     MMP19=3272,
#     IFI6=3273,
#     SPINT1-AS1=3274,
#     PDHB=3275,
#     ITGA5=3276,
#     CCNL1=3277,
#     RREB1=3278,
#     MMP2/9/12=3279,
#     LINC01510=3280,
#     SDPR-AS=3281,
#     AKT3=3282,
#     FAS=3283,
#     GAU1=3284,
#     NR4A1AS=3285,
#     SGMS2=3286,
#     RTCB=3287,
#     SOCS1=3288,
#     LINC00092=3289,
#     EP300=3290,
#     CCR1=3291,
#     CLRN1-AS1=3292,
#     lnc-DILC=3293,
#     WNT1=3294,
#     HAND2=3295,
#     PEAK1=3296,
#     CFAP45=3297,
#     MIR146A=3298,
#     MIR377=3299,
#     TTR=3300,
#     EPHA7=3301,
#     glutaminase=3302,
#     FUBP1=3303,
#     XIXT=3304,
#     MIR367=3305,
#     miR-6754-5p=3306,
#     miR-424=3307,
#     HOXB3=3308,
#     AV310809=3309,
#     LncND=3310,
#     BZW1=3311,
#     H2AX=3312,
#     MIR124-1HG=3313,
#     XIAP-AS1=3314,
#     DUXAP10=3315,
#     ANGPTL3=3316,
#     TNRC6A=3317,
#     SF1=3318,
#     STARD13-AS=3319,
#     TIGIT=3320,
#     RTL1=3321,
#     miR-410=3322,
#     ZEB2-AS1=3323,
#     CEACAM5=3324,
#     OASL=3325,
#     SPARC=3326,
#     KIF14=3327,
#     PVTL5=3328,
#     miR-547-5p=3329,
#     HMGA1=3330,
#     AMOT=3331,
#     GHET1=3332,
#     ODC1=3333,
#     TRAF3IP2=3334,
#     MIR4465=3335,
#     ZFAS1=3336,
#     APOBEC3G=3337,
#     Cyclin B1=3338,
#     miR-494=3339,
#     PCDHGA9=3340,
#     HES5=3341,
#     SMIM45=3342,
#     ZMYND8=3343,
#     OLFM4=3344,
#     miR-214-5p=3345,
#     miR-215=3346,
#     MCM2=3347,
#     WIPF2=3348,
#     WNT2=3349,
#     NCK-AS1=3350,
#     NRIR=3351,
#     TM9SF2=3352,
#     SAPCD2=3353,
#     SNHG11=3354,
#     ITGB4=3355,
#     ABCB4=3356,
#     MIR222HG=3357,
#     TP63=3358,
#     TLR4=3359,
#     COMETT=3360,
#     CREBBP=3361,
#     let-7family=3362,
#     LINC00899=3363,
#     SATB2=3364,
#     FOXP3=3365,
#     miR-130=3366,
#     CCL11=3367,
#     LINC00526=3368,
#     p38=3369,
#     miR-324-5p=3370,
#     AC003092.1=3371,
#     HIF3A=3372,
#     TRPC3=3373,
#     ID3=3374,
#     PTMA=3375,
#     LOC401317=3376,
#     PHLDA1=3377,
#     BACE2=3378,
#     AKR1B10=3379,
#     ZNF143=3380,
#     MMP16=3381,
#     HIF2PUT=3382,
#     CTNNB1=3383,
#     miR<U+2011>140<U+2011>5p=3384,
#     MIR3936HG=3385,
#     miR-218=3386,
#     MMP9=3387,
#     miR-627-3p=3388,
#     miR-454-3p=3389,
#     METTL3=3390,
#     CTLA4=3391,
#     LINC-01572:28=3392,
#     lncRNA SRA=3393,
#     miR-188-5p=3394,
#     DKK 2.00=3395,
#     MELTF-AS1=3396,
#     SGK1=3397,
#     MDK=3398,
#     ST7L=3399,
#     CLDN11=3400,
#     STXBP5-AS1=3401,
#     FOXP1=3402,
#     PROM1=3403,
#     RRAS=3404,
#     DNM3OS=3405,
#     VEGFA=3406,
#     HNRNPL=3407,
#     MIR100HG=3408,
#     CYLD=3409,
#     TLX3=3410,
#     GRIN2A=3411,
#     EPIC1=3412,
#     RGMB-AS1=3413,
#     CCN2=3414,
#     HNRNPA2B1=3415,
#     APEX1=3416,
#     SRCIN1=3417,
#     AK094457=3418,
#     GSK3B=3419,
#     miR-625-5p=3420,
#     lncRNA-6195=3421,
#     PDCD1LG2=3422,
#     Lnc-STYK1-2=3423,
#     MIR1275=3424,
#     MAARS=3425,
#     CARD11=3426,
#     LINC01391=3427,
#     mXIAP=3428,
#     TBX4=3429,
#     HLA-F-AS1=3430,
#     ATF2=3431,
#     KLF5=3432,
#     FOXK1=3433,
#     ROCK1=3434,
#     miR-216b=3435,
#     PRKAA1=3436,
#     AK136714=3437,
#     CD164=3438,
#     Caspase10=3439,
#     MAT2A=3440,
#     CXCL12=3441,
#     ZFHX4-AS1=3442,
#     miR-345-3p=3443,
#     LOC146880=3444,
#     HOXA7=3445,
#     LINC00599=3446,
#     PITPNA-AS1=3447,
#     DDA1=3448,
#     WNT5B=3449,
#     EBF1=3450,
#     FKBP5=3451,
#     EWSR1=3452,
#     CLDN8=3453,
#     IL1B=3454,
#     LZTS1=3455,
#     TOP2A=3456,
#     LINC00242=3457,
#     LATS2=3458,
#     RBM38=3459,
#     PTCSC3=3460,
#     CBX7=3461,
#     MAP3K3=3462,
#     miR-29a=3463,
#     YAP2=3464,
#     FIRRE=3465,
#     miR-1224-5p=3466,
#     SDAD1=3467,
#     COPS5=3468,
#     KCNN4=3469,
#     KLF16=3470,
#     MBTD1=3471,
#     SMAD5=3472,
#     LINC01048=3473,
#     CDH2=3474,
#     SOX3=3475,
#     ATP2B1-AS1=3476,
#     CP=3477,
#     TGFBR2=3478,
#     EIF6=3479,
#     IL22=3480,
#     FGF7=3481,
#     Caspase7=3482,
#     PAPPA=3483,
#     GABPB1-AS1=3484,
#     miR-497=3485,
#     RSF1=3486,
#     CASC9=3487,
#     ADAMTs=3488,
#     CUL4A=3489,
#     PDIA3P1=3490,
#     FOXP4-AS=3491,
#     FGF19=3492,
#     EPDR1=3493,
#     ID1=3494,
#     IP6K2=3495,
#     HOXA11=3496,
#     miR-323a-3p=3497,
#     THAP9-AS1=3498,
#     TERF2=3499,
#     LINC01050=3500,
#     NORAD=3501,
#     PTPRG-AS1=3502,
#     AC078922.1=3503,
#     BCAM=3504,
#     GCN5=3505,
#     LINC01224=3506,
#     ABCC1=3507,
#     RP5-833A20.1=3508,
#     miR-147=3509,
#     RPL4=3510,
#     Trim23-PES1=3511,
#     CBP=3512,
#     IL1R1-AS1=3513,
#     CTBP1-AS=3514,
#     PPM1E=3515,
#     miR-770-5p=3516,
#     PTEN=3517,
#     GLS2=3518,
#     DBH-AS1=3519,
#     RGMB=3520,
#     MIA2=3521,
#     miR-34a-5p=3522,
#     miR-508-3p=3523,
#     PDPK2P=3524,
#     miR-199b=3525,
#     miR-135a-5p=3526,
#     FRS2=3527,
#     HNRNPUL2=3528,
#     miR-138-5p=3529,
#     CLU=3530,
#     HOXA1=3531,
#     CCAR2=3532,
#     RBMS3-AS3=3533,
#     BBOX1-AS1=3534,
#     TNXB=3535,
#     LncIHAT=3536,
#     FUBP3=3537,
#     CHI3L1=3538,
#     mCASP3=3539,
#     miR-30c=3540,
#     RBM5=3541,
#     Endophilin-1=3542,
#     GHRL=3543,
#     ATOH8=3544,
#     SEMA4D=3545,
#     FAM225A=3546,
#     Notch=3547,
#     miR-216a-5p=3548,
#     miR-193b=3549,
#     CPEB2=3550,
#     LPCAT1=3551,
#     EPHB6=3552,
#     KEAP1=3553,
#     FAM224A=3554,
#     miR-143=3555,
#     ITGB8=3556,
#     VIM=3557,
#     GPC3=3558,
#     LRIG1=3559,
#     SNAI3-AS1=3560,
#     lncRNA©\ATB=3561,
#     MRPL28=3562,
#     DNAJB9=3563,
#     TP53BP2=3564,
#     LINC00645=3565,
#     MEF2D=3566,
#     MNX1-AS1=3567,
#     BACH1=3568,
#     SPAG9=3569,
#     BCLAF1=3570,
#     LOC101930370=3571,
#     POU5F1=3572,
#     H22954=3573,
#     miR-106b=3574,
#     SALL4=3575,
#     LINC02349=3576,
#     HOXB-AS3=3577,
#     PYCARD-AS1=3578,
#     LNCARSR=3579,
#     miR-5059=3580,
#     EBF3-AS=3581,
#     DRHC=3582,
#     miR-216a=3583,
#     SMAD5-AS1=3584,
#     RP11-820=3585,
#     SSRP1=3586,
#     MIF-AS1=3587,
#     CDK1=3588,
#     FAT1=3589,
#     TNK2-AS1=3590,
#     WNT5A=3591,
#     SOX2=3592,
#     DMTF1=3593,
#     DRD1=3594,
#     LINC01225=3595,
#     HOMER3=3596,
#     IFN¶√=3597,
#     LINC00311=3598,
#     DUXAP9=3599,
#     EEF2K=3600,
#     LINC00702=3601,
#     UCA1=3602,
#     DCTN6=3603,
#     MST1=3604,
#     LOC134466=3605,
#     NIFK-AS1=3606,
#     H19=3607,
#     TNFSF14=3608,
#     BCAT1=3609,
#     S100A4=3610,
#     PCGEM1=3611,
#     CADM1=3612,
#     SCAI=3613,
#     PTP4A1=3614,
#     PHF14=3615,
#     SUMO1P4=3616,
#     SP1=3617,
#     EMX2OS=3618,
#     HIC1=3619,
#     LINC00968=3620,
#     lnc-MMP2-2=3621,
#     CTC-497E21.4=3622,
#     F10=3623,
#     GARS1=3624,
#     ID2-AS1=3625,
#     VPS13B-DT=3626,
#     miR-206=3627,
#     EYA2=3628,
#     UBE2C=3629,
#     EIF4G2=3630,
#     LINC00641=3631,
#     ICAM1=3632,
#     GDNF=3633,
#     ERP44=3634,
#     AC005592.2=3635,
#     TRDMT1=3636,
#     LINC00682=3637,
#     FBXL3=3638,
#     PCBP2-OT1=3639,
#     miR-375=3640,
#     WNT10B=3641,
#     MRTFA=3642,
#     SEC11A=3643,
#     KHSRP=3644,
#     ELDR=3645,
#     MTA2TR=3646,
#     AK131850=3647,
#     miR-212-3p=3648,
#     miR-27b-3p=3649,
#     KANK1=3650,
#     RND3=3651,
#     FUT4=3652,
#     SIX4=3653,
#     THCYTX=3654,
#     SOX12=3655,
#     OVAAL=3656,
#     CCAT1=3657,
#     RP11-169D4.1=3658,
#     PDGFRB=3659,
#     MCM5=3660,
#     ALMS1-IT1=3661,
#     CAV1=3662,
#     MT1DP=3663,
#     LncRNA-SARCC=3664,
#     SIRT6=3665,
#     FALEC=3666,
#     miR-29c=3667,
#     PI3K-110alpha=3668,
#     PIM1=3669,
#     HOXC4=3670,
#     MIR149=3671,
#     1700020I14Rik=3672,
#     MYBL2=3673,
#     ZNF281=3674,
#     Wnt/beta-catenin=3675,
#     SLC25A5-AS1=3676,
#     OECC=3677,
#     ZNF750=3678,
#     JAM2=3679,
#     ZIC1=3680,
#     SLC2A3=3681,
#     MRPL23-AS0=3682,
#     miR-23b=3683,
#     LOC441178=3684,
#     ASLNCS5088=3685,
#     miR-196a=3686,
#     HAR1A=3687,
#     CDK2=3688,
#     GAB1=3689,
#     HES2=3690,
#     HNF1A-AS1=3691,
#     NCALD=3692,
#     TRIB3=3693,
#     miRNA-188-5p=3694,
#     RP1-86C11.7=3695,
#     HOXA-AS3=3696,
#     HES6=3697,
#     lnc-HSD17B11-1:1=3698,
#     MHRT=3699,
#     CCN4=3700,
#     TOP-FLASH=3701,
#     miR-127-5p=3702,
#     BRAF=3703,
#     ZFAT-AS1=3704,
#     RASSF6=3705,
#     TMEM75=3706,
#     MYC=3707,
#     RP1=3708,
#     NRP2=3709,
#     TSPAN3=3710,
#     KLK4=3711,
#     SIVA1=3712,
#     H2AFY=3713,
#     RAP1A=3714,
#     CXCR1=3715,
#     TUSC8=3716,
#     alpha-1 type I collagen=3717,
#     ABCG1=3718,
#     ANXA3=3719,
#     miR-150-5p=3720,
#     MIB1=3721,
#     miR-140=3722,
#     ADAM10=3723,
#     miR-31=3724,
#     SOX17=3725,
#     CEBPB=3726,
#     GPRC5A=3727,
#     PRR12=3728,
#     miR-556-3p=3729,
#     ANPEP=3730,
#     ZNRF2=3731,
#     PPP1R1B=3732,
#     TMEM18-DT=3733,
#     miR-376c-3p=3734,
#     ATF1=3735,
#     FZD1=3736,
#     MIR939=3737,
#     HIF1A-AS2=3738,
#     NAP1L1=3739,
#     HCG18=3740,
#     VMA21=3741,
#     KDM3A=3742,
#     NONHSAT105177=3743,
#     miR-191=3744,
#     miR-515-5p=3745,
#     ATG9A=3746,
#     CDK5=3747,
#     OGG1=3748,
#     MIR2052HG=3749,
#     ZFPM2-AS1=3750,
#     ¶§Np63¶¡=3751,
#     LINC00052=3752,
#     RHOB=3753,
#     lncRNA-IFI6=3754,
#     LOX=3755,
#     miR-143-3p=3756,
#     miR-329=3757,
#     MT1F=3758,
#     ITGA11=3759,
#     CERS6=3760,
#     LINC00673-v4=3761,
#     IGF1R=3762,
#     MIR363=3763,
#     ATB=3764,
#     CDK9=3765,
#     EPB41L4A-DT=3766,
#     SNHG9=3767,
#     HOXB8=3768,
#     miR-133=3769,
#     SUSD2=3770,
#     PPARGC1A=3771,
#     TCONS_00023297=3772,
#     RPL13AP23=3773,
#     SLC1A5=3774,
#     CAMK1D=3775,
#     ZEB1=3776,
#     EN2=3777,
#     LINC00491=3778,
#     RP5-916L7.2=3779,
#     BMPR1B=3780,
#     UFC1=3781,
#     PDX1=3782,
#     PRB=3783,
#     miR-199a=3784,
#     14-3-3alpha=3785,
#     CCL2=3786,
#     VEGE-C=3787,
#     MKLN1<U+2011>AS=3788,
#     XRN2=3789,
#     HDAC9=3790,
#     SUMO1P5=3791,
#     COL6A3=3792,
#     SALL1=3793,
#     CCDC144NL-AS1=3794,
#     HOXA10-AS=3795,
#     ACTG2=3796,
#     LINC00205=3797,
#     miR-181=3798,
#     CBR3-AS1=3799,
#     ZEB2=3800,
#     ROBO1=3801,
#     MIR641=3802,
#     HCG22=3803,
#     DNAJC3=3804,
#     H1-2=3805,
#     CCN1=3806,
#     CCT6A=3807,
#     LUCAT1=3808,
#     CDK19=3809,
#     LAPAS1=3810,
#     Neuropilin-1=3811,
#     LINC00994=3812,
#     STMN1=3813,
#     PI3K=3814,
#     TAF15=3815,
#     ITGB1=3816,
#     TAZ=3817,
#     DGUOK-AS1=3818,
#     MAP4K1=3819,
#     FTMT=3820,
#     AXIN2=3821,
#     CHSY1=3822,
#     MIR34A=3823,
#     NR4A3=3824,
#     ROR1-AS1=3825,
#     FOXP4=3826,
#     BRMS1=3827,
#     SLC6A4=3828,
#     miR-219a-5p=3829,
#     LINC01929=3830,
#     miR-219-1=3831,
#     CCNA1=3832,
#     miR-136=3833,
#     PAX8=3834,
#     P5848=3835,
#     ELF2=3836,
#     LINC-PINT=3837,
#     CCL20=3838,
#     NKRF=3839,
#     FARSA-AS1=3840,
#     NR2C2=3841,
#     GTF2H1=3842,
#     TARID=3843,
#     AGER=3844,
#     TBX21=3845,
#     MIR137=3846,
#     lncZBTB39=3847,
#     TCF=3848,
#     LINC00339=3849,
#     PTENP1=3850,
#     LITAF=3851,
#     LINC00488=3852,
#     HAGLROS=3853,
#     ARHGAP27P1=3854,
#     HYOU1=3855,
#     ANCR=3856,
#     miR-145-5p=3857,
#     NISCH=3858,
#     Beclin-1=3859,
#     lnc-REG3G-3-1=3860,
#     PIK3CA=3861,
#     FOXD3-AS1=3862,
#     LINC01611=3863,
#     miR-20b=3864,
#     MIR625=3865,
#     CTBP2=3866,
#     FOXF2=3867,
#     EGLN2=3868,
#     LINC00958=3869,
#     RHOA=3870,
#     RPPH1=3871,
#     BMP1=3872,
#     miR-146a=3873,
#     TNFRSF11A=3874,
#     LNC-LBCS=3875,
#     miR-140-3p=3876,
#     MAFTRR=3877,
#     MDC1-AS1=3878,
#     CORO1C=3879,
#     LINC01546=3880,
#     CAVIN2-AS1=3881,
#     BMP2=3882,
#     CDK7=3883,
#     KRT14=3884,
#     FOXF1=3885,
#     SRY-box9=3886,
#     AU021063=3887,
#     SOCS2=3888,
#     APOBEC3C=3889,
#     ELK1=3890,
#     miR-675=3891,
#     TGFA=3892,
#     CXCR2=3893,
#     IGF1=3894,
#     PURA=3895,
#     A1CF=3896,
#     SRSF6=3897,
#     ABCC10=3898,
#     miR-134=3899,
#     MSH2=3900,
#     PAUPAR=3901,
#     SPAG5-AS1=3902,
#     PTP4A3=3903,
#     SOX10=3904,
#     DYNC2LI1=3905,
#     miR-575=3906,
#     NAMPT=3907,
#   },
#   num_nodes=3908,
#   num_edges=8360
# )

# %%
# Create mapping from node indices to node types
node_type_names = ["miRNA", "PCG", "TF", "lncRNA", "snoRNA", "circRNA"]
node_type_ids = torch.argmax(data.x[:, -7:], dim=1)
node_types = [node_type_names[i] for i in node_type_ids.tolist()]

# Count how many nodes belong to each type
node_type_counts = Counter(node_types)

# Print summary of node types
print("Node type counts:")
for t, c in node_type_counts.items():
    print(f"{t}: {c}")
# Out:
# Node type counts:
# lncRNA: 1333
# miRNA: 512
# TF: 336
# PCG: 1717
# circRNA: 7
# snoRNA: 3

# %%
### all nodes are 3908 nodes from all types...

# Group global indices by node type
node_type_to_indices = defaultdict(list)
for i, node_type in enumerate(node_types):
    node_type_to_indices[node_type].append(i)

# Map global node index to local index within each node type
global_to_local = {}
for node_type, indices in node_type_to_indices.items():
    for local_idx, global_idx in enumerate(indices):
        global_to_local[(node_type, global_idx)] = local_idx

# %%
# Initialize HeteroData
hetero_data = HeteroData()

# Add node features for each type
for node_type, indices in node_type_to_indices.items():
    indices_tensor = torch.tensor(indices, dtype=torch.long)
    hetero_data[node_type].x = data.x[
        indices_tensor, :-7
    ]  # Exclude one-hot type vector
    print(
        f"{node_type}: added {len(indices)} nodes with shape {hetero_data[node_type].x.shape}"
    )
# Out:
# lncRNA: added 1333 nodes with shape torch.Size([1333, 50])
# miRNA: added 512 nodes with shape torch.Size([512, 50])
# TF: added 336 nodes with shape torch.Size([336, 50])
# PCG: added 1717 nodes with shape torch.Size([1717, 50])
# circRNA: added 7 nodes with shape torch.Size([7, 50])
# snoRNA: added 3 nodes with shape torch.Size([3, 50])

# %%
# Build edges per edge type with correct local indices
edge_groups = defaultdict(list)
edge_attrs = defaultdict(list)

for i in range(data.edge_index.shape[1]):
    src = data.edge_index[0, i].item()
    dst = data.edge_index[1, i].item()
    attr = data.edge_attr[i]

    src_type = node_types[src]
    dst_type = node_types[dst]

    edge_type = (src_type, "regulates", dst_type)
    edge_groups[edge_type].append((src, dst))
    edge_attrs[edge_type].append(attr)

# %%
# Add edge_index and edge_attr to HeteroData
for edge_type, edges in edge_groups.items():
    src_type, _, dst_type = edge_type
    src_list = [global_to_local[(src_type, s)] for s, _ in edges]
    dst_list = [global_to_local[(dst_type, d)] for _, d in edges]

    edge_index = torch.tensor([src_list, dst_list], dtype=torch.long)
    edge_attr = torch.stack(edge_attrs[edge_type])

    hetero_data[edge_type].edge_index = edge_index
    hetero_data[edge_type].edge_attr = edge_attr

    print(
        f"Added edge type {edge_type}: {edge_index.shape[1]} edges with attr shape {edge_attr.shape}"
    )
# Out:
# Added edge type ('lncRNA', 'regulates', 'miRNA'): 1088 edges with attr shape torch.Size([1088, 13])
# Added edge type ('lncRNA', 'regulates', 'PCG'): 5029 edges with attr shape torch.Size([5029, 13])
# Added edge type ('lncRNA', 'regulates', 'TF'): 1570 edges with attr shape torch.Size([1570, 13])
# Added edge type ('PCG', 'regulates', 'miRNA'): 11 edges with attr shape torch.Size([11, 13])
# Added edge type ('TF', 'regulates', 'lncRNA'): 303 edges with attr shape torch.Size([303, 13])
# Added edge type ('lncRNA', 'regulates', 'lncRNA'): 34 edges with attr shape torch.Size([34, 13])
# Added edge type ('miRNA', 'regulates', 'lncRNA'): 82 edges with attr shape torch.Size([82, 13])
# Added edge type ('PCG', 'regulates', 'PCG'): 36 edges with attr shape torch.Size([36, 13])
# Added edge type ('circRNA', 'regulates', 'miRNA'): 3 edges with attr shape torch.Size([3, 13])
# Added edge type ('circRNA', 'regulates', 'PCG'): 9 edges with attr shape torch.Size([9, 13])
# Added edge type ('PCG', 'regulates', 'lncRNA'): 178 edges with attr shape torch.Size([178, 13])
# Added edge type ('PCG', 'regulates', 'TF'): 7 edges with attr shape torch.Size([7, 13])
# Added edge type ('lncRNA', 'regulates', 'snoRNA'): 3 edges with attr shape torch.Size([3, 13])
# Added edge type ('circRNA', 'regulates', 'TF'): 3 edges with attr shape torch.Size([3, 13])
# Added edge type ('TF', 'regulates', 'miRNA'): 1 edges with attr shape torch.Size([1, 13])
# Added edge type ('TF', 'regulates', 'PCG'): 1 edges with attr shape torch.Size([1, 13])
# Added edge type ('TF', 'regulates', 'circRNA'): 1 edges with attr shape torch.Size([1, 13])
# Added edge type ('TF', 'regulates', 'TF'): 1 edges with attr shape torch.Size([1, 13])

# %%
## 6 node types each node has 768 node features
# 18 edge types each edge has 13 edge attributes.
print(hetero_data)
# Out:
# HeteroData(
#   lncRNA={ x=[1333, 50] },
#   miRNA={ x=[512, 50] },
#   TF={ x=[336, 50] },
#   PCG={ x=[1717, 50] },
#   circRNA={ x=[7, 50] },
#   snoRNA={ x=[3, 50] },
#   (lncRNA, regulates, miRNA)={
#     edge_index=[2, 1088],
#     edge_attr=[1088, 13],
#   },
#   (lncRNA, regulates, PCG)={
#     edge_index=[2, 5029],
#     edge_attr=[5029, 13],
#   },
#   (lncRNA, regulates, TF)={
#     edge_index=[2, 1570],
#     edge_attr=[1570, 13],
#   },
#   (PCG, regulates, miRNA)={
#     edge_index=[2, 11],
#     edge_attr=[11, 13],
#   },
#   (TF, regulates, lncRNA)={
#     edge_index=[2, 303],
#     edge_attr=[303, 13],
#   },
#   (lncRNA, regulates, lncRNA)={
#     edge_index=[2, 34],
#     edge_attr=[34, 13],
#   },
#   (miRNA, regulates, lncRNA)={
#     edge_index=[2, 82],
#     edge_attr=[82, 13],
#   },
#   (PCG, regulates, PCG)={
#     edge_index=[2, 36],
#     edge_attr=[36, 13],
#   },
#   (circRNA, regulates, miRNA)={
#     edge_index=[2, 3],
#     edge_attr=[3, 13],
#   },
#   (circRNA, regulates, PCG)={
#     edge_index=[2, 9],
#     edge_attr=[9, 13],
#   },
#   (PCG, regulates, lncRNA)={
#     edge_index=[2, 178],
#     edge_attr=[178, 13],
#   },
#   (PCG, regulates, TF)={
#     edge_index=[2, 7],
#     edge_attr=[7, 13],
#   },
#   (lncRNA, regulates, snoRNA)={
#     edge_index=[2, 3],
#     edge_attr=[3, 13],
#   },
#   (circRNA, regulates, TF)={
#     edge_index=[2, 3],
#     edge_attr=[3, 13],
#   },
#   (TF, regulates, miRNA)={
#     edge_index=[2, 1],
#     edge_attr=[1, 13],
#   },
#   (TF, regulates, PCG)={
#     edge_index=[2, 1],
#     edge_attr=[1, 13],
#   },
#   (TF, regulates, circRNA)={
#     edge_index=[2, 1],
#     edge_attr=[1, 13],
#   },
#   (TF, regulates, TF)={
#     edge_index=[2, 1],
#     edge_attr=[1, 13],
#   }
# )

# %%
# show metadata summary (node types and edge types)

print(len(hetero_data.node_types))
print("\nNode types:", hetero_data.node_types)

print(len(hetero_data.edge_types))
print("Edge types:", hetero_data.edge_types)
# Out:
# 6
#
# Node types: ['lncRNA', 'miRNA', 'TF', 'PCG', 'circRNA', 'snoRNA']
# 18
# Edge types: [('lncRNA', 'regulates', 'miRNA'), ('lncRNA', 'regulates', 'PCG'), ('lncRNA', 'regulates', 'TF'), ('PCG', 'regulates', 'miRNA'), ('TF', 'regulates', 'lncRNA'), ('lncRNA', 'regulates', 'lncRNA'), ('miRNA', 'regulates', 'lncRNA'), ('PCG', 'regulates', 'PCG'), ('circRNA', 'regulates', 'miRNA'), ('circRNA', 'regulates', 'PCG'), ('PCG', 'regulates', 'lncRNA'), ('PCG', 'regulates', 'TF'), ('lncRNA', 'regulates', 'snoRNA'), ('circRNA', 'regulates', 'TF'), ('TF', 'regulates', 'miRNA'), ('TF', 'regulates', 'PCG'), ('TF', 'regulates', 'circRNA'), ('TF', 'regulates', 'TF')]

# %%
# Choose where to save the file
save_path = f"../graphs/{graph_path_name}_hetero.pt"

# Save the HeteroData object
torch.save(hetero_data, save_path)

print(f"HeteroData graph saved to: {save_path}")
# Out:
# HeteroData graph saved to: ../data/graph_biobert_50_dim_hetero.pt
