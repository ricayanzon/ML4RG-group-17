# %% [markdown]
# ### Regression
# Six FDR values

# %%
import numpy as np

# Load the embeddings file again after code execution state reset
file_path = "/Users/tunaseckin/Desktop/ML4RG/ML4RG-group-17/conversionOnly_biobert_embeddings.npy"
embeddings = np.load(file_path, allow_pickle=True).item()

# %%
# Check number of entries
print(f"Number of genes: {len(embeddings)}")

# View shape of one embedding
first_key = list(embeddings.keys())[0]
print(f"Example gene ID: {first_key}")
print(f"First 10 gene IDs:", list(embeddings)[0:10])
print(f"Embedding shape: {embeddings[first_key].shape}")
# Out:
# Number of genes: 452
# Example gene ID: LINC01518
# First 10 gene IDs: ['LINC01518', 'LINC00842', 'SGMS1-AS1', 'CCEPR', 'MRLN', 'UNC5B-AS1', 'LINC00339', 'KCNMA1-AS1', 'LINC01342', 'LINC00857']
# Embedding shape: (768,)

# %%
# Re-import libraries after kernel reset
import numpy as np
import pandas as pd

# Reload embeddings and data files
embedding_data = np.load(file_path, allow_pickle=True).item()
final_df = pd.read_csv("/Users/tunaseckin/Desktop/ML4RG/ML4RG-group-17/final.tsv", sep="\t")
supp_df = pd.read_csv("/Users/tunaseckin/Desktop/ML4RG/ML4RG-group-17/Supplementary_table12.csv")

# Prepare mapping and relevant keys
embedding_keys = set(embedding_data.keys())
final_incoming_keys = set(final_df['incoming'].dropna().astype(str).unique())
supp_gene_ids = set(supp_df['Gene_ID'].dropna().astype(str).unique())

# Map from 'incoming' → 'Gene_ID'
incoming_to_geneid = dict(zip(final_df['incoming'].astype(str), final_df['Gene_ID'].astype(str)))

# FDR columns of interest
fdr_columns = [
    'LN18.dropFDR',
    'LN229.dropFDR',
    'A549.dropFDR',
    'NCIH460.dropFDR',
    'KP4.dropFDR',
    'MIAPACA2.dropFDR'
]

# Build X and Y datasets
X, Y, matched_genes = [], [], []

for incoming_gene, embedding in embedding_data.items():
    if incoming_gene not in incoming_to_geneid:
        continue
    
    gene_id = incoming_to_geneid[incoming_gene]
    fdr_row = supp_df[supp_df['Gene_ID'] == gene_id]
    
    if fdr_row.empty:
        continue
    
    fdr_values = fdr_row[fdr_columns].values.flatten()
    if np.any(pd.isna(fdr_values)):
        continue
    
    X.append(embedding)
    Y.append(fdr_values)
    matched_genes.append(incoming_gene)

X = np.stack(X)
Y = np.stack(Y)

X.shape, Y.shape, len(matched_genes)
# Out:
# ((443, 768), (443, 6), 443)

# %% [markdown]
# ## dataset for RRA and LFC values

# %%
import numpy as np
import pandas as pd

# Load BioBERT embeddings
embeddings = np.load("/Users/tunaseckin/Desktop/ML4RG/ML4RG-group-17/conversionOnly_biobert_embeddings.npy", allow_pickle=True).item()

# Load final.tsv file
final_df = pd.read_csv("/Users/tunaseckin/Desktop/ML4RG/ML4RG-group-17/final.tsv", sep="\t")

# Define the relevant columns to extract
target_columns = [
    'LN18.RRAscore', 'LN229.RRAscore', 'A549.RRAscore', 'NCIH460.RRAscore', 'KP4.RRAscore', 'MIAPACA2.RRAscore',
    'LN18.LFC', 'LN229.LFC', 'A549.LFC', 'NCIH460.LFC', 'KP4.LFC', 'MIAPACA2.LFC'
]

# Initialize lists
X = []
Y = []
gene_ids_used = []

# Iterate over genes in the embedding dictionary
for gene_name, embedding in embeddings.items():
    # Match to final_df using "Incoming" column
    match_row = final_df[final_df["incoming"] == gene_name]

    if not match_row.empty:
        # Check if all required columns are present and not null
        row_values = match_row.iloc[0][target_columns]
        if not row_values.isnull().any():
            X.append(embedding)
            Y.append(row_values.values.astype(float))
            gene_ids_used.append(gene_name)

# Convert to numpy arrays
X = np.array(X)
Y = np.array(Y)

print(f"Dataset created.")
print(f"Number of genes: {len(X)}")
print(f"Input shape (BioBERT embeddings): {X.shape}")
print(f"Output shape (target columns): {Y.shape}")
# Out:
# Dataset created.
# Number of genes: 452
# Input shape (BioBERT embeddings): (452, 768)
# Output shape (target columns): (452, 12)

# %%
import numpy as np

# Assume Y is shape (452, 12): first 6 cols are RRA, last 6 are LFC
Y_rra = Y[:, :6]
Y_lfc = Y[:, 6:]

# Discretize RRA into quartiles → values: 0, 1, 2, 3
Y_rra_quartiles = np.floor(Y_rra * 4).astype(int)
Y_rra_quartiles[Y_rra_quartiles == 4] = 3  # cap at 3

# Convert LFC into binary: 1 if > 0 else 0
Y_lfc_binary = (Y_lfc > 0).astype(int)

# Final labels
# We'll flatten each target group per sample
# RRA: shape (452, 6) → (452, 6) [values 0-3]
# LFC: shape (452, 6) → (452, 6) [values 0/1]

# %% [markdown]
# RRA quartile classes (Y_rra_quartiles) → multi-class (4 classes)
#
# LFC binary classes (Y_lfc_binary) → binary (2 classes)

# %%
import matplotlib.pyplot as plt
import numpy as np
from collections import Counter

def plot_label_distributions(Y_rra_quartiles, Y_lfc_binary, task_names=None):
    num_tasks = Y_rra_quartiles.shape[1]
    if task_names is None:
        task_names = [f'Task {i+1}' for i in range(num_tasks)]

    # RRA Quartiles (4-class)
    print("RRA Quartile Class Distributions:")
    fig_rra, axes_rra = plt.subplots(2, 3, figsize=(15, 8))
    for i in range(num_tasks):
        dist = Counter(Y_rra_quartiles[:, i])
        print(f"{task_names[i]}: {dict(dist)}")
        ax = axes_rra[i // 3][i % 3]
        ax.bar(dist.keys(), dist.values(), color='skyblue')
        ax.set_title(f"{task_names[i]} (RRA Quartiles)")
        ax.set_xticks([0, 1, 2, 3])
        ax.set_xlabel("Quartile")
        ax.set_ylabel("Count")
    plt.tight_layout()
    plt.show()

    # LFC Binary
    print("\nLFC Binary Class Distributions:")
    fig_lfc, axes_lfc = plt.subplots(2, 3, figsize=(15, 8))
    for i in range(num_tasks):
        dist = Counter(Y_lfc_binary[:, i])
        print(f"{task_names[i]}: {dict(dist)}")
        ax = axes_lfc[i // 3][i % 3]
        ax.bar(dist.keys(), dist.values(), color='lightcoral')
        ax.set_title(f"{task_names[i]} (LFC Binary)")
        ax.set_xticks([0, 1])
        ax.set_xlabel("Class (0=Negative, 1=Positive)")
        ax.set_ylabel("Count")
    plt.tight_layout()
    plt.show()

task_labels = ['LN18', 'LN229', 'A549', 'NCIH460', 'KP4', 'MIAPACA2']
plot_label_distributions(Y_rra_quartiles, Y_lfc_binary, task_labels)
# Out:
# RRA Quartile Class Distributions:
# LN18: {3: 101, 0: 157, 2: 110, 1: 84}
# LN229: {0: 172, 2: 82, 3: 112, 1: 86}
# A549: {0: 151, 3: 98, 2: 94, 1: 109}
# NCIH460: {0: 157, 1: 77, 3: 122, 2: 96}
# KP4: {0: 159, 1: 71, 3: 123, 2: 99}
# MIAPACA2: {0: 178, 3: 112, 2: 72, 1: 90}
# LFC Binary Class Distributions:
# LN18: {0: 334, 1: 118}
# LN229: {0: 315, 1: 137}
# A549: {0: 302, 1: 150}
# NCIH460: {0: 326, 1: 126}
# KP4: {0: 322, 1: 130}
# MIAPACA2: {0: 328, 1: 124}

# %% [markdown]
# multi-task classification setup with:
#
# 6 × RRA scores → 4-class classification (quartiles)
#
# 6 × LFC scores → binary classification (positive/negative)
#
# So the MLP must:
#
# Output logits for 6×4 = 24 classes (RRA)
#
# Output logits for 6×1 = 6 binary labels (LFC)
# Total output shape = 30

# %%
import torch
import torch.nn as nn

class MultiTaskMLP(nn.Module):
    def __init__(self, input_dim=768, hidden_dim=256):
        super(MultiTaskMLP, self).__init__()
        self.shared = nn.Sequential(
            nn.Linear(input_dim, hidden_dim),
            nn.GELU(),
            nn.Dropout(0.2),
            nn.Linear(hidden_dim, hidden_dim),
            nn.LeakyReLU(),
            nn.Dropout(0.2)
        )
        
        self.rra_head = nn.Linear(hidden_dim, 6 * 4)   # 6 RRA targets, each with 4 classes
        self.lfc_head = nn.Linear(hidden_dim, 6 * 2)   # 6 LFC targets, binary (we'll reshape)

    def forward(self, x):
        h = self.shared(x)
        rra_logits = self.rra_head(h).reshape(-1, 6, 4)  # shape: (batch, 6, 4)
        lfc_logits = self.lfc_head(h).reshape(-1, 6, 2)  # shape: (batch, 6, 2)
        return rra_logits, lfc_logits

# %%
# Compute per-task class weights
def compute_weights(y_true, num_classes):
    weights = []
    for i in range(y_true.shape[1]):
        class_sample_count = np.array([(y_true[:, i] == t).sum() for t in range(num_classes)])
        class_weights = 1. / (class_sample_count + 1e-6)
        weights.append(torch.tensor(class_weights, dtype=torch.float32))
    return weights

rra_weights = compute_weights(Y_rra_quartiles, 4)
lfc_weights = compute_weights(Y_lfc_binary, 2)

# Loss function with per-task weights
def multitask_loss(rra_logits, lfc_logits, rra_labels, lfc_labels):
    loss = 0
    for i in range(6):
        ce_rra = nn.CrossEntropyLoss(weight=rra_weights[i])
        ce_lfc = nn.CrossEntropyLoss(weight=lfc_weights[i])
        loss += ce_rra(rra_logits[:, i, :], rra_labels[:, i])
        loss += ce_lfc(lfc_logits[:, i, :], lfc_labels[:, i])
    return loss / 12

# %%
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset, random_split
from sklearn.metrics import f1_score, roc_auc_score
import numpy as np

# Assume the following are already defined:
# X: (452, 768) embeddings
# Y_rra_quartiles: (452, 6) integer labels in [0-3]
# Y_lfc_binary: (452, 6) integer labels in [0, 1]

# Convert to tensors
X_tensor = torch.tensor(X, dtype=torch.float32)
Y_rra_tensor = torch.tensor(Y_rra_quartiles, dtype=torch.long)
Y_lfc_tensor = torch.tensor(Y_lfc_binary, dtype=torch.long)

# Dataset and splits
dataset = TensorDataset(X_tensor, Y_rra_tensor, Y_lfc_tensor)
train_len = int(0.7 * len(dataset))
val_len = int(0.15 * len(dataset))
test_len = len(dataset) - train_len - val_len
train_set, val_set, test_set = random_split(dataset, [train_len, val_len, test_len], generator=torch.Generator().manual_seed(42))
train_loader = DataLoader(train_set, batch_size=32, shuffle=True)
val_loader = DataLoader(val_set, batch_size=32)
test_loader = DataLoader(test_set, batch_size=32)

# %%
model = MultiTaskMLP()
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)
# Training with early stopping
best_val_loss = float('inf')
patience = 20
epochs_no_improve = 0
best_model_state = None

for epoch in range(500):
    model.train()
    total_train_loss = 0
    for xb, yb_rra, yb_lfc in train_loader:
        optimizer.zero_grad()
        rra_pred, lfc_pred = model(xb)
        loss = multitask_loss(rra_pred, lfc_pred, yb_rra, yb_lfc)
        loss.backward()
        optimizer.step()
        total_train_loss += loss.item()

    model.eval()
    total_val_loss = 0
    with torch.no_grad():
        for xb, yb_rra, yb_lfc in val_loader:
            rra_pred, lfc_pred = model(xb)
            val_loss = multitask_loss(rra_pred, lfc_pred, yb_rra, yb_lfc)
            total_val_loss += val_loss.item()

    avg_train_loss = total_train_loss / len(train_loader)
    avg_val_loss = total_val_loss / len(val_loader)
    print(f"Epoch {epoch+1}: Train Loss = {avg_train_loss:.4f}, Val Loss = {avg_val_loss:.4f}")

    if avg_val_loss < best_val_loss:
        best_val_loss = avg_val_loss
        best_model_state = model.state_dict()
        epochs_no_improve = 0
    else:
        epochs_no_improve += 1
        if epochs_no_improve >= patience:
            print("Early stopping triggered.")
            break
# Out:
# Epoch 1: Train Loss = 1.0448, Val Loss = 1.0413
# Epoch 2: Train Loss = 1.0417, Val Loss = 1.0489
# Epoch 3: Train Loss = 1.0412, Val Loss = 1.0402
# Epoch 4: Train Loss = 1.0392, Val Loss = 1.0434
# Epoch 5: Train Loss = 1.0371, Val Loss = 1.0390
# Epoch 6: Train Loss = 1.0384, Val Loss = 1.0394
# Epoch 7: Train Loss = 1.0369, Val Loss = 1.0451
# Epoch 8: Train Loss = 1.0373, Val Loss = 1.0403
# Epoch 9: Train Loss = 1.0347, Val Loss = 1.0411
# Epoch 10: Train Loss = 1.0355, Val Loss = 1.0461
# Epoch 11: Train Loss = 1.0335, Val Loss = 1.0446
# Epoch 12: Train Loss = 1.0330, Val Loss = 1.0417
# Epoch 13: Train Loss = 1.0310, Val Loss = 1.0415
# Epoch 14: Train Loss = 1.0290, Val Loss = 1.0420
# Epoch 15: Train Loss = 1.0277, Val Loss = 1.0454
# Epoch 16: Train Loss = 1.0288, Val Loss = 1.0489
# Epoch 17: Train Loss = 1.0224, Val Loss = 1.0565
# Epoch 18: Train Loss = 1.0255, Val Loss = 1.0488
# Epoch 19: Train Loss = 1.0205, Val Loss = 1.0522
# Epoch 20: Train Loss = 1.0208, Val Loss = 1.0476
# Epoch 21: Train Loss = 1.0142, Val Loss = 1.0702
# Epoch 22: Train Loss = 1.0174, Val Loss = 1.0624
# Epoch 23: Train Loss = 1.0110, Val Loss = 1.0497
# Epoch 24: Train Loss = 1.0076, Val Loss = 1.0803
# Epoch 25: Train Loss = 1.0108, Val Loss = 1.0617
# Early stopping triggered.

# %%
# Load best model
model.load_state_dict(best_model_state)

# Evaluation on test set
model.eval()
all_rra_true = []
all_rra_pred = []
all_lfc_true = []
all_lfc_pred = []

with torch.no_grad():
    for xb, yb_rra, yb_lfc in test_loader:
        rra_logits, lfc_logits = model(xb)
        rra_preds = rra_logits.argmax(dim=2).numpy()
        lfc_preds = lfc_logits.argmax(dim=2).numpy()
        all_rra_true.append(yb_rra.numpy())
        all_rra_pred.append(rra_preds)
        all_lfc_true.append(yb_lfc.numpy())
        all_lfc_pred.append(lfc_preds)

rra_true = np.vstack(all_rra_true)
rra_pred = np.vstack(all_rra_pred)
lfc_true = np.vstack(all_lfc_true)
lfc_pred = np.vstack(all_lfc_pred)

# Per-class F1 and AUC
for i in range(6):
    f1 = f1_score(lfc_true[:, i], lfc_pred[:, i], zero_division=0)
    try:
        auc = roc_auc_score(lfc_true[:, i], lfc_pred[:, i])
    except ValueError:
        auc = float('nan')
    print(f"LFC Task {i+1}: F1 = {f1:.3f}, ROC-AUC = {auc:.3f}")

for i in range(6):
    f1_macro = f1_score(rra_true[:, i], rra_pred[:, i], average='macro', zero_division=0)
    print(f"RRA Task {i+1}: Macro F1 = {f1_macro:.3f}")
# Out:
# LFC Task 1: F1 = 0.414, ROC-AUC = 0.618
# LFC Task 2: F1 = 0.364, ROC-AUC = 0.572
# LFC Task 3: F1 = 0.441, ROC-AUC = 0.549
# LFC Task 4: F1 = 0.267, ROC-AUC = 0.456
# LFC Task 5: F1 = 0.387, ROC-AUC = 0.475
# LFC Task 6: F1 = 0.339, ROC-AUC = 0.474
# RRA Task 1: Macro F1 = 0.232
# RRA Task 2: Macro F1 = 0.213
# RRA Task 3: Macro F1 = 0.110
# RRA Task 4: Macro F1 = 0.258
# RRA Task 5: Macro F1 = 0.271
# RRA Task 6: Macro F1 = 0.203

# %%
from sklearn.metrics import f1_score, roc_auc_score, precision_score, recall_score

# Load best model
model.load_state_dict(best_model_state)
model.eval()

all_rra_true = []
all_rra_pred = []
all_lfc_true = []
all_lfc_pred = []

with torch.no_grad():
    for xb, yb_rra, yb_lfc in test_loader:
        rra_logits, lfc_logits = model(xb)
        rra_preds = rra_logits.argmax(dim=2).numpy()
        lfc_preds = lfc_logits.argmax(dim=2).numpy()
        all_rra_true.append(yb_rra.numpy())
        all_rra_pred.append(rra_preds)
        all_lfc_true.append(yb_lfc.numpy())
        all_lfc_pred.append(lfc_preds)

rra_true = np.vstack(all_rra_true)
rra_pred = np.vstack(all_rra_pred)
lfc_true = np.vstack(all_lfc_true)
lfc_pred = np.vstack(all_lfc_pred)

print("=== LFC Task Evaluation (Binary Classification) ===")
for i in range(6):
    f1 = f1_score(lfc_true[:, i], lfc_pred[:, i], zero_division=0)
    precision = precision_score(lfc_true[:, i], lfc_pred[:, i], zero_division=0)
    recall = recall_score(lfc_true[:, i], lfc_pred[:, i], zero_division=0)
    try:
        auc = roc_auc_score(lfc_true[:, i], lfc_pred[:, i])
    except ValueError:
        auc = float('nan')
    print(f"LFC Task {i+1}: F1 = {f1:.3f}, Precision = {precision:.3f}, Recall = {recall:.3f}, ROC-AUC = {auc:.3f}")

print("\n=== RRA Task Evaluation (Multi-class Classification) ===")
for i in range(6):
    f1_macro = f1_score(rra_true[:, i], rra_pred[:, i], average='macro', zero_division=0)
    precision_macro = precision_score(rra_true[:, i], rra_pred[:, i], average='macro', zero_division=0)
    recall_macro = recall_score(rra_true[:, i], rra_pred[:, i], average='macro', zero_division=0)
    print(f"RRA Task {i+1}: Macro F1 = {f1_macro:.3f}, Precision = {precision_macro:.3f}, Recall = {recall_macro:.3f}")
# Out:
# === LFC Task Evaluation (Binary Classification) ===
# LFC Task 1: F1 = 0.414, Precision = 0.600, Recall = 0.316, ROC-AUC = 0.618
# LFC Task 2: F1 = 0.364, Precision = 0.276, Recall = 0.533, ROC-AUC = 0.572
# LFC Task 3: F1 = 0.441, Precision = 0.342, Recall = 0.619, ROC-AUC = 0.549
# LFC Task 4: F1 = 0.267, Precision = 0.240, Recall = 0.300, ROC-AUC = 0.456
# LFC Task 5: F1 = 0.387, Precision = 0.300, Recall = 0.545, ROC-AUC = 0.475
# LFC Task 6: F1 = 0.339, Precision = 0.244, Recall = 0.556, ROC-AUC = 0.474
#
# === RRA Task Evaluation (Multi-class Classification) ===
# RRA Task 1: Macro F1 = 0.232, Precision = 0.291, Recall = 0.285
# RRA Task 2: Macro F1 = 0.213, Precision = 0.191, Recall = 0.241
# RRA Task 3: Macro F1 = 0.110, Precision = 0.164, Recall = 0.231
# RRA Task 4: Macro F1 = 0.258, Precision = 0.313, Recall = 0.289
# RRA Task 5: Macro F1 = 0.271, Precision = 0.251, Recall = 0.298
# RRA Task 6: Macro F1 = 0.203, Precision = 0.275, Recall = 0.295

# %% [markdown]
# ## Separate MLP models for LFC and RRA
#
# Data split for RRA and LFC encoding

# %%
import numpy as np
import torch
from sklearn.model_selection import train_test_split

# Load the full data from the previous step
X = X # np.load("/mnt/data/X_final.npy")            # shape: (452, 768)
Y = Y # np.load("/mnt/data/Y_final.npy")            # shape: (452, 12)

# Split Y into RRA and LFC parts
Y_rra = Y[:, :6]  # First 6 columns: RRA scores (float)
Y_lfc = Y[:, 6:]  # Last 6 columns: LFC values (float)

# Binarize LFC: 1 if LFC > 0, else 0
Y_lfc_binary = (Y_lfc > 0).astype(int)

# For RRA: Bin into quartiles (0: Q1, 1: Q2, 2: Q3, 3: Q4)
Y_rra_quartile = np.zeros_like(Y_rra, dtype=int)
for i in range(Y_rra.shape[1]):
    col = Y_rra[:, i]
    thresholds = np.quantile(col, [0.25, 0.5, 0.75])
    Y_rra_quartile[:, i] = np.digitize(col, bins=thresholds)

# Split into train/val/test
X_train, X_temp, y_lfc_train, y_lfc_temp = train_test_split(
    X, Y_lfc_binary, test_size=0.3, random_state=42, stratify=Y_lfc_binary[:, 0]  # stratify on 1st task
)
X_val, X_test, y_lfc_val, y_lfc_test = train_test_split(
    X_temp, y_lfc_temp, test_size=0.5, random_state=42, stratify=y_lfc_temp[:, 0]
)

# Output the shapes
X_train.shape, X_val.shape, X_test.shape, y_lfc_train.shape
# Out:
# ((316, 768), (68, 768), (68, 768), (316, 6))

# %%
import torch
import torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from sklearn.metrics import f1_score, roc_auc_score, precision_score, recall_score
import numpy as np

# Set device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Prepare datasets
X_train_tensor = torch.tensor(X_train, dtype=torch.float32)
y_train_tensor = torch.tensor(y_lfc_train, dtype=torch.float32)

X_val_tensor = torch.tensor(X_val, dtype=torch.float32)
y_val_tensor = torch.tensor(y_lfc_val, dtype=torch.float32)

X_test_tensor = torch.tensor(X_test, dtype=torch.float32)
y_test_tensor = torch.tensor(y_lfc_test, dtype=torch.float32)

train_loader = DataLoader(TensorDataset(X_train_tensor, y_train_tensor), batch_size=32, shuffle=True)
val_loader = DataLoader(TensorDataset(X_val_tensor, y_val_tensor), batch_size=32)
test_loader = DataLoader(TensorDataset(X_test_tensor, y_test_tensor), batch_size=32)

# Compute class imbalance for pos_weight
pos_weights = (1.0 - y_lfc_train.mean(axis=0)) / y_lfc_train.mean(axis=0)
pos_weights = torch.tensor(pos_weights, dtype=torch.float32).to(device)

# Define MLP model
class LFCClassifier(nn.Module):
    def __init__(self):
        super().__init__()
        self.model = nn.Sequential(
            nn.Linear(768, 256),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(256, 128),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(128, 6)  # 6 binary tasks
        )
    
    def forward(self, x):
        return self.model(x)

model = LFCClassifier().to(device)

# Loss and optimizer
criterion = nn.BCEWithLogitsLoss(pos_weight=pos_weights)
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)

# Training loop with early stopping
best_model_state = None
best_val_loss = float('inf')
patience = 20
patience_counter = 0

for epoch in range(500):
    model.train()
    train_loss = 0
    for xb, yb in train_loader:
        xb, yb = xb.to(device), yb.to(device)
        optimizer.zero_grad()
        logits = model(xb)
        loss = criterion(logits, yb)
        loss.backward()
        optimizer.step()
        train_loss += loss.item()

    model.eval()
    val_loss = 0
    with torch.no_grad():
        for xb, yb in val_loader:
            xb, yb = xb.to(device), yb.to(device)
            logits = model(xb)
            loss = criterion(logits, yb)
            val_loss += loss.item()

    avg_train_loss = train_loss / len(train_loader)
    avg_val_loss = val_loss / len(val_loader)
    print(f"Epoch {epoch+1}: Train Loss = {avg_train_loss:.4f}, Val Loss = {avg_val_loss:.4f}")

    # Early stopping
    if avg_val_loss < best_val_loss:
        best_val_loss = avg_val_loss
        best_model_state = model.state_dict()
        patience_counter = 0
    else:
        patience_counter += 1
        if patience_counter >= patience:
            print("Early stopping triggered.")
            break

# ----------------------
#  Evaluation
# ----------------------

# Load best model
model.load_state_dict(best_model_state)
model.eval()

all_true, all_pred = [], []
with torch.no_grad():
    for xb, yb in test_loader:
        xb = xb.to(device)
        logits = model(xb)
        probs = torch.sigmoid(logits).cpu().numpy()
        preds = (probs > 0.5).astype(int)
        all_pred.append(preds)
        all_true.append(yb.numpy())

y_true = np.vstack(all_true)
y_pred = np.vstack(all_pred)

# Metrics
for i in range(6):
    f1 = f1_score(y_true[:, i], y_pred[:, i], zero_division=0)
    prec = precision_score(y_true[:, i], y_pred[:, i], zero_division=0)
    rec = recall_score(y_true[:, i], y_pred[:, i], zero_division=0)
    try:
        auc = roc_auc_score(y_true[:, i], y_pred[:, i])
    except ValueError:
        auc = float('nan')
    print(f"LFC Task {i+1}: F1 = {f1:.3f}, Precision = {prec:.3f}, Recall = {rec:.3f}, ROC-AUC = {auc:.3f}")
# Out:
# Epoch 1: Train Loss = 0.9892, Val Loss = 1.0163
# Epoch 2: Train Loss = 0.9854, Val Loss = 1.0165
# Epoch 3: Train Loss = 0.9820, Val Loss = 1.0161
# Epoch 4: Train Loss = 0.9835, Val Loss = 1.0185
# Epoch 5: Train Loss = 0.9847, Val Loss = 1.0125
# Epoch 6: Train Loss = 0.9819, Val Loss = 1.0207
# Epoch 7: Train Loss = 0.9824, Val Loss = 1.0161
# Epoch 8: Train Loss = 0.9806, Val Loss = 1.0038
# Epoch 9: Train Loss = 0.9862, Val Loss = 1.0184
# Epoch 10: Train Loss = 0.9874, Val Loss = 1.0150
# Epoch 11: Train Loss = 0.9829, Val Loss = 1.0152
# Epoch 12: Train Loss = 0.9823, Val Loss = 1.0121
# Epoch 13: Train Loss = 0.9788, Val Loss = 1.0105
# Epoch 14: Train Loss = 0.9806, Val Loss = 1.0137
# Epoch 15: Train Loss = 0.9805, Val Loss = 1.0061
# Epoch 16: Train Loss = 0.9782, Val Loss = 1.0081
# Epoch 17: Train Loss = 0.9780, Val Loss = 1.0113
# Epoch 18: Train Loss = 0.9778, Val Loss = 1.0083
# Epoch 19: Train Loss = 0.9783, Val Loss = 1.0127
# Epoch 20: Train Loss = 0.9748, Val Loss = 1.0125
# Epoch 21: Train Loss = 0.9818, Val Loss = 1.0170
# Epoch 22: Train Loss = 0.9752, Val Loss = 1.0055
# Epoch 23: Train Loss = 0.9703, Val Loss = 1.0229
# Epoch 24: Train Loss = 0.9760, Val Loss = 1.0215
# Epoch 25: Train Loss = 0.9760, Val Loss = 1.0107
# Epoch 26: Train Loss = 0.9733, Val Loss = 1.0091
# Epoch 27: Train Loss = 0.9805, Val Loss = 1.0175
# Epoch 28: Train Loss = 0.9738, Val Loss = 1.0069
# Early stopping triggered.
# LFC Task 1: F1 = 0.432, Precision = 0.286, Recall = 0.889, ROC-AUC = 0.544
# LFC Task 2: F1 = 0.400, Precision = 0.263, Recall = 0.833, ROC-AUC = 0.497
# LFC Task 3: F1 = 0.518, Precision = 0.367, Recall = 0.880, ROC-AUC = 0.498
# LFC Task 4: F1 = 0.469, Precision = 0.317, Recall = 0.905, ROC-AUC = 0.516
# LFC Task 5: F1 = 0.167, Precision = 0.250, Recall = 0.125, ROC-AUC = 0.505
# LFC Task 6: F1 = 0.400, Precision = 0.295, Recall = 0.619, ROC-AUC = 0.480

# %% [markdown]
# ## Separate models for six sub-types of LFC

# %%
embeddings = np.load("/Users/tunaseckin/Desktop/ML4RG/ML4RG-group-17/all_biobert_embeddings_50_dim.npy", allow_pickle=True)
type(embedding)
# Out:
# numpy.ndarray

# %%
embeddings = np.load("/Users/tunaseckin/Desktop/ML4RG/ML4RG-group-17/lncrna_to_embedding.pkl", allow_pickle=True)

# %%
len(embeddings)
# Out:
# 1333

# %%
for lncrnatype, emb in embeddings.items():
    if isinstance(emb, np.ndarray):
        print(f"lncRNA_name: {lncrnatype}, Embedding shape: {emb.shape}")
    else:
        print(f"lncRNA_name: {lncrnatype}, Embedding len: {len(emb)}")
# Out:
# lncRNA_name: LINC00313, Embedding len: 128
# lncRNA_name: FAM83H-AS1, Embedding len: 128
# lncRNA_name: NEAT1, Embedding len: 128
# lncRNA_name: ZFPM2-AS1, Embedding len: 128
# lncRNA_name: SNHG1, Embedding len: 128
# lncRNA_name: LINC00222, Embedding len: 128
# lncRNA_name: TP73-AS1, Embedding len: 128
# lncRNA_name: PVT1, Embedding len: 128
# lncRNA_name: FEZF1-AS1, Embedding len: 128
# lncRNA_name: DANCR, Embedding len: 128
# lncRNA_name: HOTTIP, Embedding len: 128
# lncRNA_name: CCAT1, Embedding len: 128
# lncRNA_name: GAS5, Embedding len: 128
# lncRNA_name: CCDC26, Embedding len: 128
# lncRNA_name: CRNDE, Embedding len: 128
# lncRNA_name: LINC00858, Embedding len: 128
# lncRNA_name: HOTAIR, Embedding len: 128
# lncRNA_name: HAGLR, Embedding len: 128
# lncRNA_name: TDRG1, Embedding len: 128
# lncRNA_name: LIFR-AS1, Embedding len: 128
# lncRNA_name: THORLNC, Embedding len: 128
# lncRNA_name: LINC00339, Embedding len: 128
# lncRNA_name: NNT-AS1, Embedding len: 128
# lncRNA_name: CBR3-AS1, Embedding len: 128
# lncRNA_name: ZEB2-AS1, Embedding len: 128
# lncRNA_name: FUNDC2P4, Embedding len: 128
# lncRNA_name: SNHG12, Embedding len: 128
# lncRNA_name: LNCRNA-ATB, Embedding len: 128
# lncRNA_name: CYTOR, Embedding len: 128
# lncRNA_name: MALAT1, Embedding len: 128
# lncRNA_name: SNHG5, Embedding len: 128
# lncRNA_name: FOXP4-AS1, Embedding len: 128
# lncRNA_name: TUG1, Embedding len: 128
# lncRNA_name: LINC00174, Embedding len: 128
# lncRNA_name: MIR22HG, Embedding len: 128
# lncRNA_name: MEG3, Embedding len: 128
# lncRNA_name: MIAT, Embedding len: 128
# lncRNA_name: SOX21-AS1, Embedding len: 128
# lncRNA_name: DICER1-AS1, Embedding len: 128
# lncRNA_name: CASC15, Embedding len: 128
# lncRNA_name: FTX, Embedding len: 128
# lncRNA_name: MIR31HG, Embedding len: 128
# lncRNA_name: BTG3-AS1, Embedding len: 128
# lncRNA_name: CASC2, Embedding len: 128
# lncRNA_name: OIP5-AS1, Embedding len: 128
# lncRNA_name: XIST, Embedding len: 128
# lncRNA_name: LSINCT5, Embedding len: 128
# lncRNA_name: PCSEAT, Embedding len: 128
# lncRNA_name: KCNQ1OT1, Embedding len: 128
# lncRNA_name: linc-UFC1, Embedding len: 128
# lncRNA_name: SNHG7, Embedding len: 128
# lncRNA_name: UCA1, Embedding len: 128
# lncRNA_name: FENDRR, Embedding len: 128
# lncRNA_name: BCYRN1, Embedding len: 128
# lncRNA_name: BCAR4, Embedding len: 128
# lncRNA_name: BLACAT1, Embedding len: 128
# lncRNA_name: CASC7, Embedding len: 128
# lncRNA_name: CASC8, Embedding len: 128
# lncRNA_name: CASC9, Embedding len: 128
# lncRNA_name: CAT104, Embedding len: 128
# lncRNA_name: CCAT2, Embedding len: 128
# lncRNA_name: LINC00460, Embedding len: 128
# lncRNA_name: LINC00319, Embedding len: 128
# lncRNA_name: H19, Embedding len: 128
# lncRNA_name: HULC, Embedding len: 128
# lncRNA_name: HOXA-AS2, Embedding len: 128
# lncRNA_name: LINC01510, Embedding len: 128
# lncRNA_name: SNHG16, Embedding len: 128
# lncRNA_name: EGFR-AS1, Embedding len: 128
# lncRNA_name: DGCR5, Embedding len: 128
# lncRNA_name: HIF1A-AS2, Embedding len: 128
# lncRNA_name: SNHG6, Embedding len: 128
# lncRNA_name: LOC728196, Embedding len: 128
# lncRNA_name: LINC00052, Embedding len: 128
# lncRNA_name: BABAM2-AS1, Embedding len: 128
# lncRNA_name: ZFHX4-AS1, Embedding len: 128
# lncRNA_name: WDR86-AS1, Embedding len: 128
# lncRNA_name: CDKN2B-AS1, Embedding len: 128
# lncRNA_name: NORAD, Embedding len: 128
# lncRNA_name: GACAT3, Embedding len: 128
# lncRNA_name: GClnc1, Embedding len: 128
# lncRNA_name: ZEB1-AS1, Embedding len: 128
# lncRNA_name: WSPAR, Embedding len: 128
# lncRNA_name: AL589986.2, Embedding len: 128
# lncRNA_name: C5orf66-AS1, Embedding len: 128
# lncRNA_name: ADAMTS9-AS2, Embedding len: 128
# lncRNA_name: LINC00472, Embedding len: 128
# lncRNA_name: snaR, Embedding len: 128
# lncRNA_name: AFAP1-AS1, Embedding len: 128
# lncRNA_name: SNHG4, Embedding len: 128
# lncRNA_name: LINC01503, Embedding len: 128
# lncRNA_name: LINC00662, Embedding len: 128
# lncRNA_name: LINC00844, Embedding len: 128
# lncRNA_name: IFNG-AS1, Embedding len: 128
# lncRNA_name: LINC00707, Embedding len: 128
# lncRNA_name: PDCD4-AS1, Embedding len: 128
# lncRNA_name: CCDC144NL-AS1, Embedding len: 128
# lncRNA_name: MIR4435-2HG, Embedding len: 128
# lncRNA_name: MAP3K20-AS1, Embedding len: 128
# lncRNA_name: LUCAT1, Embedding len: 128
# lncRNA_name: PANTR1, Embedding len: 128
# lncRNA_name: AC123023.1, Embedding len: 128
# lncRNA_name: CARMN, Embedding len: 128
# lncRNA_name: BDNF-AS, Embedding len: 128
# lncRNA_name: NBAT1, Embedding len: 128
# lncRNA_name: FOXD2-AS1, Embedding len: 128
# lncRNA_name: IGF2-AS, Embedding len: 128
# lncRNA_name: THRIL, Embedding len: 128
# lncRNA_name: HNF1A-AS1, Embedding len: 128
# lncRNA_name: FER1L4, Embedding len: 128
# lncRNA_name: FLVCR1-DT, Embedding len: 128
# lncRNA_name: DBH-AS1, Embedding len: 128
# lncRNA_name: kcna3, Embedding len: 128
# lncRNA_name: LINC00473, Embedding len: 128
# lncRNA_name: NIFK-AS1, Embedding len: 128
# lncRNA_name: FALEC, Embedding len: 128
# lncRNA_name: LINC00599, Embedding len: 128
# lncRNA_name: SOX2-OT, Embedding len: 128
# lncRNA_name: VPS9D1-AS1, Embedding len: 128
# lncRNA_name: HOXA10-AS, Embedding len: 128
# lncRNA_name: IATPR, Embedding len: 128
# lncRNA_name: RMRP, Embedding len: 128
# lncRNA_name: TMEM75, Embedding len: 128
# lncRNA_name: PSG10P, Embedding len: 128
# lncRNA_name: DUXAP8, Embedding len: 128
# lncRNA_name: LINC00961, Embedding len: 128
# lncRNA_name: DLX6-AS1, Embedding len: 128
# lncRNA_name: APTR, Embedding len: 128
# lncRNA_name: Lnc-EPIC1, Embedding len: 128
# lncRNA_name: MNX1-AS1, Embedding len: 128
# lncRNA_name: HOXC-AS3, Embedding len: 128
# lncRNA_name: UBE2CP3-001, Embedding len: 128
# lncRNA_name: FTH1P3, Embedding len: 128
# lncRNA_name: LOC441178, Embedding len: 128
# lncRNA_name: LINC01606, Embedding len: 128
# lncRNA_name: SNHG14, Embedding len: 128
# lncRNA_name: uc003fir, Embedding len: 128
# lncRNA_name: TBILA, Embedding len: 128
# lncRNA_name: GSC-DT, Embedding len: 128
# lncRNA_name: NKX2-1-AS1, Embedding len: 128
# lncRNA_name: DUXAP9, Embedding len: 128
# lncRNA_name: SNHG15, Embedding len: 128
# lncRNA_name: SNHG8, Embedding len: 128
# lncRNA_name: LINC-ROR, Embedding len: 128
# lncRNA_name: LncND, Embedding len: 128
# lncRNA_name: TP53COR1, Embedding len: 128
# lncRNA_name: HOTAIRM1, Embedding len: 128
# lncRNA_name: ZFAS1, Embedding len: 128
# lncRNA_name: PART1, Embedding len: 128
# lncRNA_name: FOXD3-AS1, Embedding len: 128
# lncRNA_name: PTENP1, Embedding len: 128
# lncRNA_name: PCA3, Embedding len: 128
# lncRNA_name: LINC01619, Embedding len: 128
# lncRNA_name: TUSC7, Embedding len: 128
# lncRNA_name: LINC00483, Embedding len: 128
# lncRNA_name: DUXAP10, Embedding len: 128
# lncRNA_name: LINC01139, Embedding len: 128
# lncRNA_name: SNHG20, Embedding len: 128
# lncRNA_name: WDFY3-AS2, Embedding len: 128
# lncRNA_name: LINC01446, Embedding len: 128
# lncRNA_name: RAD51-AS1, Embedding len: 128
# lncRNA_name: SLCO4A1-AS1, Embedding len: 128
# lncRNA_name: lncR-D63785, Embedding len: 128
# lncRNA_name: HOXA11-AS, Embedding len: 128
# lncRNA_name: LINC01605, Embedding len: 128
# lncRNA_name: HOXB13-AS1, Embedding len: 128
# lncRNA_name: RP11-543N12.1, Embedding len: 128
# lncRNA_name: CRRL, Embedding len: 128
# lncRNA_name: lncRNA-ECM, Embedding len: 128
# lncRNA_name: JPX, Embedding len: 128
# lncRNA_name: AGAP2-AS1, Embedding len: 128
# lncRNA_name: ANCR, Embedding len: 128
# lncRNA_name: RP11-79H23.3, Embedding len: 128
# lncRNA_name: TINCR, Embedding len: 128
# lncRNA_name: DLEU1, Embedding len: 128
# lncRNA_name: PVT1-214, Embedding len: 128
# lncRNA_name: ETS1-AS1, Embedding len: 128
# lncRNA_name: GAS8-AS1, Embedding len: 128
# lncRNA_name: SPRY4-IT1, Embedding len: 128
# lncRNA_name: LNC00312, Embedding len: 128
# lncRNA_name: MYCNOS-01, Embedding len: 128
# lncRNA_name: LINC00261, Embedding len: 128
# lncRNA_name: NCK1-DT, Embedding len: 128
# lncRNA_name: CCND2-AS1, Embedding len: 128
# lncRNA_name: BG981369, Embedding len: 128
# lncRNA_name: LINC-PINT, Embedding len: 128
# lncRNA_name: XLOC_008466, Embedding len: 128
# lncRNA_name: AF119895, Embedding len: 128
# lncRNA_name: XLOC_000647, Embedding len: 128
# lncRNA_name: HAND2-AS1, Embedding len: 128
# lncRNA_name: NKILA, Embedding len: 128
# lncRNA_name: PVT1-5, Embedding len: 128
# lncRNA_name: LOC101927497, Embedding len: 128
# lncRNA_name: HAGLROS, Embedding len: 128
# lncRNA_name: LINC00176, Embedding len: 128
# lncRNA_name: CPS1-IT1, Embedding len: 128
# lncRNA_name: AB073614, Embedding len: 128
# lncRNA_name: TMEM238L, Embedding len: 128
# lncRNA_name: LINC00518, Embedding len: 128
# lncRNA_name: RP11-789C1.1, Embedding len: 128
# lncRNA_name: PCGEM1, Embedding len: 128
# lncRNA_name: RCC2-AS1, Embedding len: 128
# lncRNA_name: LINC01121, Embedding len: 128
# lncRNA_name: MT1JP, Embedding len: 128
# lncRNA_name: SH3PXD2A-AS1, Embedding len: 128
# lncRNA_name: LNCDQ, Embedding len: 128
# lncRNA_name: EPEL, Embedding len: 128
# lncRNA_name: BISPR, Embedding len: 128
# lncRNA_name: Lnc-EGFR, Embedding len: 128
# lncRNA_name: AC078922.1, Embedding len: 128
# lncRNA_name: RP11-317J10.2, Embedding len: 128
# lncRNA_name: PCAT7, Embedding len: 128
# lncRNA_name: NPTN-IT1, Embedding len: 128
# lncRNA_name: SUMO1P3, Embedding len: 128
# lncRNA_name: uc.38, Embedding len: 128
# lncRNA_name: MIR210HG, Embedding len: 128
# lncRNA_name: BANCR, Embedding len: 128
# lncRNA_name: PTCSC3, Embedding len: 128
# lncRNA_name: LNCARSR, Embedding len: 128
# lncRNA_name: Lnc-BM, Embedding len: 128
# lncRNA_name: lncHERG, Embedding len: 128
# lncRNA_name: ILF3-DT, Embedding len: 128
# lncRNA_name: PCAT1, Embedding len: 128
# lncRNA_name: LINC00963, Embedding len: 128
# lncRNA_name: PWAR5, Embedding len: 128
# lncRNA_name: AP000439.3, Embedding len: 128
# lncRNA_name: MT1DP, Embedding len: 128
# lncRNA_name: RP11-436H11.5, Embedding len: 128
# lncRNA_name: SNHG17, Embedding len: 128
# lncRNA_name: UICLM, Embedding len: 128
# lncRNA_name: Lnc-Myd88, Embedding len: 128
# lncRNA_name: FOXC2-AS1, Embedding len: 128
# lncRNA_name: GHET1, Embedding len: 128
# lncRNA_name: HAS2-AS1, Embedding len: 128
# lncRNA_name: IGFBP4-1, Embedding len: 128
# lncRNA_name: PARTICL, Embedding len: 128
# lncRNA_name: DPP10-AS1, Embedding len: 128
# lncRNA_name: TRERNA1, Embedding len: 128
# lncRNA_name: MVIH, Embedding len: 128
# lncRNA_name: LncRNA-SARCC, Embedding len: 128
# lncRNA_name: HCG11, Embedding len: 128
# lncRNA_name: RP11-713B9.1, Embedding len: 128
# lncRNA_name: SNHG3, Embedding len: 128
# lncRNA_name: LOC90784, Embedding len: 128
# lncRNA_name: ABHD11-AS1, Embedding len: 128
# lncRNA_name: LINC00461, Embedding len: 128
# lncRNA_name: XIAP-AS1, Embedding len: 128
# lncRNA_name: LINC0086, Embedding len: 128
# lncRNA_name: LINC00668, Embedding len: 128
# lncRNA_name: ERLNC1, Embedding len: 128
# lncRNA_name: LL22NC03-N64E9.1, Embedding len: 128
# lncRNA_name: LINC00673, Embedding len: 128
# lncRNA_name: CCEPR, Embedding len: 128
# lncRNA_name: RSU1P2, Embedding len: 128
# lncRNA_name: lnc-Sox5, Embedding len: 128
# lncRNA_name: XLOC_006390, Embedding len: 128
# lncRNA_name: RP11-169D4.1, Embedding len: 128
# lncRNA_name: LINC00312, Embedding len: 128
# lncRNA_name: MIR100HG, Embedding len: 128
# lncRNA_name: FILNC1, Embedding len: 128
# lncRNA_name: NMRAL2P, Embedding len: 128
# lncRNA_name: TPM1-AS, Embedding len: 128
# lncRNA_name: RP11-714G18.1, Embedding len: 128
# lncRNA_name: LINC00958, Embedding len: 128
# lncRNA_name: FAF1, Embedding len: 128
# lncRNA_name: SCHLAP1, Embedding len: 128
# lncRNA_name: RAB11B-AS1, Embedding len: 128
# lncRNA_name: COL1A2-AS1, Embedding len: 128
# lncRNA_name: KLF3-AS1, Embedding len: 128
# lncRNA_name: LOC100507600, Embedding len: 128
# lncRNA_name: GAPLINC, Embedding len: 128
# lncRNA_name: DLG1-AS1, Embedding len: 128
# lncRNA_name: LINC00515, Embedding len: 128
# lncRNA_name: LINC01260, Embedding len: 128
# lncRNA_name: LOC101930370, Embedding len: 128
# lncRNA_name: FOXCUT, Embedding len: 128
# lncRNA_name: PCBP2-OT1, Embedding len: 128
# lncRNA_name: SPINT1-AS1, Embedding len: 128
# lncRNA_name: CASC2c, Embedding len: 128
# lncRNA_name: PGK1P2, Embedding len: 128
# lncRNA_name: NONHSAG045500, Embedding len: 128
# lncRNA_name: LOXL1-AS1, Embedding len: 128
# lncRNA_name: PCAT29, Embedding len: 128
# lncRNA_name: PAUPAR, Embedding len: 128
# lncRNA_name: LINC01138, Embedding len: 128
# lncRNA_name: HK2P1, Embedding len: 128
# lncRNA_name: ENST00113, Embedding len: 128
# lncRNA_name: PDIA3P1, Embedding len: 128
# lncRNA_name: EBF3-AS, Embedding len: 128
# lncRNA_name: MSX2P1, Embedding len: 128
# lncRNA_name: linc-DYNC2H1-4, Embedding len: 128
# lncRNA_name: SLC7A11-AS1, Embedding len: 128
# lncRNA_name: LINC00630, Embedding len: 128
# lncRNA_name: DLEU2, Embedding len: 128
# lncRNA_name: lncRNA625, Embedding len: 128
# lncRNA_name: AL163636.1, Embedding len: 128
# lncRNA_name: MIR99AHG, Embedding len: 128
# lncRNA_name: RP11-445H22.4, Embedding len: 128
# lncRNA_name: LINC00589, Embedding len: 128
# lncRNA_name: HIF1A-AS1, Embedding len: 128
# lncRNA_name: LINC00941, Embedding len: 128
# lncRNA_name: RP11-296A18.3, Embedding len: 128
# lncRNA_name: uc.339, Embedding len: 128
# lncRNA_name: LINC01567, Embedding len: 128
# lncRNA_name: WDR7-7, Embedding len: 128
# lncRNA_name: LINC00346, Embedding len: 128
# lncRNA_name: HEIH, Embedding len: 128
# lncRNA_name: MAGI2-AS3, Embedding len: 128
# lncRNA_name: ITGB2-AS1, Embedding len: 128
# lncRNA_name: lncRNA-CTD-2108O9.1, Embedding len: 128
# lncRNA_name: AWPPH, Embedding len: 128
# lncRNA_name: LINC00554, Embedding len: 128
# lncRNA_name: RP5-1024C24.1, Embedding len: 128
# lncRNA_name: CAMTA1-DT, Embedding len: 128
# lncRNA_name: RP11-552M11.4, Embedding len: 128
# lncRNA_name: lncRNA-PRLB, Embedding len: 128
# lncRNA_name: MRUL, Embedding len: 128
# lncRNA_name: TUSC8, Embedding len: 128
# lncRNA_name: AC132217.4, Embedding len: 128
# lncRNA_name: PURPL, Embedding len: 128
# lncRNA_name: MIR155HG, Embedding len: 128
# lncRNA_name: lncSHRG, Embedding len: 128
# lncRNA_name: lnc-DILC, Embedding len: 128
# lncRNA_name: OLA1P2, Embedding len: 128
# lncRNA_name: SIRT1-AS, Embedding len: 128
# lncRNA_name: BGLT3, Embedding len: 128
# lncRNA_name: PANDAR, Embedding len: 128
# lncRNA_name: RP5-833A20.1, Embedding len: 128
# lncRNA_name: VLDLR-AS1, Embedding len: 128
# lncRNA_name: RP11-708H21.4, Embedding len: 128
# lncRNA_name: PHBP1, Embedding len: 128
# lncRNA_name: UC.134, Embedding len: 128
# lncRNA_name: HNRNPKP2, Embedding len: 128
# lncRNA_name: PRAL, Embedding len: 128
# lncRNA_name: LINC00672, Embedding len: 128
# lncRNA_name: LNCSRLR, Embedding len: 128
# lncRNA_name: GASAL1, Embedding len: 128
# lncRNA_name: lncRNA-BCAT1, Embedding len: 128
# lncRNA_name: AK093407, Embedding len: 128
# lncRNA_name: PSMD6-AS1, Embedding len: 128
# lncRNA_name: LINC01116, Embedding len: 128
# lncRNA_name: LINC01013, Embedding len: 128
# lncRNA_name: LOC100129148, Embedding len: 128
# lncRNA_name: RB1-DT, Embedding len: 128
# lncRNA_name: LINC00092, Embedding len: 128
# lncRNA_name: RP11-190D6.2, Embedding len: 128
# lncRNA_name: SNHG6-003, Embedding len: 128
# lncRNA_name: PILRLS, Embedding len: 128
# lncRNA_name: AK058003, Embedding len: 128
# lncRNA_name: LncRNA-HIT, Embedding len: 128
# lncRNA_name: LINC00161, Embedding len: 128
# lncRNA_name: lncRNA-Unigene56159, Embedding len: 128
# lncRNA_name: linc-cdh4-2, Embedding len: 128
# lncRNA_name: SNHG18, Embedding len: 128
# lncRNA_name: GIHCG, Embedding len: 128
# lncRNA_name: LINC01133, Embedding len: 128
# lncRNA_name: GPC3-AS1, Embedding len: 128
# lncRNA_name: MFI2, Embedding len: 128
# lncRNA_name: KRT7-AS, Embedding len: 128
# lncRNA_name: linc-223, Embedding len: 128
# lncRNA_name: CLMAT3, Embedding len: 128
# lncRNA_name: CAR10, Embedding len: 128
# lncRNA_name: TRPM2-AS, Embedding len: 128
# lncRNA_name: HIT000218960, Embedding len: 128
# lncRNA_name: PTCSC2, Embedding len: 128
# lncRNA_name: HANR, Embedding len: 128
# lncRNA_name: AC009084.3, Embedding len: 128
# lncRNA_name: lnc-GNAT1-1, Embedding len: 128
# lncRNA_name: MRCCAT1, Embedding len: 128
# lncRNA_name: FBXL19-AS1, Embedding len: 128
# lncRNA_name: TCONS_00026907, Embedding len: 128
# lncRNA_name: MSTO2P, Embedding len: 128
# lncRNA_name: PCAT14, Embedding len: 128
# lncRNA_name: AF113014, Embedding len: 128
# lncRNA_name: n340790, Embedding len: 128
# lncRNA_name: UCC, Embedding len: 128
# lncRNA_name: CANT1, Embedding len: 128
# lncRNA_name: lncRNA-PE, Embedding len: 128
# lncRNA_name: SOCS2-AS1, Embedding len: 128
# lncRNA_name: PICSAR, Embedding len: 128
# lncRNA_name: CASC11, Embedding len: 128
# lncRNA_name: FGFR3-AS1, Embedding len: 128
# lncRNA_name: Lnc34a, Embedding len: 128
# lncRNA_name: TATDN1, Embedding len: 128
# lncRNA_name: TATDN2, Embedding len: 128
# lncRNA_name: TATDN3, Embedding len: 128
# lncRNA_name: BACE1-AS, Embedding len: 128
# lncRNA_name: SAMMSON, Embedding len: 128
# lncRNA_name: RGMB-AS1, Embedding len: 128
# lncRNA_name: lncRNA-NUTF2P3-001, Embedding len: 128
# lncRNA_name: AOC4P, Embedding len: 128
# lncRNA_name: PCAT6, Embedding len: 128
# lncRNA_name: loc285194, Embedding len: 128
# lncRNA_name: RASSF1-AS1, Embedding len: 128
# lncRNA_name: RAB4B-EGLN2, Embedding len: 128
# lncRNA_name: PACERR, Embedding len: 128
# lncRNA_name: WT1-AS, Embedding len: 128
# lncRNA_name: FAM30A, Embedding len: 128
# lncRNA_name: GAS1RR, Embedding len: 128
# lncRNA_name: MINCR, Embedding len: 128
# lncRNA_name: MALINC1, Embedding len: 128
# lncRNA_name: PRDM16-DT, Embedding len: 128
# lncRNA_name: NALT1, Embedding len: 128
# lncRNA_name: RN7SK, Embedding len: 128
# lncRNA_name: ZXF2, Embedding len: 128
# lncRNA_name: lnc-bc060912, Embedding len: 128
# lncRNA_name: MDC1-AS1, Embedding len: 128
# lncRNA_name: LINC00974, Embedding len: 128
# lncRNA_name: LOC401317, Embedding len: 128
# lncRNA_name: POU3F3, Embedding len: 128
# lncRNA_name: DALIR, Embedding len: 128
# lncRNA_name: EWSAT1, Embedding len: 128
# lncRNA_name: PTCSC1, Embedding len: 128
# lncRNA_name: LINC00511, Embedding len: 128
# lncRNA_name: ACTA2-AS1, Embedding len: 128
# lncRNA_name: TP53TG1, Embedding len: 128
# lncRNA_name: BX357664, Embedding len: 128
# lncRNA_name: GSEC, Embedding len: 128
# lncRNA_name: 91H, Embedding len: 128
# lncRNA_name: BC032469, Embedding len: 128
# lncRNA_name: IRAIN, Embedding len: 128
# lncRNA_name: LINC01225, Embedding len: 128
# lncRNA_name: CHAST, Embedding len: 128
# lncRNA_name: NRCP, Embedding len: 128
# lncRNA_name: LUADT1, Embedding len: 128
# lncRNA_name: LINC01426, Embedding len: 128
# lncRNA_name: FAS-AS1, Embedding len: 128
# lncRNA_name: SMILR, Embedding len: 128
# lncRNA_name: ABALON, Embedding len: 128
# lncRNA_name: BALR-6, Embedding len: 128
# lncRNA_name: AK022798, Embedding len: 128
# lncRNA_name: BOK-AS1, Embedding len: 128
# lncRNA_name: AATBC, Embedding len: 128
# lncRNA_name: AB074278, Embedding len: 128
# lncRNA_name: TMPOP2, Embedding len: 128
# lncRNA_name: AK126698, Embedding len: 128
# lncRNA_name: LOC285194, Embedding len: 128
# lncRNA_name: lncRNA-LOWEG, Embedding len: 128
# lncRNA_name: DACOR1, Embedding len: 128
# lncRNA_name: EWSR1, Embedding len: 128
# lncRNA_name: RPL13AP23, Embedding len: 128
# lncRNA_name: CTBP1-AS, Embedding len: 128
# lncRNA_name: GAS6-AS1, Embedding len: 128
# lncRNA_name: TARID, Embedding len: 128
# lncRNA_name: NBR2, Embedding len: 128
# lncRNA_name: LINC00462, Embedding len: 128
# lncRNA_name: LNMICC, Embedding len: 128
# lncRNA_name: SBF2-AS1, Embedding len: 128
# lncRNA_name: LINC01672, Embedding len: 128
# lncRNA_name: EZR-AS1, Embedding len: 128
# lncRNA_name: AK001796, Embedding len: 128
# lncRNA_name: TTN-AS1, Embedding len: 128
# lncRNA_name: POU6F2-AS2, Embedding len: 128
# lncRNA_name: LINC01118, Embedding len: 128
# lncRNA_name: LNCOC1, Embedding len: 128
# lncRNA_name: LUNAR1, Embedding len: 128
# lncRNA_name: LINC00528, Embedding len: 128
# lncRNA_name: LINC00467, Embedding len: 128
# lncRNA_name: LINC01342, Embedding len: 128
# lncRNA_name: LINC00205, Embedding len: 128
# lncRNA_name: DNM3OS, Embedding len: 128
# lncRNA_name: LINC00665, Embedding len: 128
# lncRNA_name: ZNF667-AS1, Embedding len: 128
# lncRNA_name: Mirt2, Embedding len: 128
# lncRNA_name: SCAMP1, Embedding len: 128
# lncRNA_name: LINC00184, Embedding len: 128
# lncRNA_name: PSTAR, Embedding len: 128
# lncRNA_name: Lnc-UCID, Embedding len: 128
# lncRNA_name: AB209371, Embedding len: 128
# lncRNA_name: SPAAR, Embedding len: 128
# lncRNA_name: LINC00299, Embedding len: 128
# lncRNA_name: LOC105375913, Embedding len: 128
# lncRNA_name: SYNE3, Embedding len: 128
# lncRNA_name: LINC00458, Embedding len: 128
# lncRNA_name: LEF1-AS1, Embedding len: 128
# lncRNA_name: MCM3AP-AS1, Embedding len: 128
# lncRNA_name: NR2F1-AS1, Embedding len: 128
# lncRNA_name: VIM-AS1, Embedding len: 128
# lncRNA_name: LncRNATCF7, Embedding len: 128
# lncRNA_name: XIXT, Embedding len: 128
# lncRNA_name: TPT1-AS1, Embedding len: 128
# lncRNA_name: Chaer, Embedding len: 128
# lncRNA_name: FAM83A-AS1, Embedding len: 128
# lncRNA_name: lnc-ABCA12-3, Embedding len: 128
# lncRNA_name: LINC01198, Embedding len: 128
# lncRNA_name: LINC00342, Embedding len: 128
# lncRNA_name: SAMD12-AS1, Embedding len: 128
# lncRNA_name: LINC00466, Embedding len: 128
# lncRNA_name: MIR222HG, Embedding len: 128
# lncRNA_name: SCARNA10, Embedding len: 128
# lncRNA_name: LINC01579, Embedding len: 128
# lncRNA_name: TCL6, Embedding len: 128
# lncRNA_name: RPL13AP20, Embedding len: 128
# lncRNA_name: LINC00882, Embedding len: 128
# lncRNA_name: HCP5, Embedding len: 128
# lncRNA_name: LACAT1, Embedding len: 128
# lncRNA_name: AV310809, Embedding len: 128
# lncRNA_name: PCAT19, Embedding len: 128
# lncRNA_name: PTTG3P, Embedding len: 128
# lncRNA_name: Lnc00908, Embedding len: 128
# lncRNA_name: ATB, Embedding len: 128
# lncRNA_name: LEGLTBC, Embedding len: 128
# lncRNA_name: VIM-AS2, Embedding len: 128
# lncRNA_name: VIM-AS3, Embedding len: 128
# lncRNA_name: LINC01410, Embedding len: 128
# lncRNA_name: LINC00673-v4, Embedding len: 128
# lncRNA_name: XIC, Embedding len: 128
# lncRNA_name: N-BLR, Embedding len: 128
# lncRNA_name: lncRNA 430945, Embedding len: 128
# lncRNA_name: LINC01433, Embedding len: 128
# lncRNA_name: Olfr29-ps1, Embedding len: 128
# lncRNA_name: NRON, Embedding len: 128
# lncRNA_name: TROJAN, Embedding len: 128
# lncRNA_name: LINC01093, Embedding len: 128
# lncRNA_name: MEG8, Embedding len: 128
# lncRNA_name: ZBTB40-IT1, Embedding len: 128
# lncRNA_name: LINC01232, Embedding len: 128
# lncRNA_name: TASR, Embedding len: 128
# lncRNA_name: FGD5-AS1, Embedding len: 128
# lncRNA_name: TTTY15, Embedding len: 128
# lncRNA_name: H23, Embedding len: 128
# lncRNA_name: lncRNAuc001.dgp.1, Embedding len: 128
# lncRNA_name: ST8SIA6-AS1, Embedding len: 128
# lncRNA_name: RP11-820, Embedding len: 128
# lncRNA_name: CHROMR, Embedding len: 128
# lncRNA_name: EMSLR, Embedding len: 128
# lncRNA_name: DLEU1-AS1, Embedding len: 128
# lncRNA_name: COPDA1, Embedding len: 128
# lncRNA_name: AC096664.3, Embedding len: 128
# lncRNA_name: EPB41L4A-AS1, Embedding len: 128
# lncRNA_name: RPSAP52, Embedding len: 128
# lncRNA_name: GATA6-AS, Embedding len: 128
# lncRNA_name: LINC01234, Embedding len: 128
# lncRNA_name: MANCR, Embedding len: 128
# lncRNA_name: IQANK1, Embedding len: 128
# lncRNA_name: SND1-IT1, Embedding len: 128
# lncRNA_name: PLCD3-OT1, Embedding len: 128
# lncRNA_name: PPP1R13B-DT, Embedding len: 128
# lncRNA_name: ADPGK-AS1, Embedding len: 128
# lncRNA_name: LINC00899, Embedding len: 128
# lncRNA_name: SAP30-DT, Embedding len: 128
# lncRNA_name: lnc-AL445665.1-4, Embedding len: 128
# lncRNA_name: AC024560.2, Embedding len: 128
# lncRNA_name: PFAR, Embedding len: 128
# lncRNA_name: WWC2-AS1, Embedding len: 128
# lncRNA_name: CTBP1-DT, Embedding len: 128
# lncRNA_name: RP11-2B6.2, Embedding len: 128
# lncRNA_name: lnc-ob1, Embedding len: 128
# lncRNA_name: AF131217.1, Embedding len: 128
# lncRNA_name: CERNA1, Embedding len: 128
# lncRNA_name: lncRNA-TM1P3, Embedding len: 128
# lncRNA_name: MAGI2-AS, Embedding len: 128
# lncRNA_name: BRD3OS, Embedding len: 128
# lncRNA_name: lncRNA-FA2H-2, Embedding len: 128
# lncRNA_name: LINC01128, Embedding len: 128
# lncRNA_name: CAIF, Embedding len: 128
# lncRNA_name: LINC00702, Embedding len: 128
# lncRNA_name: CCR5AS, Embedding len: 128
# lncRNA_name: LINC02525, Embedding len: 128
# lncRNA_name: HIX003209, Embedding len: 128
# lncRNA_name: TOB1-AS1, Embedding len: 128
# lncRNA_name: XLOC_006277, Embedding len: 128
# lncRNA_name: LncRNA-TWIST1, Embedding len: 128
# lncRNA_name: OIS1, Embedding len: 128
# lncRNA_name: ASLNCS5088, Embedding len: 128
# lncRNA_name: NR_003923, Embedding len: 128
# lncRNA_name: MELTF-AS1, Embedding len: 128
# lncRNA_name: ENST00000602558.1, Embedding len: 128
# lncRNA_name: TMEM18-DT, Embedding len: 128
# lncRNA_name: RP11-670E13.6, Embedding len: 128
# lncRNA_name: LINC01149, Embedding len: 128
# lncRNA_name: CHRF, Embedding len: 128
# lncRNA_name: WiNTRLINC1, Embedding len: 128
# lncRNA_name: SYNE1-AS1, Embedding len: 128
# lncRNA_name: LINC00520, Embedding len: 128
# lncRNA_name: DNAJC3-DT, Embedding len: 128
# lncRNA_name: MGAT3-AS1, Embedding len: 128
# lncRNA_name: u50535, Embedding len: 128
# lncRNA_name: LINC01638, Embedding len: 128
# lncRNA_name: HERES, Embedding len: 128
# lncRNA_name: CHAR, Embedding len: 128
# lncRNA_name: BM450697, Embedding len: 128
# lncRNA_name: PCED1B-AS1, Embedding len: 128
# lncRNA_name: lncRNA SRA, Embedding len: 128
# lncRNA_name: C2dat1, Embedding len: 128
# lncRNA_name: LINC00922, Embedding len: 128
# lncRNA_name: lncRNA-ENST00000411554, Embedding len: 128
# lncRNA_name: TFDP1, Embedding len: 128
# lncRNA_name: CCAT1-L, Embedding len: 128
# lncRNA_name: CIR, Embedding len: 128
# lncRNA_name: LINC01224, Embedding len: 128
# lncRNA_name: Linc-SCRG1, Embedding len: 128
# lncRNA_name: FGF12-AS2, Embedding len: 128
# lncRNA_name: ICMT-DT, Embedding len: 128
# lncRNA_name: TMPO-AS1, Embedding len: 128
# lncRNA_name: AC010789.1, Embedding len: 128
# lncRNA_name: FGD5, Embedding len: 128
# lncRNA_name: FAM99A, Embedding len: 128
# lncRNA_name: LINC00355, Embedding len: 128
# lncRNA_name: PTPRG-AS1, Embedding len: 128
# lncRNA_name: LINC01189, Embedding len: 128
# lncRNA_name: MIR503HG, Embedding len: 128
# lncRNA_name: LINC01089, Embedding len: 128
# lncRNA_name: CR594175, Embedding len: 128
# lncRNA_name: HOXA-AS3, Embedding len: 128
# lncRNA_name: Hsp4, Embedding len: 128
# lncRNA_name: LINC02418, Embedding len: 128
# lncRNA_name: SLC26A4-AS1, Embedding len: 128
# lncRNA_name: PEBP1P2, Embedding len: 128
# lncRNA_name: RP11-395G23.3, Embedding len: 128
# lncRNA_name: FAM230B, Embedding len: 128
# lncRNA_name: PWRN1, Embedding len: 128
# lncRNA_name: RPPH1, Embedding len: 128
# lncRNA_name: KTN1-AS1, Embedding len: 128
# lncRNA_name: CERS6-AS1, Embedding len: 128
# lncRNA_name: EMX2OS, Embedding len: 128
# lncRNA_name: circ_0029589, Embedding len: 128
# lncRNA_name: PGM5-AS1, Embedding len: 128
# lncRNA_name: PCAT18, Embedding len: 128
# lncRNA_name: DMTF1, Embedding len: 128
# lncRNA_name: LINC00839, Embedding len: 128
# lncRNA_name: DSCAM-AS1, Embedding len: 128
# lncRNA_name: LINC00242, Embedding len: 128
# lncRNA_name: MIR497HG, Embedding len: 128
# lncRNA_name: GATA3-AS1, Embedding len: 128
# lncRNA_name: PRKCQ-AS1, Embedding len: 128
# lncRNA_name: RP11-340F14.6, Embedding len: 128
# lncRNA_name: ZNF407-AS1, Embedding len: 128
# lncRNA_name: LINC00324, Embedding len: 128
# lncRNA_name: LOC100506178, Embedding len: 128
# lncRNA_name: DGUOK-AS1, Embedding len: 128
# lncRNA_name: SPYR4-IT1, Embedding len: 128
# lncRNA_name: ciRS-7, Embedding len: 128
# lncRNA_name: SENEBLOC, Embedding len: 128
# lncRNA_name: ANKRD40CL, Embedding len: 128
# lncRNA_name: MIR181A2HG, Embedding len: 128
# lncRNA_name: MAFG-DT, Embedding len: 128
# lncRNA_name: SNHG22, Embedding len: 128
# lncRNA_name: FAFASA-AS1, Embedding len: 128
# lncRNA_name: ROR1-AS1, Embedding len: 128
# lncRNA_name: IGFL2-AS1, Embedding len: 128
# lncRNA_name: GABPB1-AS1, Embedding len: 128
# lncRNA_name: LINC00973, Embedding len: 128
# lncRNA_name: DDX11-AS1, Embedding len: 128
# lncRNA_name: EFNA1, Embedding len: 128
# lncRNA_name: DLST, Embedding len: 128
# lncRNA_name: DONSON, Embedding len: 128
# lncRNA_name: NRIP1, Embedding len: 128
# lncRNA_name: RBM33, Embedding len: 128
# lncRNA_name: PSMC3, Embedding len: 128
# lncRNA_name: IGKJ2-MALLP2, Embedding len: 128
# lncRNA_name: SMIM45, Embedding len: 128
# lncRNA_name: BBOX1-AS1, Embedding len: 128
# lncRNA_name: 1700020I14Rik, Embedding len: 128
# lncRNA_name: CLNK, Embedding len: 128
# lncRNA_name: MIR124-1HG, Embedding len: 128
# lncRNA_name: lnc-C/EBPbeta, Embedding len: 128
# lncRNA_name: MYLK-AS1, Embedding len: 128
# lncRNA_name: LOC440173, Embedding len: 128
# lncRNA_name: SNHG11, Embedding len: 128
# lncRNA_name: ELDR, Embedding len: 128
# lncRNA_name: Linc-smad7, Embedding len: 128
# lncRNA_name: lnc-REG3G-3-1, Embedding len: 128
# lncRNA_name: lncRNA-TTN-AS1, Embedding len: 128
# lncRNA_name: MACC1-AS1, Embedding len: 128
# lncRNA_name: ZRANB1, Embedding len: 128
# lncRNA_name: lnc-BAZ2B, Embedding len: 128
# lncRNA_name: LGMNP1, Embedding len: 128
# lncRNA_name: RP11-323N12.5, Embedding len: 128
# lncRNA_name: lnc-HSD17B11-1:1, Embedding len: 128
# lncRNA_name: LINC01419, Embedding len: 128
# lncRNA_name: PITPNA-AS1, Embedding len: 128
# lncRNA_name: TGFbeta2-AS1, Embedding len: 128
# lncRNA_name: LINC02349, Embedding len: 128
# lncRNA_name: B4GALT1-AS1, Embedding len: 128
# lncRNA_name: Lnc13, Embedding len: 128
# lncRNA_name: NRAV, Embedding len: 128
# lncRNA_name: OR3A4P, Embedding len: 128
# lncRNA_name: SLC20A1, Embedding len: 128
# lncRNA_name: ARAP1-AS2, Embedding len: 128
# lncRNA_name: RP11, Embedding len: 128
# lncRNA_name: A2M-AS1, Embedding len: 128
# lncRNA_name: LBX2-AS1, Embedding len: 128
# lncRNA_name: LINC01611, Embedding len: 128
# lncRNA_name: RP1-90L14.1, Embedding len: 128
# lncRNA_name: LncIHAT, Embedding len: 128
# lncRNA_name: MaTAR25, Embedding len: 128
# lncRNA_name: RP11-1094M14.8, Embedding len: 128
# lncRNA_name: TONSL-AS1, Embedding len: 128
# lncRNA_name: MAARS, Embedding len: 128
# lncRNA_name: NONHSAT143692.2, Embedding len: 128
# lncRNA_name: LncRNA-OBFC2A, Embedding len: 128
# lncRNA_name: lncRNACNN3-206, Embedding len: 128
# lncRNA_name: EPIC1, Embedding len: 128
# lncRNA_name: ENST, Embedding len: 128
# lncRNA_name: RUSC1-AS1, Embedding len: 128
# lncRNA_name: SCAMP1-TV2, Embedding len: 128
# lncRNA_name: RP11-86H7.1, Embedding len: 128
# lncRNA_name: MROCKI, Embedding len: 128
# lncRNA_name: LINC00173.v1, Embedding len: 128
# lncRNA_name: GCM1, Embedding len: 128
# lncRNA_name: AK002210, Embedding len: 128
# lncRNA_name: LINC01278, Embedding len: 128
# lncRNA_name: ELFN1-AS1, Embedding len: 128
# lncRNA_name: AK094457, Embedding len: 128
# lncRNA_name: MHRT, Embedding len: 128
# lncRNA_name: MIR205HG, Embedding len: 128
# lncRNA_name: HCG18, Embedding len: 128
# lncRNA_name: CASC19, Embedding len: 128
# lncRNA_name: AK039862, Embedding len: 128
# lncRNA_name: LINC00210, Embedding len: 128
# lncRNA_name: Lnc-ATG9B-4, Embedding len: 128
# lncRNA_name: PSMA3-AS1, Embedding len: 128
# lncRNA_name: SAP30-2:1, Embedding len: 128
# lncRNA_name: EIF3J-DT, Embedding len: 128
# lncRNA_name: DINOL, Embedding len: 128
# lncRNA_name: LATS2-AS1-001, Embedding len: 128
# lncRNA_name: lncRNA-SARCC, Embedding len: 128
# lncRNA_name: LINC00173, Embedding len: 128
# lncRNA_name: lncRNA 00312, Embedding len: 128
# lncRNA_name: MIR3936HG, Embedding len: 128
# lncRNA_name: MCF2L-AS1, Embedding len: 128
# lncRNA_name: HNF4A-AS1, Embedding len: 128
# lncRNA_name: LINC01939, Embedding len: 128
# lncRNA_name: LINC00667, Embedding len: 128
# lncRNA_name: SNHG9, Embedding len: 128
# lncRNA_name: LncDACH1, Embedding len: 128
# lncRNA_name: Ahit, Embedding len: 128
# lncRNA_name: LINC00240, Embedding len: 128
# lncRNA_name: LINC00163, Embedding len: 128
# lncRNA_name: CYCSP5, Embedding len: 128
# lncRNA_name: HYOU1-AS, Embedding len: 128
# lncRNA_name: THCYTX, Embedding len: 128
# lncRNA_name: MAPKAPK5-AS1, Embedding len: 128
# lncRNA_name: LINC00485, Embedding len: 128
# lncRNA_name: LINC01535, Embedding len: 128
# lncRNA_name: MKLN1<U+2011>AS, Embedding len: 128
# lncRNA_name: FKBP9P1, Embedding len: 128
# lncRNA_name: ADIPOQ, Embedding len: 128
# lncRNA_name: RBAT1, Embedding len: 128
# lncRNA_name: DRAIC, Embedding len: 128
# lncRNA_name: LOC646616, Embedding len: 128
# lncRNA_name: TRIM52-AS1, Embedding len: 128
# lncRNA_name: TBX5-AS1:2, Embedding len: 128
# lncRNA_name: lncZBTB39, Embedding len: 128
# lncRNA_name: TCONS_00016233, Embedding len: 128
# lncRNA_name: AL049437, Embedding len: 128
# lncRNA_name: GPNCA, Embedding len: 128
# lncRNA_name: CISAL, Embedding len: 128
# lncRNA_name: SPAG5-AS1, Embedding len: 128
# lncRNA_name: LINC00525, Embedding len: 128
# lncRNA_name: IUR, Embedding len: 128
# lncRNA_name: FERRE, Embedding len: 128
# lncRNA_name: LINC02381, Embedding len: 128
# lncRNA_name: ARFRP1, Embedding len: 128
# lncRNA_name: LINC00426, Embedding len: 128
# lncRNA_name: lincNMR, Embedding len: 128
# lncRNA_name: AK131850, Embedding len: 128
# lncRNA_name: HSRL, Embedding len: 128
# lncRNA_name: LINC01126, Embedding len: 128
# lncRNA_name: LINC01436, Embedding len: 128
# lncRNA_name: PCNAP1, Embedding len: 128
# lncRNA_name: MIR924HG, Embedding len: 128
# lncRNA_name: NFIA-AS2, Embedding len: 128
# lncRNA_name: SLEAR, Embedding len: 128
# lncRNA_name: TPTEP1, Embedding len: 128
# lncRNA_name: RAPIA, Embedding len: 128
# lncRNA_name: LCTS5, Embedding len: 128
# lncRNA_name: RHPN1-AS1, Embedding len: 128
# lncRNA_name: TYKRIL, Embedding len: 128
# lncRNA_name: SATB2-AS1, Embedding len: 128
# lncRNA_name: SNHG10, Embedding len: 128
# lncRNA_name: lncRNA-5657, Embedding len: 128
# lncRNA_name: SUMO1P4, Embedding len: 128
# lncRNA_name: SUMO1P5, Embedding len: 128
# lncRNA_name: NUTM2A-AS1, Embedding len: 128
# lncRNA_name: HOXB-AS3, Embedding len: 128
# lncRNA_name: HIF1A-AS3, Embedding len: 128
# lncRNA_name: HIF1A-AS4, Embedding len: 128
# lncRNA_name: KDM7A-DT, Embedding len: 128
# lncRNA_name: lncGALM, Embedding len: 128
# lncRNA_name: LINC00987, Embedding len: 128
# lncRNA_name: TANAR, Embedding len: 128
# lncRNA_name: TCONS_00004099, Embedding len: 128
# lncRNA_name: THAP9-AS1, Embedding len: 128
# lncRNA_name: FAM225B, Embedding len: 128
# lncRNA_name: SDCBP2-AS1, Embedding len: 128
# lncRNA_name: MIR29B2CHG, Embedding len: 128
# lncRNA_name: BRE-AS1, Embedding len: 128
# lncRNA_name: HAR1A, Embedding len: 128
# lncRNA_name: HAR2A, Embedding len: 128
# lncRNA_name: W42, Embedding len: 128
# lncRNA_name: LAPAS1, Embedding len: 128
# lncRNA_name: PINK1-AS, Embedding len: 128
# lncRNA_name: AK097647, Embedding len: 128
# lncRNA_name: KCNQ1, Embedding len: 128
# lncRNA_name: OXCT1-AS1, Embedding len: 128
# lncRNA_name: MSC-AS1, Embedding len: 128
# lncRNA_name: PINT87aa, Embedding len: 128
# lncRNA_name: SLC16A1-AS1, Embedding len: 128
# lncRNA_name: MITA1, Embedding len: 128
# lncRNA_name: RP11-279C4.1, Embedding len: 128
# lncRNA_name: RPL34-DT, Embedding len: 128
# lncRNA_name: AND2-AS1, Embedding len: 128
# lncRNA_name: SNX17, Embedding len: 128
# lncRNA_name: LINC00842, Embedding len: 128
# lncRNA_name: LOC146880, Embedding len: 128
# lncRNA_name: TCONS_00034812, Embedding len: 128
# lncRNA_name: AK136714, Embedding len: 128
# lncRNA_name: PRKAR1B-AS2, Embedding len: 128
# lncRNA_name: KIMAT1, Embedding len: 128
# lncRNA_name: LINC01006, Embedding len: 128
# lncRNA_name: lncRNA-PAICC, Embedding len: 128
# lncRNA_name: PRR34-AS1, Embedding len: 128
# lncRNA_name: HOXBLINC, Embedding len: 128
# lncRNA_name: AFAP1-AS2, Embedding len: 128
# lncRNA_name: LINC00942, Embedding len: 128
# lncRNA_name: GAU1, Embedding len: 128
# lncRNA_name: GLCC1, Embedding len: 128
# lncRNA_name: LINC02620, Embedding len: 128
# lncRNA_name: NRAD1, Embedding len: 128
# lncRNA_name: LINC01929, Embedding len: 128
# lncRNA_name: Lnc-HZ08, Embedding len: 128
# lncRNA_name: LINC00641, Embedding len: 128
# lncRNA_name: AC005592.2, Embedding len: 128
# lncRNA_name: CCNL1, Embedding len: 128
# lncRNA_name: LINC01518, Embedding len: 128
# lncRNA_name: INHBA, Embedding len: 128
# lncRNA_name: LINC01123, Embedding len: 128
# lncRNA_name: LINC00659, Embedding len: 128
# lncRNA_name: NR2F2-AS1, Embedding len: 128
# lncRNA_name: DLGAP1-AS1, Embedding len: 128
# lncRNA_name: LINC00847, Embedding len: 128
# lncRNA_name: CRYBG3, Embedding len: 128
# lncRNA_name: lnc005620, Embedding len: 128
# lncRNA_name: ELNAT1, Embedding len: 128
# lncRNA_name: CCDC80, Embedding len: 128
# lncRNA_name: NR026833.1, Embedding len: 128
# lncRNA_name: LOC100129620, Embedding len: 128
# lncRNA_name: lncRSPH9-4, Embedding len: 128
# lncRNA_name: PWAR6, Embedding len: 128
# lncRNA_name: LINC00908, Embedding len: 128
# lncRNA_name: lnc-LYZ-2, Embedding len: 128
# lncRNA_name: PD-L1-lnc, Embedding len: 128
# lncRNA_name: LINC01303, Embedding len: 128
# lncRNA_name: DQ786243, Embedding len: 128
# lncRNA_name: UNC5B-AS1, Embedding len: 128
# lncRNA_name: ERLR, Embedding len: 128
# lncRNA_name: LNC-HZ01, Embedding len: 128
# lncRNA_name: LINC00477, Embedding len: 128
# lncRNA_name: SLC2A1-DT, Embedding len: 128
# lncRNA_name: RAMS11, Embedding len: 128
# lncRNA_name: SFTA3, Embedding len: 128
# lncRNA_name: SGMS1-AS1, Embedding len: 128
# lncRNA_name: PFI, Embedding len: 128
# lncRNA_name: LPAL2, Embedding len: 128
# lncRNA_name: LINC00221, Embedding len: 128
# lncRNA_name: MAGI1-IT1, Embedding len: 128
# lncRNA_name: VESTAR, Embedding len: 128
# lncRNA_name: RP11-301G19.1, Embedding len: 128
# lncRNA_name: MCTP1-AS1, Embedding len: 128
# lncRNA_name: ATP2B1-AS1, Embedding len: 128
# lncRNA_name: TCONS_00023297, Embedding len: 128
# lncRNA_name: LINC02200, Embedding len: 128
# lncRNA_name: ENST00000437781.1, Embedding len: 128
# lncRNA_name: LINC00968, Embedding len: 128
# lncRNA_name: RP1-86C11.7, Embedding len: 128
# lncRNA_name: ALMS1-IT1, Embedding len: 128
# lncRNA_name: TG2-lncRNA, Embedding len: 128
# lncRNA_name: TSIX, Embedding len: 128
# lncRNA_name: LOC100505817, Embedding len: 128
# lncRNA_name: ARHGAP5-AS1, Embedding len: 128
# lncRNA_name: LOC550643, Embedding len: 128
# lncRNA_name: LINC00852, Embedding len: 128
# lncRNA_name: MROS-1, Embedding len: 128
# lncRNA_name: Lnc-STYK1-2, Embedding len: 128
# lncRNA_name: RP11-84C13.1, Embedding len: 128
# lncRNA_name: AL355711, Embedding len: 128
# lncRNA_name: NONHSAT009986, Embedding len: 128
# lncRNA_name: RP11-115N4.1, Embedding len: 128
# lncRNA_name: GSTM3TV2, Embedding len: 128
# lncRNA_name: AU021063, Embedding len: 128
# lncRNA_name: NONHSAT069381, Embedding len: 128
# lncRNA_name: NONHSAT140844, Embedding len: 128
# lncRNA_name: HHIP<U+2011>AS1, Embedding len: 128
# lncRNA_name: EPIST, Embedding len: 128
# lncRNA_name: LINC01385, Embedding len: 128
# lncRNA_name: NR_002794, Embedding len: 128
# lncRNA_name: lncBCAS1-4_1, Embedding len: 128
# lncRNA_name: LNC000093, Embedding len: 128
# lncRNA_name: Linc8087, Embedding len: 128
# lncRNA_name: THAP7-AS2, Embedding len: 128
# lncRNA_name: AC012213.3, Embedding len: 128
# lncRNA_name: SNX20AR, Embedding len: 128
# lncRNA_name: 7SK, Embedding len: 128
# lncRNA_name: GRASLND, Embedding len: 128
# lncRNA_name: FAM66C, Embedding len: 128
# lncRNA_name: SCDAL, Embedding len: 128
# lncRNA_name: FOXD1-AS1, Embedding len: 128
# lncRNA_name: LncHrt, Embedding len: 128
# lncRNA_name: PCDHB17P, Embedding len: 128
# lncRNA_name: AC016745.3, Embedding len: 128
# lncRNA_name: LINC01554, Embedding len: 128
# lncRNA_name: PAX8-AS1, Embedding len: 128
# lncRNA_name: TFAP2A-AS1, Embedding len: 128
# lncRNA_name: RP11-531A24.3, Embedding len: 128
# lncRNA_name: NONRATG019935.2, Embedding len: 128
# lncRNA_name: TMEM220-AS1, Embedding len: 128
# lncRNA_name: LINC01050, Embedding len: 128
# lncRNA_name: PPM1A-AS, Embedding len: 128
# lncRNA_name: AY927529, Embedding len: 128
# lncRNA_name: LINC01094, Embedding len: 128
# lncRNA_name: GRIK1-AS1, Embedding len: 128
# lncRNA_name: XLOC_006753, Embedding len: 128
# lncRNA_name: DUXAP9-206, Embedding len: 128
# lncRNA_name: LNCBRM, Embedding len: 128
# lncRNA_name: ELF3-AS1, Embedding len: 128
# lncRNA_name: TNK2-AS1, Embedding len: 128
# lncRNA_name: HOXC13-AS, Embedding len: 128
# lncRNA_name: LncHOXA10, Embedding len: 128
# lncRNA_name: CamK-A, Embedding len: 128
# lncRNA_name: DCXR-DT, Embedding len: 128
# lncRNA_name: TCONS_00023979, Embedding len: 128
# lncRNA_name: CCHE1, Embedding len: 128
# lncRNA_name: LncHDAC2, Embedding len: 128
# lncRNA_name: LINC-01572:28, Embedding len: 128
# lncRNA_name: BORG, Embedding len: 128
# lncRNA_name: RUNX1-IT1, Embedding len: 128
# lncRNA_name: P5848, Embedding len: 128
# lncRNA_name: lncRNA®CCDC6, Embedding len: 128
# lncRNA_name: LIN28B-AS1, Embedding len: 128
# lncRNA_name: GCAWKR, Embedding len: 128
# lncRNA_name: lnc-MMP2-2, Embedding len: 128
# lncRNA_name: TCONS_00024652, Embedding len: 128
# lncRNA_name: NTT, Embedding len: 128
# lncRNA_name: PNCTR, Embedding len: 128
# lncRNA_name: lnc-RAB1A-2, Embedding len: 128
# lncRNA_name: lncRNA2448-11, Embedding len: 128
# lncRNA_name: lncRNA1403, Embedding len: 128
# lncRNA_name: LERFS, Embedding len: 128
# lncRNA_name: ENSG00000231881, Embedding len: 128
# lncRNA_name: NEAT1_2, Embedding len: 128
# lncRNA_name: NONHSAT105177, Embedding len: 128
# lncRNA_name: COMETT, Embedding len: 128
# lncRNA_name: CALML3-AS1, Embedding len: 128
# lncRNA_name: LINC000607, Embedding len: 128
# lncRNA_name: LINC02303, Embedding len: 128
# lncRNA_name: ELL2, Embedding len: 128
# lncRNA_name: LINC01585, Embedding len: 128
# lncRNA_name: OGFRP1, Embedding len: 128
# lncRNA_name: PRNCR1, Embedding len: 128
# lncRNA_name: MIF-AS1, Embedding len: 128
# lncRNA_name: NEXN-AS1, Embedding len: 128
# lncRNA_name: DDN-AS1, Embedding len: 128
# lncRNA_name: CRCMSL, Embedding len: 128
# lncRNA_name: GREP1, Embedding len: 128
# lncRNA_name: AZIN2-sv, Embedding len: 128
# lncRNA_name: B3GALT5-AS1, Embedding len: 128
# lncRNA_name: LINC00320, Embedding len: 128
# lncRNA_name: APC1, Embedding len: 128
# lncRNA_name: LNCNEF, Embedding len: 128
# lncRNA_name: lnc-TSI, Embedding len: 128
# lncRNA_name: LOC105374325, Embedding len: 128
# lncRNA_name: LINC00628, Embedding len: 128
# lncRNA_name: lncRNA-135528, Embedding len: 128
# lncRNA_name: lncRNA-IFI6, Embedding len: 128
# lncRNA_name: AK006025, Embedding len: 128
# lncRNA_name: MRPL39, Embedding len: 128
# lncRNA_name: CA3-AS1, Embedding len: 128
# lncRNA_name: LNC-LBCS, Embedding len: 128
# lncRNA_name: ARSR, Embedding len: 128
# lncRNA_name: TPTE2P1, Embedding len: 128
# lncRNA_name: CARL, Embedding len: 128
# lncRNA_name: MDRL, Embedding len: 128
# lncRNA_name: APF, Embedding len: 128
# lncRNA_name: Ang262, Embedding len: 128
# lncRNA_name: Giver, Embedding len: 128
# lncRNA_name: ZNF281, Embedding len: 128
# lncRNA_name: NLIPMT, Embedding len: 128
# lncRNA_name: HATAIR, Embedding len: 128
# lncRNA_name: HOXO-AS1, Embedding len: 128
# lncRNA_name: XLOC-00846, Embedding len: 128
# lncRNA_name: SLC8A1-AS1, Embedding len: 128
# lncRNA_name: DRHC, Embedding len: 128
# lncRNA_name: lnc-ATB, Embedding len: 128
# lncRNA_name: NPCCAT1, Embedding len: 128
# lncRNA_name: ARAP1-AS1, Embedding len: 128
# lncRNA_name: GAS6-DT, Embedding len: 128
# lncRNA_name: Gm15290, Embedding len: 128
# lncRNA_name: CCAL, Embedding len: 128
# lncRNA_name: A1BG-AS1, Embedding len: 128
# lncRNA_name: MIR570HG, Embedding len: 128
# lncRNA_name: ZNF205-AS1, Embedding len: 128
# lncRNA_name: lncATB, Embedding len: 128
# lncRNA_name: WEE2-AS1, Embedding len: 128
# lncRNA_name: lncRNA-6195, Embedding len: 128
# lncRNA_name: NDRG1-ot1, Embedding len: 128
# lncRNA_name: LOC134466, Embedding len: 128
# lncRNA_name: OVAAL, Embedding len: 128
# lncRNA_name: Lnc-SNHG1, Embedding len: 128
# lncRNA_name: SCARNA2, Embedding len: 128
# lncRNA_name: AC003092.1, Embedding len: 128
# lncRNA_name: LINC00619, Embedding len: 128
# lncRNA_name: LINP1, Embedding len: 128
# lncRNA_name: PENG, Embedding len: 128
# lncRNA_name: LINC00691, Embedding len: 128
# lncRNA_name: SLC25A15, Embedding len: 128
# lncRNA_name: OTUD6B-AS1, Embedding len: 128
# lncRNA_name: LINC00114, Embedding len: 128
# lncRNA_name: CTC, Embedding len: 128
# lncRNA_name: LINC01352, Embedding len: 128
# lncRNA_name: PLACT1, Embedding len: 128
# lncRNA_name: GAS5-AS1, Embedding len: 128
# lncRNA_name: LINC00160, Embedding len: 128
# lncRNA_name: MST1P2, Embedding len: 128
# lncRNA_name: AC091729.7, Embedding len: 128
# lncRNA_name: AGER-1, Embedding len: 128
# lncRNA_name: LINC02245, Embedding len: 128
# lncRNA_name: ASMTL-AS1, Embedding len: 128
# lncRNA_name: BAN, Embedding len: 128
# lncRNA_name: NCK-AS1, Embedding len: 128
# lncRNA_name: MX1, Embedding len: 128
# lncRNA_name: lnc-BMP1-1, Embedding len: 128
# lncRNA_name: DLGAP1-AS2, Embedding len: 128
# lncRNA_name: CRAL, Embedding len: 128
# lncRNA_name: RAD21, Embedding len: 128
# lncRNA_name: C2orf92, Embedding len: 128
# lncRNA_name: GMDS-DT, Embedding len: 128
# lncRNA_name: LINC02882, Embedding len: 128
# lncRNA_name: TSPOAP1-AS1, Embedding len: 128
# lncRNA_name: LINC00265, Embedding len: 128
# lncRNA_name: lncRNA-14327.1, Embedding len: 128
# lncRNA_name: ZFAT-AS1, Embedding len: 128
# lncRNA_name: LINC01088, Embedding len: 128
# lncRNA_name: STARD13-AS, Embedding len: 128
# lncRNA_name: LINRIS, Embedding len: 128
# lncRNA_name: MYCNOS, Embedding len: 128
# lncRNA_name: MBNL1-AS1, Embedding len: 128
# lncRNA_name: LINC01111, Embedding len: 128
# lncRNA_name: PRKCZ-AS1, Embedding len: 128
# lncRNA_name: uc061hsf.1, Embedding len: 128
# lncRNA_name: ID2-AS1, Embedding len: 128
# lncRNA_name: RP11-468E2.5, Embedding len: 128
# lncRNA_name: RBMS3-AS3, Embedding len: 128
# lncRNA_name: PRECSIT, Embedding len: 128
# lncRNA_name: WWTR1-AS1, Embedding len: 128
# lncRNA_name: H22954, Embedding len: 128
# lncRNA_name: AK002107, Embedding len: 128
# lncRNA_name: SMAD5-AS1, Embedding len: 128
# lncRNA_name: LINC00994, Embedding len: 128
# lncRNA_name: ST3GAL6-AS1, Embedding len: 128
# lncRNA_name: COL1A1-014, Embedding len: 128
# lncRNA_name: PSTPIP1, Embedding len: 128
# lncRNA_name: LOC105372579, Embedding len: 128
# lncRNA_name: LncRNA-SRA1, Embedding len: 128
# lncRNA_name: NOC2L-4.1, Embedding len: 128
# lncRNA_name: lnc-ELF209, Embedding len: 128
# lncRNA_name: PYCARD-AS1, Embedding len: 128
# lncRNA_name: RP1, Embedding len: 128
# lncRNA_name: C1QTNF1-AS1, Embedding len: 128
# lncRNA_name: Lnc-NA, Embedding len: 128
# lncRNA_name: SMIM31, Embedding len: 128
# lncRNA_name: GEHT1, Embedding len: 128
# lncRNA_name: EPB41L4A-DT, Embedding len: 128
# lncRNA_name: HIF2PUT, Embedding len: 128
# lncRNA_name: URRCC, Embedding len: 128
# lncRNA_name: SANT1, Embedding len: 128
# lncRNA_name: TNRC6C-AS1, Embedding len: 128
# lncRNA_name: GATD3, Embedding len: 128
# lncRNA_name: LOC730100, Embedding len: 128
# lncRNA_name: KB-1471A8.2, Embedding len: 128
# lncRNA_name: LINC02041, Embedding len: 128
# lncRNA_name: SLC25A5-AS1, Embedding len: 128
# lncRNA_name: HOXB-AS1, Embedding len: 128
# lncRNA_name: FGF13-AS1, Embedding len: 128
# lncRNA_name: TUBA4B, Embedding len: 128
# lncRNA_name: PICART1, Embedding len: 128
# lncRNA_name: TCAM1P-004, Embedding len: 128
# lncRNA_name: RP11-598D14.1, Embedding len: 128
# lncRNA_name: C3orf85, Embedding len: 128
# lncRNA_name: LINC01305, Embedding len: 128
# lncRNA_name: SEMA3B-AS1, Embedding len: 128
# lncRNA_name: LINC02465, Embedding len: 128
# lncRNA_name: PHACTR2-AS1, Embedding len: 128
# lncRNA_name: LINC00612, Embedding len: 128
# lncRNA_name: NONHSAT141924, Embedding len: 128
# lncRNA_name: LINC01134, Embedding len: 128
# lncRNA_name: ZNF710-AS1-202, Embedding len: 128
# lncRNA_name: ACTG1P25, Embedding len: 128
# lncRNA_name: LY6E-DT, Embedding len: 128
# lncRNA_name: LINC01354, Embedding len: 128
# lncRNA_name: MIR17HG, Embedding len: 128
# lncRNA_name: SSATX, Embedding len: 128
# lncRNA_name: RNA00887, Embedding len: 128
# lncRNA_name: LINC00887, Embedding len: 128
# lncRNA_name: TRG-AS1, Embedding len: 128
# lncRNA_name: LINC00689, Embedding len: 128
# lncRNA_name: PXN-AS1-L, Embedding len: 128
# lncRNA_name: LINC01018, Embedding len: 128
# lncRNA_name: LOC105369748, Embedding len: 128
# lncRNA_name: LINC02023, Embedding len: 128
# lncRNA_name: LMCD1-AS1, Embedding len: 128
# lncRNA_name: LINC00886, Embedding len: 128
# lncRNA_name: LOC646329, Embedding len: 128
# lncRNA_name: LINC01714, Embedding len: 128
# lncRNA_name: MITF-SOX10, Embedding len: 128
# lncRNA_name: LINC00857, Embedding len: 128
# lncRNA_name: HMMR-AS1, Embedding len: 128
# lncRNA_name: RP11-476D10.1, Embedding len: 128
# lncRNA_name: LINC01857, Embedding len: 128
# lncRNA_name: LINC00304, Embedding len: 128
# lncRNA_name: MIR2052HG, Embedding len: 128
# lncRNA_name: LINC01048, Embedding len: 128
# lncRNA_name: RP5-916L7.2, Embedding len: 128
# lncRNA_name: LINC00336, Embedding len: 128
# lncRNA_name: DCST1-AS1, Embedding len: 128
# lncRNA_name: SAP30L-AS1, Embedding len: 128
# lncRNA_name: HOXC-AS1, Embedding len: 128
# lncRNA_name: LINC02273, Embedding len: 128
# lncRNA_name: LINC00459, Embedding len: 128
# lncRNA_name: SSTR5-AS1, Embedding len: 128
# lncRNA_name: LCAT1, Embedding len: 128
# lncRNA_name: XLOC_001659, Embedding len: 128
# lncRNA_name: CASC21, Embedding len: 128
# lncRNA_name: LINC00629, Embedding len: 128
# lncRNA_name: ARHGAP27P1, Embedding len: 128
# lncRNA_name: GATA2-AS1, Embedding len: 128
# lncRNA_name: HOXC-AS2, Embedding len: 128
# lncRNA_name: MYOSLID, Embedding len: 128
# lncRNA_name: Linc-00313, Embedding len: 128
# lncRNA_name: sONE, Embedding len: 128
# lncRNA_name: ENST00000413528, Embedding len: 128
# lncRNA_name: SLNCR1, Embedding len: 128
# lncRNA_name: LOXL1-AS, Embedding len: 128
# lncRNA_name: GSTP1P1, Embedding len: 128
# lncRNA_name: MIR7-3HG, Embedding len: 128
# lncRNA_name: LINC00311, Embedding len: 128
# lncRNA_name: LINC00400, Embedding len: 128
# lncRNA_name: LEF-AS1, Embedding len: 128
# lncRNA_name: LINC00976, Embedding len: 128
# lncRNA_name: RAB5IF, Embedding len: 128
# lncRNA_name: LINC00470, Embedding len: 128
# lncRNA_name: ROCR, Embedding len: 128
# lncRNA_name: HHIP-AS1, Embedding len: 128
# lncRNA_name: LINC00645, Embedding len: 128
# lncRNA_name: lnc-SLC4A1-1, Embedding len: 128
# lncRNA_name: PXN-AS1, Embedding len: 128
# lncRNA_name: NONHSAT101069, Embedding len: 128
# lncRNA_name: UFC1, Embedding len: 128
# lncRNA_name: LINC81507, Embedding len: 128
# lncRNA_name: NR4A1AS, Embedding len: 128
# lncRNA_name: LINC02862, Embedding len: 128
# lncRNA_name: STXBP5-AS1, Embedding len: 128
# lncRNA_name: F11-AS1, Embedding len: 128
# lncRNA_name: LINC01061, Embedding len: 128
# lncRNA_name: AC016405.3, Embedding len: 128
# lncRNA_name: NR_023387, Embedding len: 128
# lncRNA_name: ADAMTS9-AS1, Embedding len: 128
# lncRNA_name: FGF14-AS2, Embedding len: 128
# lncRNA_name: LINC00488, Embedding len: 128
# lncRNA_name: RAMP2-AS1, Embedding len: 128
# lncRNA_name: LINC00519, Embedding len: 128
# lncRNA_name: TLR8-AS1, Embedding len: 128
# lncRNA_name: NRIR, Embedding len: 128
# lncRNA_name: MRPL23-AS0, Embedding len: 128
# lncRNA_name: MRPL23-AS1, Embedding len: 128
# lncRNA_name: ASB16-AS1, Embedding len: 128
# lncRNA_name: LINC01783, Embedding len: 128
# lncRNA_name: HMGA2-AS1, Embedding len: 128
# lncRNA_name: AC093818.1, Embedding len: 128
# lncRNA_name: CP, Embedding len: 128
# lncRNA_name: LINC02835, Embedding len: 128
# lncRNA_name: RBM5-AS1, Embedding len: 128
# lncRNA_name: HLA-F-AS1, Embedding len: 128
# lncRNA_name: AC114812.8, Embedding len: 128
# lncRNA_name: LncCCAT1, Embedding len: 128
# lncRNA_name: LNMAT2, Embedding len: 128
# lncRNA_name: lncRNA-CTS, Embedding len: 128
# lncRNA_name: PDPK2P, Embedding len: 128
# lncRNA_name: FAM225A, Embedding len: 128
# lncRNA_name: LINC01551, Embedding len: 128
# lncRNA_name: lncAPP, Embedding len: 128
# lncRNA_name: LINC00504, Embedding len: 128
# lncRNA_name: LINC01980, Embedding len: 128
# lncRNA_name: LOC101927746, Embedding len: 128
# lncRNA_name: MIR570MG, Embedding len: 128
# lncRNA_name: WFDC21P, Embedding len: 128
# lncRNA_name: LCAL1, Embedding len: 128
# lncRNA_name: TSLD8, Embedding len: 128
# lncRNA_name: PBB12, Embedding len: 128
# lncRNA_name: GNAS-AS1, Embedding len: 128
# lncRNA_name: LINC00536, Embedding len: 128
# lncRNA_name: HORAS5, Embedding len: 128
# lncRNA_name: LINC01555, Embedding len: 128
# lncRNA_name: LINC01170, Embedding len: 128
# lncRNA_name: PSMG3-AS1, Embedding len: 128
# lncRNA_name: lncOGFRP1, Embedding len: 128
# lncRNA_name: ST7-AS1, Embedding len: 128
# lncRNA_name: FRMD6-AS2, Embedding len: 128
# lncRNA_name: SOD2, Embedding len: 128
# lncRNA_name: lncRNA-AC078883.3, Embedding len: 128
# lncRNA_name: NHEG1, Embedding len: 128
# lncRNA_name: TGLC15, Embedding len: 128
# lncRNA_name: VPS13B-DT, Embedding len: 128
# lncRNA_name: RP11-361F15.2, Embedding len: 128
# lncRNA_name: FAM201A, Embedding len: 128
# lncRNA_name: LINC00682, Embedding len: 128
# lncRNA_name: PSMB8-AS1, Embedding len: 128
# lncRNA_name: CACS15, Embedding len: 128
# lncRNA_name: Unigene56159, Embedding len: 128
# lncRNA_name: AC007271.3, Embedding len: 128
# lncRNA_name: IL1R1-AS1, Embedding len: 128
# lncRNA_name: LncRNA-HGBC, Embedding len: 128
# lncRNA_name: MATN1-AS1, Embedding len: 128
# lncRNA_name: LNCOG, Embedding len: 128
# lncRNA_name: LINC02582, Embedding len: 128
# lncRNA_name: LINC00243, Embedding len: 128
# lncRNA_name: IDH1-AS1, Embedding len: 128
# lncRNA_name: CTC-497E21.4, Embedding len: 128
# lncRNA_name: LINC00997, Embedding len: 128
# lncRNA_name: MTA2TR, Embedding len: 128
# lncRNA_name: BC050642, Embedding len: 128
# lncRNA_name: SDPR-AS, Embedding len: 128
# lncRNA_name: RP5-1120P11.3, Embedding len: 128
# lncRNA_name: AK027294, Embedding len: 128
# lncRNA_name: SOD2-OT1, Embedding len: 128
# lncRNA_name: SNAI3-AS1, Embedding len: 128
# lncRNA_name: LNRRIL6, Embedding len: 128
# lncRNA_name: KCNMA1-AS1, Embedding len: 128
# lncRNA_name: MELTF, Embedding len: 128
# lncRNA_name: RP11-732M18.3, Embedding len: 128
# lncRNA_name: IRF1-AS, Embedding len: 128
# lncRNA_name: ATXN8OS, Embedding len: 128
# lncRNA_name: n384546, Embedding len: 128
# lncRNA_name: OSER1-DT, Embedding len: 128
# lncRNA_name: LINC00115, Embedding len: 128
# lncRNA_name: LINC01096, Embedding len: 128
# lncRNA_name: LDC1P, Embedding len: 128
# lncRNA_name: OECC, Embedding len: 128
# lncRNA_name: GIAT4RA, Embedding len: 128
# lncRNA_name: KRT19P3, Embedding len: 128
# lncRNA_name: ECRG4, Embedding len: 128
# lncRNA_name: CAVIN2-AS1, Embedding len: 128
# lncRNA_name: LINC00423, Embedding len: 128
# lncRNA_name: LINC01287, Embedding len: 128
# lncRNA_name: FAM224A, Embedding len: 128
# lncRNA_name: LINC01391, Embedding len: 128
# lncRNA_name: CLRN1-AS1, Embedding len: 128
# lncRNA_name: YWHAE, Embedding len: 128
# lncRNA_name: LINC00526, Embedding len: 128
# lncRNA_name: LINC01355, Embedding len: 128
# lncRNA_name: HCG22, Embedding len: 128
# lncRNA_name: CACNA1G-AS1, Embedding len: 128
# lncRNA_name: SCAT1, Embedding len: 128
# lncRNA_name: LINC01559, Embedding len: 128
# lncRNA_name: LASP1-AS, Embedding len: 128
# lncRNA_name: NBDY, Embedding len: 128
# lncRNA_name: ITIH4-AS1, Embedding len: 128
# lncRNA_name: PAXIP1-DT, Embedding len: 128
# lncRNA_name: BFAL1, Embedding len: 128
# lncRNA_name: NONHSAT113026, Embedding len: 128
# lncRNA_name: TALAM1, Embedding len: 128
# lncRNA_name: AP002754.2, Embedding len: 128
# lncRNA_name: DIO3OS, Embedding len: 128
# lncRNA_name: NRSN2-AS1, Embedding len: 128
# lncRNA_name: ZFAS2, Embedding len: 128
# lncRNA_name: ENST00000609697, Embedding len: 128
# lncRNA_name: circRNA_000543, Embedding len: 128
# lncRNA_name: FAM87A, Embedding len: 128
# lncRNA_name: PVTL5, Embedding len: 128
# lncRNA_name: SCIRT, Embedding len: 128
# lncRNA_name: Hmrhl, Embedding len: 128
# lncRNA_name: HOMER3-AS1, Embedding len: 128
# lncRNA_name: Moshe, Embedding len: 128
# lncRNA_name: Uc003xsl.1, Embedding len: 128
# lncRNA_name: LINC00475, Embedding len: 128
# lncRNA_name: LINC01152, Embedding len: 128
# lncRNA_name: SAMD12-AS2, Embedding len: 128
# lncRNA_name: Gm44593, Embedding len: 128
# lncRNA_name: GABARAPL2, Embedding len: 128
# lncRNA_name: CHRNB2, Embedding len: 128
# lncRNA_name: IL21-AS1, Embedding len: 128
# lncRNA_name: CASC9-1, Embedding len: 128
# lncRNA_name: MIR600HG, Embedding len: 128
# lncRNA_name: UBA6-DT, Embedding len: 128
# lncRNA_name: TEX41, Embedding len: 128
# lncRNA_name: LOC100507144, Embedding len: 128
# lncRNA_name: LINC01615, Embedding len: 128
# lncRNA_name: DUBR, Embedding len: 128
# lncRNA_name: FOXP4-AS, Embedding len: 128
# lncRNA_name: KDM4A-AS1, Embedding len: 128
# lncRNA_name: LINC00491, Embedding len: 128
# lncRNA_name: LAMTOR5-AS1, Embedding len: 128
# lncRNA_name: HSPA7, Embedding len: 128
# lncRNA_name: PKMYT1AR, Embedding len: 128
# lncRNA_name: RP5-857K21.7, Embedding len: 128
# lncRNA_name: circ-PSEN1, Embedding len: 128
# lncRNA_name: RP11-838N2.4, Embedding len: 128
# lncRNA_name: HCCL5, Embedding len: 128
# lncRNA_name: lncWDR59, Embedding len: 128
# lncRNA_name: GCASPC, Embedding len: 128
# lncRNA_name: PRINS, Embedding len: 128
# lncRNA_name: ERICD, Embedding len: 128
# lncRNA_name: lnc-IL7R, Embedding len: 128
# lncRNA_name: AK055347, Embedding len: 128
# lncRNA_name: lncRNA-numb, Embedding len: 128
# lncRNA_name: AK056155, Embedding len: 128
# lncRNA_name: BX647187, Embedding len: 128
# lncRNA_name: FRGCA, Embedding len: 128
# lncRNA_name: AF339813, Embedding len: 128
# lncRNA_name: MRLN, Embedding len: 128
# lncRNA_name: LINC01541, Embedding len: 128
# lncRNA_name: PAX8<U+2011>AS1:28, Embedding len: 128
# lncRNA_name: FIRRE, Embedding len: 128
# lncRNA_name: SUSAJ1, Embedding len: 128
# lncRNA_name: FARSA-AS1, Embedding len: 128
# lncRNA_name: lnc-FANCI-2, Embedding len: 128
# lncRNA_name: LncMyoD, Embedding len: 128
# lncRNA_name: SEPTIN6, Embedding len: 128
# lncRNA_name: PAN RNA, Embedding len: 128
# lncRNA_name: LINC01546, Embedding len: 128
# lncRNA_name: LOC101928316, Embedding len: 128
# lncRNA_name: MAFTRR, Embedding len: 128
# lncRNA_name: THAP7-AS1, Embedding len: 128
# lncRNA_name: CCSlnc362, Embedding len: 128
# lncRNA_name: LINC00165, Embedding len: 128
# lncRNA_name: NONHSAT112228.2, Embedding len: 128
# lncRNA_name: LETR1, Embedding len: 128
# lncRNA_name: lncRNA-Glu, Embedding len: 128
# lncRNA_name: lncRNA©\ATB, Embedding len: 128
# lncRNA_name: UGP2, Embedding len: 128
# lncRNA_name: NLUCAT1, Embedding len: 128
# lncRNA_name: LncRNA-Y5, Embedding len: 128

# %%
import torch

# Load the file
file_path = "/Users/tunaseckin/Desktop/ML4RG/ML4RG-group-17/lncRNA_embedding.pt"
data = torch.load(file_path)

# Inspect type
print(f"Type of loaded object: {type(data)}")

# If it's a dictionary
if isinstance(data, dict):
    print(f"Number of items: {len(data)}")
    keys = list(data.keys())[:5]
    print(f"First 5 keys: {keys}")
    print(f"Shape of first embedding: {data[keys[0]].shape if hasattr(data[keys[0]], 'shape') else type(data[keys[0]])}")

# If it's a tensor
elif isinstance(data, torch.Tensor):
    print(f"Tensor shape: {data.shape}")
    print(f"Tensor dtype: {data.dtype}")

# Other types
else:
    print(f"Unhandled type: {type(data)}")
# Out:
# Type of loaded object: <class 'torch.Tensor'>
# Tensor shape: torch.Size([1333, 128])
# Tensor dtype: torch.float32

# %%
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader, random_split
from sklearn.metrics import f1_score, roc_auc_score, precision_score, recall_score
import random

# Set random seeds for reproducibility
random.seed(42)
np.random.seed(42)
torch.manual_seed(42)

# Load BioBERT embeddings dictionary
embeddings = np.load("/Users/tunaseckin/Desktop/ML4RG/ML4RG-group-17/all_biobert_embeddings_128_dim (1).npy", allow_pickle=True).item()
embeddings = np.load("/Users/tunaseckin/Desktop/ML4RG/ML4RG-group-17/all_biobert_embeddings_50_dim.npy", allow_pickle=True).item()
#embeddings = np.load("/Users/tunaseckin/Desktop/ML4RG/ML4RG-group-17/node_embeddings_50d.pkl", allow_pickle=True)
embeddings = np.load("/Users/tunaseckin/Desktop/ML4RG/ML4RG-group-17/lncrna_to_embedding.pkl", allow_pickle=True)
# Load target table
final_df = pd.read_csv("/Users/tunaseckin/Desktop/ML4RG/ML4RG-group-17/final.tsv", sep="\t")

# Define target columns
lfc_columns = [
    'LN18.LFC', 'LN229.LFC', 'A549.LFC',
    'NCIH460.LFC', 'KP4.LFC', 'MIAPACA2.LFC'
]

# Build X and Y for LFC tasks
X = []
Ys = {col: [] for col in lfc_columns}
gene_ids = []

for gene, emb in embeddings.items():
    row = final_df[final_df["incoming"] == gene]
    if not row.empty:
        row = row.iloc[0]
        if not row[lfc_columns].isnull().any():
            X.append(emb)
            for col in lfc_columns:
                Ys[col].append(1 if row[col] > 0 else 0)  # Binary classification
            gene_ids.append(gene)

X = np.array(X).astype(np.float32)
Ys = {col: np.array(labels).astype(np.int64) for col, labels in Ys.items()}

print(f"Input shape: {X.shape}")
for col in lfc_columns:
    print(f"{col} label distribution: {np.bincount(Ys[col])}")
# Out:
# Input shape: (451, 128)
# LN18.LFC label distribution: [334 117]
# LN229.LFC label distribution: [315 136]
# A549.LFC label distribution: [302 149]
# NCIH460.LFC label distribution: [325 126]
# KP4.LFC label distribution: [321 130]
# MIAPACA2.LFC label distribution: [327 124]

# %%
# Load Node embeddings dictionary
embeddings_dict = np.load("/Users/tunaseckin/Desktop/ML4RG/ML4RG-group-17/node_embeddings_50d.pkl", allow_pickle=True)
lncrna_embeddings = embeddings_dict.get('lncRNA')  # shape: (1333, 50)
lncrna_embeddings = embeddings_dict.get("lncRNA")
if lncrna_embeddings is None:
    raise ValueError("lncRNA embeddings not found in the file")

# %%
for k,v in embeddings_dict.items():
    print(k)
# Out:
# miRNA
# PCG
# TF
# lncRNA
# snoRNA
# circRNA

# %%
lncrna_embeddings.shape
# Out:
# (1333, 50)

# %%
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader, random_split
from sklearn.metrics import f1_score, roc_auc_score, precision_score, recall_score
import random

# Set random seeds for reproducibility
random.seed(42)
np.random.seed(42)
torch.manual_seed(42)

# Load Node embeddings dictionary
embeddings_dict = np.load("/Users/tunaseckin/Desktop/ML4RG/ML4RG-group-17/node_embeddings_50d.pkl", allow_pickle=True)
lncrna_embeddings = embeddings_dict.get('lncRNA')  # shape: (1333, 50)

# Load target table
final_df = pd.read_csv("/Users/tunaseckin/Desktop/ML4RG/ML4RG-group-17/final.tsv", sep="\t")

# Define target columns
lfc_columns = [
    'LN18.LFC', 'LN229.LFC', 'A549.LFC',
    'NCIH460.LFC', 'KP4.LFC', 'MIAPACA2.LFC'
]

# Build X and Y for LFC tasks
X = []
Ys = {col: [] for col in lfc_columns}
gene_ids = []

for i, row in final_df.iterrows():
    gene = row['incoming']
    if gene in embeddings_dict['lncRNA']:
        emb_index = list(embeddings_dict['lncRNA']).index(gene)
        embedding = lncrna_embeddings[emb_index]
        if not row[lfc_columns].isnull().any():
            X.append(embedding)
            for col in lfc_columns:
                Ys[col].append(1 if row[col] > 0 else 0)
            gene_ids.append(gene)

X = np.array(X).astype(np.float32)
Ys = {col: np.array(labels).astype(np.int64) for col, labels in Ys.items()}

print(f"Input shape: {X.shape}")
for col in lfc_columns:
    print(f"{col} label distribution: {np.bincount(Ys[col])}")
# Out:
# Input shape: (0,)
# LN18.LFC label distribution: []
# LN229.LFC label distribution: []
# A549.LFC label distribution: []
# NCIH460.LFC label distribution: []
# KP4.LFC label distribution: []
# MIAPACA2.LFC label distribution: []

# %%
class LFCDataset(Dataset):
    def __init__(self, X, y):
        self.X = torch.tensor(X, dtype=torch.float32)
        self.y = torch.tensor(y, dtype=torch.long)

    def __len__(self):
        return len(self.X)

    def __getitem__(self, idx):
        return self.X[idx], self.y[idx]

# %%
class MLPBinaryClassifier(nn.Module):
    def __init__(self, input_dim=128):
        super().__init__()
        self.model = nn.Sequential(
            nn.Linear(input_dim, 64),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(64, 2)  # Output logits for binary classification
        )

    def forward(self, x):
        return self.model(x)

# %%
class MLPBinaryClassifier(nn.Module):
    def __init__(self, input_dim=128):
        super().__init__()
        self.model = nn.Sequential(
            nn.Linear(input_dim, 128),
            nn.GELU(),
            nn.Dropout(0.3),
            nn.Linear(128, 64),
            nn.GELU(),
            nn.Dropout(0.2),
            nn.Linear(64, 2)
        )

    def forward(self, x):
        return self.model(x)

# %%
from torch.nn.functional import cross_entropy
from copy import deepcopy

def train_single_lfc_task(X, y, task_name, epochs=100, patience=15, batch_size=2, lr=1e-3):
    dataset = LFCDataset(X, y)
    train_len = int(0.8 * len(dataset))
    val_len = len(dataset) - train_len
    train_set, val_set = random_split(dataset, [train_len, val_len])

    train_loader = DataLoader(train_set, batch_size=batch_size, shuffle=True)
    val_loader = DataLoader(val_set, batch_size=batch_size)

    model = MLPBinaryClassifier(input_dim=X.shape[1])
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    model.to(device)

    # Compute pos_weight to handle imbalance
    y_train = torch.tensor([y for _, y in train_set])
    pos_weight_val = (len(y_train) - y_train.sum()) / y_train.sum()
    pos_weight = torch.tensor(pos_weight_val, dtype=torch.float32).to(device)
    criterion = nn.CrossEntropyLoss(weight=torch.tensor([1.0, pos_weight.item()]).to(device))
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)

    best_val_loss = float("inf")
    best_model = None
    patience_counter = 0

    for epoch in range(epochs):
        model.train()
        total_loss = 0
        for xb, yb in train_loader:
            xb, yb = xb.to(device), yb.to(device)
            logits = model(xb)
            loss = criterion(logits, yb)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            total_loss += loss.item()

        avg_train_loss = total_loss / len(train_loader)

        # Validation
        model.eval()
        val_loss = 0
        with torch.no_grad():
            for xb, yb in val_loader:
                xb, yb = xb.to(device), yb.to(device)
                logits = model(xb)
                loss = criterion(logits, yb)
                val_loss += loss.item()

        avg_val_loss = val_loss / len(val_loader)
        print(f"[{task_name}] Epoch {epoch+1}: Train Loss = {avg_train_loss:.4f}, Val Loss = {avg_val_loss:.4f}")

        if avg_val_loss < best_val_loss:
            best_val_loss = avg_val_loss
            best_model = deepcopy(model.state_dict())
            patience_counter = 0
        else:
            patience_counter += 1
            if patience_counter >= patience:
                print(f"[{task_name}] Early stopping triggered.")
                break

    # Load best model
    model.load_state_dict(best_model)

    # Evaluation
    model.eval()
    all_true, all_pred = [], []
    with torch.no_grad():
        for xb, yb in DataLoader(dataset, batch_size=batch_size):
            xb = xb.to(device)
            logits = model(xb)
            preds = logits.argmax(dim=1).cpu().numpy()
            all_true.extend(yb.numpy())
            all_pred.extend(preds)

    y_true = np.array(all_true)
    y_pred = np.array(all_pred)
    f1 = f1_score(y_true, y_pred, zero_division=0)
    precision = precision_score(y_true, y_pred, zero_division=0)
    recall = recall_score(y_true, y_pred, zero_division=0)
    try:
        auc = roc_auc_score(y_true, y_pred)
    except:
        auc = float("nan")

    print(f"[{task_name}] F1 = {f1:.3f}, Precision = {precision:.3f}, Recall = {recall:.3f}, ROC-AUC = {auc:.3f}")

# %%
for i, task in enumerate(lfc_columns):
    print(f"\nTraining for task: {task}")
    train_single_lfc_task(X, Ys[task], task_name=task)
# Out:
# Training for task: LN18.LFC
# [LN18.LFC] Epoch 1: Train Loss = 0.6868, Val Loss = 0.6633
# /var/folders/jq/4s6sf2812b90mbpcbf2wyg1w0000gn/T/ipykernel_53787/2719341610.py:20: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   pos_weight = torch.tensor(pos_weight_val, dtype=torch.float32).to(device)
# [LN18.LFC] Epoch 2: Train Loss = 0.6550, Val Loss = 0.6460
# [LN18.LFC] Epoch 3: Train Loss = 0.6517, Val Loss = 0.6398
# [LN18.LFC] Epoch 4: Train Loss = 0.6333, Val Loss = 0.6887
# [LN18.LFC] Epoch 5: Train Loss = 0.6079, Val Loss = 0.6840
# [LN18.LFC] Epoch 6: Train Loss = 0.5985, Val Loss = 0.6826
# [LN18.LFC] Epoch 7: Train Loss = 0.6213, Val Loss = 0.7365
# [LN18.LFC] Epoch 8: Train Loss = 0.5840, Val Loss = 0.7591
# [LN18.LFC] Epoch 9: Train Loss = 0.5788, Val Loss = 0.7550
# [LN18.LFC] Epoch 10: Train Loss = 0.5720, Val Loss = 0.7674
# [LN18.LFC] Epoch 11: Train Loss = 0.5791, Val Loss = 0.7720
# [LN18.LFC] Epoch 12: Train Loss = 0.5500, Val Loss = 0.8575
# [LN18.LFC] Epoch 13: Train Loss = 0.5462, Val Loss = 0.8083
# [LN18.LFC] Epoch 14: Train Loss = 0.5419, Val Loss = 0.8099
# [LN18.LFC] Epoch 15: Train Loss = 0.5350, Val Loss = 0.8851
# [LN18.LFC] Epoch 16: Train Loss = 0.5328, Val Loss = 0.8836
# [LN18.LFC] Epoch 17: Train Loss = 0.5165, Val Loss = 0.9081
# [LN18.LFC] Epoch 18: Train Loss = 0.5239, Val Loss = 0.8446
# [LN18.LFC] Early stopping triggered.
# [LN18.LFC] F1 = 0.161, Precision = 0.550, Recall = 0.094, ROC-AUC = 0.534
#
# Training for task: LN229.LFC
# [LN229.LFC] Epoch 1: Train Loss = 0.6984, Val Loss = 0.6881
# [LN229.LFC] Epoch 2: Train Loss = 0.6615, Val Loss = 0.7010
# /var/folders/jq/4s6sf2812b90mbpcbf2wyg1w0000gn/T/ipykernel_53787/2719341610.py:20: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   pos_weight = torch.tensor(pos_weight_val, dtype=torch.float32).to(device)
# [LN229.LFC] Epoch 3: Train Loss = 0.6487, Val Loss = 0.7243
# [LN229.LFC] Epoch 4: Train Loss = 0.6503, Val Loss = 0.7105
# [LN229.LFC] Epoch 5: Train Loss = 0.6320, Val Loss = 0.7169
# [LN229.LFC] Epoch 6: Train Loss = 0.6257, Val Loss = 0.7133
# [LN229.LFC] Epoch 7: Train Loss = 0.6243, Val Loss = 0.7361
# [LN229.LFC] Epoch 8: Train Loss = 0.6258, Val Loss = 0.7746
# [LN229.LFC] Epoch 9: Train Loss = 0.6067, Val Loss = 0.7338
# [LN229.LFC] Epoch 10: Train Loss = 0.6113, Val Loss = 0.7193
# [LN229.LFC] Epoch 11: Train Loss = 0.6012, Val Loss = 0.7731
# [LN229.LFC] Epoch 12: Train Loss = 0.6019, Val Loss = 0.7513
# [LN229.LFC] Epoch 13: Train Loss = 0.6016, Val Loss = 0.7456
# [LN229.LFC] Epoch 14: Train Loss = 0.5962, Val Loss = 0.7621
# [LN229.LFC] Epoch 15: Train Loss = 0.5778, Val Loss = 0.7466
# [LN229.LFC] Epoch 16: Train Loss = 0.5825, Val Loss = 0.7689
# [LN229.LFC] Early stopping triggered.
# [LN229.LFC] F1 = 0.056, Precision = 0.500, Recall = 0.029, ROC-AUC = 0.508
#
# Training for task: A549.LFC
# [A549.LFC] Epoch 1: Train Loss = 0.7024, Val Loss = 0.6736
# /var/folders/jq/4s6sf2812b90mbpcbf2wyg1w0000gn/T/ipykernel_53787/2719341610.py:20: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   pos_weight = torch.tensor(pos_weight_val, dtype=torch.float32).to(device)
# [A549.LFC] Epoch 2: Train Loss = 0.6778, Val Loss = 0.6252
# [A549.LFC] Epoch 3: Train Loss = 0.6614, Val Loss = 0.6769
# [A549.LFC] Epoch 4: Train Loss = 0.6601, Val Loss = 0.6511
# [A549.LFC] Epoch 5: Train Loss = 0.6412, Val Loss = 0.6583
# [A549.LFC] Epoch 6: Train Loss = 0.6473, Val Loss = 0.6463
# [A549.LFC] Epoch 7: Train Loss = 0.6387, Val Loss = 0.6465
# [A549.LFC] Epoch 8: Train Loss = 0.6264, Val Loss = 0.6666
# [A549.LFC] Epoch 9: Train Loss = 0.6073, Val Loss = 0.6521
# [A549.LFC] Epoch 10: Train Loss = 0.6096, Val Loss = 0.6898
# [A549.LFC] Epoch 11: Train Loss = 0.6069, Val Loss = 0.7037
# [A549.LFC] Epoch 12: Train Loss = 0.6051, Val Loss = 0.6556
# [A549.LFC] Epoch 13: Train Loss = 0.5812, Val Loss = 0.6805
# [A549.LFC] Epoch 14: Train Loss = 0.5820, Val Loss = 0.6923
# [A549.LFC] Epoch 15: Train Loss = 0.5707, Val Loss = 0.6769
# [A549.LFC] Epoch 16: Train Loss = 0.5570, Val Loss = 0.6463
# [A549.LFC] Epoch 17: Train Loss = 0.5401, Val Loss = 0.6464
# [A549.LFC] Early stopping triggered.
# [A549.LFC] F1 = 0.245, Precision = 0.590, Recall = 0.154, ROC-AUC = 0.551
#
# Training for task: NCIH460.LFC
# [NCIH460.LFC] Epoch 1: Train Loss = 0.6895, Val Loss = 0.7131
# /var/folders/jq/4s6sf2812b90mbpcbf2wyg1w0000gn/T/ipykernel_53787/2719341610.py:20: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   pos_weight = torch.tensor(pos_weight_val, dtype=torch.float32).to(device)
# [NCIH460.LFC] Epoch 2: Train Loss = 0.6475, Val Loss = 0.7040
# [NCIH460.LFC] Epoch 3: Train Loss = 0.6339, Val Loss = 0.7224
# [NCIH460.LFC] Epoch 4: Train Loss = 0.6285, Val Loss = 0.7027
# [NCIH460.LFC] Epoch 5: Train Loss = 0.6076, Val Loss = 0.8050
# [NCIH460.LFC] Epoch 6: Train Loss = 0.5930, Val Loss = 0.7326
# [NCIH460.LFC] Epoch 7: Train Loss = 0.5978, Val Loss = 0.7406
# [NCIH460.LFC] Epoch 8: Train Loss = 0.5952, Val Loss = 0.7340
# [NCIH460.LFC] Epoch 9: Train Loss = 0.5717, Val Loss = 0.8974
# [NCIH460.LFC] Epoch 10: Train Loss = 0.5804, Val Loss = 0.7604
# [NCIH460.LFC] Epoch 11: Train Loss = 0.5526, Val Loss = 0.7611
# [NCIH460.LFC] Epoch 12: Train Loss = 0.5451, Val Loss = 0.7841
# [NCIH460.LFC] Epoch 13: Train Loss = 0.5493, Val Loss = 0.8185
# [NCIH460.LFC] Epoch 14: Train Loss = 0.5436, Val Loss = 0.8384
# [NCIH460.LFC] Epoch 15: Train Loss = 0.5325, Val Loss = 0.8456
# [NCIH460.LFC] Epoch 16: Train Loss = 0.5134, Val Loss = 0.7907
# [NCIH460.LFC] Epoch 17: Train Loss = 0.5154, Val Loss = 0.8448
# [NCIH460.LFC] Epoch 18: Train Loss = 0.5173, Val Loss = 0.7993
# [NCIH460.LFC] Epoch 19: Train Loss = 0.5179, Val Loss = 0.8232
# [NCIH460.LFC] Early stopping triggered.
# [NCIH460.LFC] F1 = 0.167, Precision = 0.667, Recall = 0.095, ROC-AUC = 0.538
#
# Training for task: KP4.LFC
# /var/folders/jq/4s6sf2812b90mbpcbf2wyg1w0000gn/T/ipykernel_53787/2719341610.py:20: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   pos_weight = torch.tensor(pos_weight_val, dtype=torch.float32).to(device)
# [KP4.LFC] Epoch 1: Train Loss = 0.6895, Val Loss = 0.7252
# [KP4.LFC] Epoch 2: Train Loss = 0.6444, Val Loss = 0.7098
# [KP4.LFC] Epoch 3: Train Loss = 0.6383, Val Loss = 0.7304
# [KP4.LFC] Epoch 4: Train Loss = 0.6346, Val Loss = 0.7094
# [KP4.LFC] Epoch 5: Train Loss = 0.6312, Val Loss = 0.7345
# [KP4.LFC] Epoch 6: Train Loss = 0.6235, Val Loss = 0.7519
# [KP4.LFC] Epoch 7: Train Loss = 0.5953, Val Loss = 0.7500
# [KP4.LFC] Epoch 8: Train Loss = 0.5968, Val Loss = 0.7720
# [KP4.LFC] Epoch 9: Train Loss = 0.6026, Val Loss = 0.7525
# [KP4.LFC] Epoch 10: Train Loss = 0.5854, Val Loss = 0.8152
# [KP4.LFC] Epoch 11: Train Loss = 0.5825, Val Loss = 0.8350
# [KP4.LFC] Epoch 12: Train Loss = 0.5875, Val Loss = 0.8159
# [KP4.LFC] Epoch 13: Train Loss = 0.5918, Val Loss = 0.8166
# [KP4.LFC] Epoch 14: Train Loss = 0.5601, Val Loss = 0.8444
# [KP4.LFC] Epoch 15: Train Loss = 0.5530, Val Loss = 0.8501
# [KP4.LFC] Epoch 16: Train Loss = 0.5459, Val Loss = 0.8603
# [KP4.LFC] Epoch 17: Train Loss = 0.5457, Val Loss = 0.8251
# [KP4.LFC] Epoch 18: Train Loss = 0.5407, Val Loss = 0.9020
# [KP4.LFC] Epoch 19: Train Loss = 0.5334, Val Loss = 0.8735
# [KP4.LFC] Early stopping triggered.
# [KP4.LFC] F1 = 0.236, Precision = 0.613, Recall = 0.146, ROC-AUC = 0.554
#
# Training for task: MIAPACA2.LFC
# [MIAPACA2.LFC] Epoch 1: Train Loss = 0.6709, Val Loss = 0.7498
# [MIAPACA2.LFC] Epoch 2: Train Loss = 0.6549, Val Loss = 0.7141
# /var/folders/jq/4s6sf2812b90mbpcbf2wyg1w0000gn/T/ipykernel_53787/2719341610.py:20: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   pos_weight = torch.tensor(pos_weight_val, dtype=torch.float32).to(device)
# [MIAPACA2.LFC] Epoch 3: Train Loss = 0.6269, Val Loss = 0.7837
# [MIAPACA2.LFC] Epoch 4: Train Loss = 0.6054, Val Loss = 0.7419
# [MIAPACA2.LFC] Epoch 5: Train Loss = 0.5996, Val Loss = 0.7580
# [MIAPACA2.LFC] Epoch 6: Train Loss = 0.5731, Val Loss = 0.7998
# [MIAPACA2.LFC] Epoch 7: Train Loss = 0.5789, Val Loss = 0.8222
# [MIAPACA2.LFC] Epoch 8: Train Loss = 0.5735, Val Loss = 0.9340
# [MIAPACA2.LFC] Epoch 9: Train Loss = 0.5711, Val Loss = 0.8258
# [MIAPACA2.LFC] Epoch 10: Train Loss = 0.5534, Val Loss = 0.9810
# [MIAPACA2.LFC] Epoch 11: Train Loss = 0.5721, Val Loss = 0.8962
# [MIAPACA2.LFC] Epoch 12: Train Loss = 0.5482, Val Loss = 0.9637
# [MIAPACA2.LFC] Epoch 13: Train Loss = 0.5644, Val Loss = 0.8146
# [MIAPACA2.LFC] Epoch 14: Train Loss = 0.5392, Val Loss = 0.8281
# [MIAPACA2.LFC] Epoch 15: Train Loss = 0.5335, Val Loss = 0.8884
# [MIAPACA2.LFC] Epoch 16: Train Loss = 0.5205, Val Loss = 0.9054
# [MIAPACA2.LFC] Epoch 17: Train Loss = 0.5247, Val Loss = 0.8975
# [MIAPACA2.LFC] Early stopping triggered.
# [MIAPACA2.LFC] F1 = 0.131, Precision = 0.692, Recall = 0.073, ROC-AUC = 0.530

# %%
import matplotlib.pyplot as plt

# Metrics for each task
tasks = ['LN18', 'LN229', 'A549', 'NCIH460', 'KP4', 'MIAPACA2']
f1 =        [0.574, 0.292, 0.393, 0.103, 0.083, 0.031]
precision = [0.659, 0.735, 0.368, 0.700, 0.429, 0.400]
recall =    [0.508, 0.182, 0.420, 0.056, 0.046, 0.016]
roc_auc =   [0.708, 0.577, 0.531, 0.523, 0.511, 0.503]

metrics = {
    'F1 Score': f1,
    'Precision': precision,
    'Recall': recall,
    'ROC-AUC': roc_auc
}

# Plot
plt.figure(figsize=(16, 4))
for i, (name, values) in enumerate(metrics.items(), 1):
    plt.subplot(1, 4, i)
    plt.bar(tasks, values, color='steelblue')
    plt.ylim(0, 1)
    plt.title(name)
    plt.xticks(rotation=45)
    plt.grid(axis='y', linestyle='--', alpha=0.5)

plt.suptitle("Performance Metrics per LFC Task (50D Embeddings)", fontsize=14, y=1.05)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Separate classifers for six sub-types of RRA

# %%
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader, TensorDataset, random_split
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from collections import Counter
import random

# Set random seeds for reproducibility
random.seed(42)
np.random.seed(42)
torch.manual_seed(42)

# Load Node embeddings dictionary
embeddings_dict = np.load("/Users/tunaseckin/Desktop/ML4RG/ML4RG-group-17/lncrna_to_embedding.pkl", allow_pickle=True)

# Load target table
final_df = pd.read_csv("/Users/tunaseckin/Desktop/ML4RG/ML4RG-group-17/final.tsv", sep="\t")

# Define RRA target columns
rra_columns = [
    'LN18.RRAscore', 'LN229.RRAscore', 'A549.RRAscore',
    'NCIH460.RRAscore', 'KP4.RRAscore', 'MIAPACA2.RRAscore'
]

# Build X and Y using 'incoming' column for gene-to-embedding matching
X = []
Ys = {col: [] for col in rra_columns}
gene_ids = []

for gene, emb in embeddings_dict.items():
    row = final_df[final_df["incoming"] == gene]
    if not row.empty:
        row = row.iloc[0]
        if not row[rra_columns].isnull().any():
            X.append(emb)
            for col in rra_columns:
                Ys[col].append(row[col])
            gene_ids.append(gene)

X = np.array(X).astype(np.float32)
Ys = {col: np.array(labels).astype(np.float32) for col, labels in Ys.items()}

print(f"Input shape: {X.shape}")

# --- Convert RRA Scores to Quartile Labels ---
def convert_to_quartile_labels(Ys_dict):
    Ys_quartiles = {}
    for col, values in Ys_dict.items():
        col_labels = np.digitize(values, bins=[0.25, 0.5, 0.75])  # Q0: 0-0.25, Q1: 0.25-0.5, etc.
        print(f"{col} label distribution: {np.bincount(col_labels)}")
        for q in range(4):
            q_vals = values[col_labels == q]
            if len(q_vals) > 0:
                print(f"  Quartile {q}: min={q_vals.min():.4f}, max={q_vals.max():.4f}, count={len(q_vals)}")
        Ys_quartiles[col] = col_labels.astype(np.int64)
    return Ys_quartiles

Y_quartiles = convert_to_quartile_labels(Ys)

# --- Define Model ---
class MLPQuartileClassifier(nn.Module):
    def __init__(self, input_dim=128):
        super().__init__()
        self.model = nn.Sequential(
            nn.Linear(input_dim, 64),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(64, 4)
        )

    def forward(self, x):
        return self.model(x)

# --- Training Pipeline ---
def train_and_evaluate(task_name, input_dim=128, device='cuda', patience=15, max_epochs=200):
    print(f"\n Task: {task_name}")

    y_task = Y_quartiles[task_name]
    X_train, X_test, y_train, y_test = train_test_split(X, y_task, test_size=0.2, stratify=y_task, random_state=42)

    X_train_tensor = torch.tensor(X_train, dtype=torch.float32)
    y_train_tensor = torch.tensor(y_train, dtype=torch.long)
    X_test_tensor = torch.tensor(X_test, dtype=torch.float32)
    y_test_tensor = torch.tensor(y_test, dtype=torch.long)

    full_train_ds = TensorDataset(X_train_tensor, y_train_tensor)
    train_size = int(0.8 * len(full_train_ds))
    val_size = len(full_train_ds) - train_size
    train_ds, val_ds = random_split(full_train_ds, [train_size, val_size])

    train_labels = y_train_tensor[train_ds.indices].numpy()
    class_counts = Counter(train_labels)
    total = sum(class_counts.values())
    weights = [total / class_counts[i] for i in range(4)]
    class_weights = torch.tensor(weights, dtype=torch.float32).to(device)

    train_loader = DataLoader(train_ds, batch_size=4, shuffle=True)
    val_loader = DataLoader(val_ds, batch_size=4)
    test_loader = DataLoader(TensorDataset(X_test_tensor, y_test_tensor), batch_size=4)

    model = MLPQuartileClassifier(input_dim=input_dim).to(device)
    criterion = nn.CrossEntropyLoss(weight=class_weights)
    optimizer = optim.Adam(model.parameters(), lr=1e-3)

    best_val_loss = float('inf')
    best_model_state = None
    patience_counter = 0

    for epoch in range(max_epochs):
        model.train()
        total_loss = 0
        for xb, yb in train_loader:
            xb, yb = xb.to(device), yb.to(device)
            optimizer.zero_grad()
            pred = model(xb)
            loss = criterion(pred, yb)
            loss.backward()
            optimizer.step()
            total_loss += loss.item()

        model.eval()
        val_loss = 0
        with torch.no_grad():
            for xb, yb in val_loader:
                xb, yb = xb.to(device), yb.to(device)
                pred = model(xb)
                loss = criterion(pred, yb)
                val_loss += loss.item()

        print(f"Epoch {epoch+1}: Train Loss = {total_loss:.4f}, Val Loss = {val_loss:.4f}")

        if val_loss < best_val_loss:
            best_val_loss = val_loss
            best_model_state = model.state_dict()
            patience_counter = 0
        else:
            patience_counter += 1
            if patience_counter >= patience:
                print("Early stopping triggered.")
                break

    # Evaluation
    model.load_state_dict(best_model_state)
    model.eval()
    all_preds, all_true = [], []
    with torch.no_grad():
        for xb, yb in test_loader:
            xb = xb.to(device)
            pred = model(xb).argmax(dim=1).cpu().numpy()
            all_preds.extend(pred)
            all_true.extend(yb.numpy())

    print(classification_report(all_true, all_preds, zero_division=0))

# --- Run the RRA Classification Tasks ---
device = "cuda" if torch.cuda.is_available() else "cpu"
for name in rra_columns:
    train_and_evaluate(name, input_dim=X.shape[1], device=device)
# Out:
# Input shape: (451, 128)
# LN18.RRAscore label distribution: [157  84 109 101]
#   Quartile 0: min=0.0000, max=0.2494, count=157
#   Quartile 1: min=0.2505, max=0.4977, count=84
#   Quartile 2: min=0.5030, max=0.7493, count=109
#   Quartile 3: min=0.7563, max=0.9971, count=101
# LN229.RRAscore label distribution: [172  86  82 111]
#   Quartile 0: min=0.0000, max=0.2459, count=172
#   Quartile 1: min=0.2503, max=0.4988, count=86
#   Quartile 2: min=0.5040, max=0.7490, count=82
#   Quartile 3: min=0.7549, max=0.9993, count=111
# A549.RRAscore label distribution: [151 108  94  98]
#   Quartile 0: min=0.0000, max=0.2484, count=151
#   Quartile 1: min=0.2528, max=0.4974, count=108
#   Quartile 2: min=0.5073, max=0.7490, count=94
#   Quartile 3: min=0.7515, max=1.0000, count=98
# NCIH460.RRAscore label distribution: [156  77  96 122]
#   Quartile 0: min=0.0000, max=0.2465, count=156
#   Quartile 1: min=0.2507, max=0.4917, count=77
#   Quartile 2: min=0.5020, max=0.7455, count=96
#   Quartile 3: min=0.7548, max=0.9996, count=122
# KP4.RRAscore label distribution: [159  70  99 123]
#   Quartile 0: min=0.0000, max=0.2499, count=159
#   Quartile 1: min=0.2511, max=0.4993, count=70
#   Quartile 2: min=0.5020, max=0.7494, count=99
#   Quartile 3: min=0.7524, max=0.9985, count=123
# MIAPACA2.RRAscore label distribution: [178  89  72 112]
#   Quartile 0: min=0.0000, max=0.2435, count=178
#   Quartile 1: min=0.2525, max=0.4797, count=89
#   Quartile 2: min=0.5007, max=0.7495, count=72
#   Quartile 3: min=0.7501, max=0.9935, count=112
#
#  Task: LN18.RRAscore
# Epoch 1: Train Loss = 102.2403, Val Loss = 24.9983
# Epoch 2: Train Loss = 97.0571, Val Loss = 25.1257
# Epoch 3: Train Loss = 95.1133, Val Loss = 25.4563
# Epoch 4: Train Loss = 95.3735, Val Loss = 25.8596
# Epoch 5: Train Loss = 90.8283, Val Loss = 25.8887
# Epoch 6: Train Loss = 91.4391, Val Loss = 26.2637
# Epoch 7: Train Loss = 89.6458, Val Loss = 26.3575
# Epoch 8: Train Loss = 86.3496, Val Loss = 26.9373
# Epoch 9: Train Loss = 83.8242, Val Loss = 26.7921
# Epoch 10: Train Loss = 84.0649, Val Loss = 27.3184
# Epoch 11: Train Loss = 80.5300, Val Loss = 28.4916
# Epoch 12: Train Loss = 84.4212, Val Loss = 28.4533
# Epoch 13: Train Loss = 78.8503, Val Loss = 28.1447
# Epoch 14: Train Loss = 75.9336, Val Loss = 28.2715
# Epoch 15: Train Loss = 78.1241, Val Loss = 28.8438
# Epoch 16: Train Loss = 76.4058, Val Loss = 29.1531
# Early stopping triggered.
#               precision    recall  f1-score   support
#
#            0       0.32      0.25      0.28        32
#            1       0.30      0.41      0.35        17
#            2       0.41      0.32      0.36        22
#            3       0.19      0.25      0.22        20
#
#     accuracy                           0.30        91
#    macro avg       0.31      0.31      0.30        91
# weighted avg       0.31      0.30      0.30        91
#
#
#  Task: LN229.RRAscore
# Epoch 1: Train Loss = 102.2529, Val Loss = 25.1656
# Epoch 2: Train Loss = 97.7038, Val Loss = 26.0054
# Epoch 3: Train Loss = 97.0670, Val Loss = 26.3096
# Epoch 4: Train Loss = 94.5136, Val Loss = 26.5570
# Epoch 5: Train Loss = 91.8318, Val Loss = 27.4651
# Epoch 6: Train Loss = 90.4073, Val Loss = 28.1641
# Epoch 7: Train Loss = 89.9970, Val Loss = 27.3964
# Epoch 8: Train Loss = 86.4425, Val Loss = 29.2432
# Epoch 9: Train Loss = 87.4755, Val Loss = 28.6605
# Epoch 10: Train Loss = 86.3355, Val Loss = 29.2806
# Epoch 11: Train Loss = 85.0745, Val Loss = 29.4154
# Epoch 12: Train Loss = 80.8910, Val Loss = 30.0899
# Epoch 13: Train Loss = 82.4633, Val Loss = 29.6770
# Epoch 14: Train Loss = 79.7885, Val Loss = 30.4037
# Epoch 15: Train Loss = 77.0219, Val Loss = 31.5932
# Epoch 16: Train Loss = 76.7490, Val Loss = 31.2397
# Early stopping triggered.
#               precision    recall  f1-score   support
#
#            0       0.42      0.23      0.30        35
#            1       0.09      0.06      0.07        17
#            2       0.06      0.06      0.06        17
#            3       0.27      0.55      0.36        22
#
#     accuracy                           0.24        91
#    macro avg       0.21      0.22      0.20        91
# weighted avg       0.26      0.24      0.23        91
#
#
#  Task: A549.RRAscore
# Epoch 1: Train Loss = 101.8862, Val Loss = 25.6592
# Epoch 2: Train Loss = 97.6606, Val Loss = 25.9920
# Epoch 3: Train Loss = 95.0747, Val Loss = 26.4509
# Epoch 4: Train Loss = 94.3257, Val Loss = 26.5733
# Epoch 5: Train Loss = 93.0253, Val Loss = 27.3843
# Epoch 6: Train Loss = 90.0423, Val Loss = 28.3260
# Epoch 7: Train Loss = 87.9773, Val Loss = 29.6579
# Epoch 8: Train Loss = 86.2032, Val Loss = 28.0986
# Epoch 9: Train Loss = 85.6287, Val Loss = 29.6724
# Epoch 10: Train Loss = 81.1926, Val Loss = 29.9186
# Epoch 11: Train Loss = 83.4996, Val Loss = 29.9091
# Epoch 12: Train Loss = 79.0351, Val Loss = 33.0818
# Epoch 13: Train Loss = 78.3839, Val Loss = 31.6636
# Epoch 14: Train Loss = 76.5946, Val Loss = 31.6179
# Epoch 15: Train Loss = 74.0105, Val Loss = 32.5096
# Epoch 16: Train Loss = 75.7730, Val Loss = 32.4945
# Early stopping triggered.
#               precision    recall  f1-score   support
#
#            0       0.48      0.43      0.46        30
#            1       0.29      0.23      0.26        22
#            2       0.29      0.11      0.15        19
#            3       0.30      0.60      0.40        20
#
#     accuracy                           0.35        91
#    macro avg       0.34      0.34      0.32        91
# weighted avg       0.36      0.35      0.33        91
#
#
#  Task: NCIH460.RRAscore
# Epoch 1: Train Loss = 100.8524, Val Loss = 26.0457
# Epoch 2: Train Loss = 97.5684, Val Loss = 26.6852
# Epoch 3: Train Loss = 96.0913, Val Loss = 26.7174
# Epoch 4: Train Loss = 94.3274, Val Loss = 27.4361
# Epoch 5: Train Loss = 92.9802, Val Loss = 27.8128
# Epoch 6: Train Loss = 91.5259, Val Loss = 28.0103
# Epoch 7: Train Loss = 90.7753, Val Loss = 28.0565
# Epoch 8: Train Loss = 89.8431, Val Loss = 28.8463
# Epoch 9: Train Loss = 87.6245, Val Loss = 29.4923
# Epoch 10: Train Loss = 85.8652, Val Loss = 29.6573
# Epoch 11: Train Loss = 85.1075, Val Loss = 30.6742
# Epoch 12: Train Loss = 85.5432, Val Loss = 30.3464
# Epoch 13: Train Loss = 82.2144, Val Loss = 30.6122
# Epoch 14: Train Loss = 81.2771, Val Loss = 31.7943
# Epoch 15: Train Loss = 81.1263, Val Loss = 31.5450
# Epoch 16: Train Loss = 79.8696, Val Loss = 31.2536
# Early stopping triggered.
#               precision    recall  f1-score   support
#
#            0       0.29      0.19      0.23        31
#            1       0.11      0.06      0.08        16
#            2       0.15      0.16      0.15        19
#            3       0.27      0.44      0.33        25
#
#     accuracy                           0.23        91
#    macro avg       0.20      0.21      0.20        91
# weighted avg       0.22      0.23      0.22        91
#
#
#  Task: KP4.RRAscore
# Epoch 1: Train Loss = 101.7433, Val Loss = 25.4496
# Epoch 2: Train Loss = 98.4675, Val Loss = 25.1546
# Epoch 3: Train Loss = 96.1839, Val Loss = 25.3799
# Epoch 4: Train Loss = 94.7247, Val Loss = 25.9827
# Epoch 5: Train Loss = 93.3913, Val Loss = 26.5046
# Epoch 6: Train Loss = 92.1986, Val Loss = 25.9060
# Epoch 7: Train Loss = 90.7401, Val Loss = 26.0739
# Epoch 8: Train Loss = 90.0143, Val Loss = 26.2751
# Epoch 9: Train Loss = 88.6451, Val Loss = 27.0337
# Epoch 10: Train Loss = 88.3692, Val Loss = 27.2614
# Epoch 11: Train Loss = 85.1107, Val Loss = 27.5290
# Epoch 12: Train Loss = 83.5936, Val Loss = 28.9512
# Epoch 13: Train Loss = 82.1703, Val Loss = 28.3356
# Epoch 14: Train Loss = 82.2520, Val Loss = 29.0635
# Epoch 15: Train Loss = 80.5092, Val Loss = 29.6687
# Epoch 16: Train Loss = 80.6750, Val Loss = 30.7667
# Epoch 17: Train Loss = 78.7409, Val Loss = 30.1392
# Early stopping triggered.
#               precision    recall  f1-score   support
#
#            0       0.38      0.47      0.42        32
#            1       0.17      0.14      0.15        14
#            2       0.26      0.35      0.30        20
#            3       0.17      0.08      0.11        25
#
#     accuracy                           0.29        91
#    macro avg       0.24      0.26      0.24        91
# weighted avg       0.26      0.29      0.27        91
#
#
#  Task: MIAPACA2.RRAscore
# Epoch 1: Train Loss = 102.6424, Val Loss = 25.6481
# Epoch 2: Train Loss = 97.9525, Val Loss = 25.6720
# Epoch 3: Train Loss = 94.6858, Val Loss = 25.9255
# Epoch 4: Train Loss = 93.6873, Val Loss = 26.3193
# Epoch 5: Train Loss = 91.2485, Val Loss = 26.4319
# Epoch 6: Train Loss = 90.1862, Val Loss = 26.9933
# Epoch 7: Train Loss = 88.6851, Val Loss = 26.9851
# Epoch 8: Train Loss = 85.5619, Val Loss = 27.3189
# Epoch 9: Train Loss = 85.4369, Val Loss = 27.9838
# Epoch 10: Train Loss = 85.3504, Val Loss = 27.7212
# Epoch 11: Train Loss = 83.5118, Val Loss = 27.7819
# Epoch 12: Train Loss = 81.9713, Val Loss = 29.0962
# Epoch 13: Train Loss = 81.8572, Val Loss = 28.5960
# Epoch 14: Train Loss = 80.5205, Val Loss = 28.5196
# Epoch 15: Train Loss = 80.1859, Val Loss = 28.5559
# Epoch 16: Train Loss = 76.1927, Val Loss = 29.4314
# Early stopping triggered.
#               precision    recall  f1-score   support
#
#            0       0.37      0.36      0.37        36
#            1       0.22      0.33      0.27        18
#            2       0.17      0.07      0.10        14
#            3       0.35      0.35      0.35        23
#
#     accuracy                           0.31        91
#    macro avg       0.28      0.28      0.27        91
# weighted avg       0.30      0.31      0.30        91

# %% [markdown]
# ### Random Forest Classfier of RRA Quartile for six RRA sub-types

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report
from collections import Counter
import random

# Set random seed
random.seed(42)
np.random.seed(42)

# Load Node embeddings dictionary
embeddings_dict = np.load("/Users/tunaseckin/Desktop/ML4RG/ML4RG-group-17/lncrna_to_embedding.pkl", allow_pickle=True)

# Load target table
final_df = pd.read_csv("/Users/tunaseckin/Desktop/ML4RG/ML4RG-group-17/final.tsv", sep="\t")

# Define RRA target columns
rra_columns = [
    'LN18.RRAscore', 'LN229.RRAscore', 'A549.RRAscore',
    'NCIH460.RRAscore', 'KP4.RRAscore', 'MIAPACA2.RRAscore'
]

# Build X and Y using 'incoming' column for gene-to-embedding matching
X = []
Ys = {col: [] for col in rra_columns}
gene_ids = []

for gene, emb in embeddings_dict.items():
    row = final_df[final_df["incoming"] == gene]
    if not row.empty:
        row = row.iloc[0]
        if not row[rra_columns].isnull().any():
            X.append(emb)
            for col in rra_columns:
                Ys[col].append(row[col])
            gene_ids.append(gene)

X = np.array(X).astype(np.float32)
Ys = {col: np.array(labels).astype(np.float32) for col, labels in Ys.items()}

print(f"Input shape: {X.shape}")

# --- Convert RRA Scores to Quartile Labels ---
def convert_to_quartile_labels(Ys_dict):
    Ys_quartiles = {}
    for col, values in Ys_dict.items():
        col_labels = np.digitize(values, bins=[0.25, 0.5, 0.75])  # Q0: 0-0.25, Q1: 0.25-0.5, etc.
        print(f"{col} label distribution: {np.bincount(col_labels)}")
        for q in range(4):
            q_vals = values[col_labels == q]
            if len(q_vals) > 0:
                print(f"  Quartile {q}: min={q_vals.min():.4f}, max={q_vals.max():.4f}, count={len(q_vals)}")
        Ys_quartiles[col] = col_labels.astype(np.int64)
    return Ys_quartiles

Y_quartiles = convert_to_quartile_labels(Ys)

# --- Random Forest Pipeline ---
def train_rf_classifier(task_name):
    print(f"\n Task: {task_name} (Random Forest)")

    y_task = Y_quartiles[task_name]
    X_train, X_test, y_train, y_test = train_test_split(X, y_task, test_size=0.2, stratify=y_task, random_state=42)

    class_counts = Counter(y_train)
    total = sum(class_counts.values())
    class_weights = {i: total / class_counts[i] for i in range(4)}

    clf = RandomForestClassifier(n_estimators=100, class_weight=class_weights, random_state=42)
    clf.fit(X_train, y_train)

    y_pred = clf.predict(X_test)
    print(classification_report(y_test, y_pred, zero_division=0))

# --- Run the RRA Classification Tasks with RF ---
for name in rra_columns:
    train_rf_classifier(name)
# Out:
# Input shape: (451, 128)
# LN18.RRAscore label distribution: [157  84 109 101]
#   Quartile 0: min=0.0000, max=0.2494, count=157
#   Quartile 1: min=0.2505, max=0.4977, count=84
#   Quartile 2: min=0.5030, max=0.7493, count=109
#   Quartile 3: min=0.7563, max=0.9971, count=101
# LN229.RRAscore label distribution: [172  86  82 111]
#   Quartile 0: min=0.0000, max=0.2459, count=172
#   Quartile 1: min=0.2503, max=0.4988, count=86
#   Quartile 2: min=0.5040, max=0.7490, count=82
#   Quartile 3: min=0.7549, max=0.9993, count=111
# A549.RRAscore label distribution: [151 108  94  98]
#   Quartile 0: min=0.0000, max=0.2484, count=151
#   Quartile 1: min=0.2528, max=0.4974, count=108
#   Quartile 2: min=0.5073, max=0.7490, count=94
#   Quartile 3: min=0.7515, max=1.0000, count=98
# NCIH460.RRAscore label distribution: [156  77  96 122]
#   Quartile 0: min=0.0000, max=0.2465, count=156
#   Quartile 1: min=0.2507, max=0.4917, count=77
#   Quartile 2: min=0.5020, max=0.7455, count=96
#   Quartile 3: min=0.7548, max=0.9996, count=122
# KP4.RRAscore label distribution: [159  70  99 123]
#   Quartile 0: min=0.0000, max=0.2499, count=159
#   Quartile 1: min=0.2511, max=0.4993, count=70
#   Quartile 2: min=0.5020, max=0.7494, count=99
#   Quartile 3: min=0.7524, max=0.9985, count=123
# MIAPACA2.RRAscore label distribution: [178  89  72 112]
#   Quartile 0: min=0.0000, max=0.2435, count=178
#   Quartile 1: min=0.2525, max=0.4797, count=89
#   Quartile 2: min=0.5007, max=0.7495, count=72
#   Quartile 3: min=0.7501, max=0.9935, count=112
#
#  Task: LN18.RRAscore (Random Forest)
#               precision    recall  f1-score   support
#
#            0       0.34      0.59      0.43        32
#            1       0.25      0.06      0.10        17
#            2       0.39      0.32      0.35        22
#            3       0.38      0.25      0.30        20
#
#     accuracy                           0.35        91
#    macro avg       0.34      0.31      0.30        91
# weighted avg       0.34      0.35      0.32        91
#
#
#  Task: LN229.RRAscore (Random Forest)
#               precision    recall  f1-score   support
#
#            0       0.38      0.71      0.50        35
#            1       0.25      0.06      0.10        17
#            2       0.00      0.00      0.00        17
#            3       0.43      0.27      0.33        22
#
#     accuracy                           0.35        91
#    macro avg       0.27      0.26      0.23        91
# weighted avg       0.30      0.35      0.29        91
#
#
#  Task: A549.RRAscore (Random Forest)
#               precision    recall  f1-score   support
#
#            0       0.39      0.80      0.53        30
#            1       0.42      0.23      0.29        22
#            2       0.36      0.21      0.27        19
#            3       0.29      0.10      0.15        20
#
#     accuracy                           0.38        91
#    macro avg       0.36      0.33      0.31        91
# weighted avg       0.37      0.38      0.33        91
#
#
#  Task: NCIH460.RRAscore (Random Forest)
#               precision    recall  f1-score   support
#
#            0       0.36      0.65      0.46        31
#            1       0.00      0.00      0.00        16
#            2       0.11      0.05      0.07        19
#            3       0.23      0.20      0.21        25
#
#     accuracy                           0.29        91
#    macro avg       0.17      0.22      0.19        91
# weighted avg       0.21      0.29      0.23        91
#
#
#  Task: KP4.RRAscore (Random Forest)
#               precision    recall  f1-score   support
#
#            0       0.42      0.69      0.52        32
#            1       0.00      0.00      0.00        14
#            2       0.20      0.15      0.17        20
#            3       0.47      0.32      0.38        25
#
#     accuracy                           0.36        91
#    macro avg       0.27      0.29      0.27        91
# weighted avg       0.32      0.36      0.32        91
#
#
#  Task: MIAPACA2.RRAscore (Random Forest)
#               precision    recall  f1-score   support
#
#            0       0.37      0.72      0.49        36
#            1       0.50      0.22      0.31        18
#            2       0.00      0.00      0.00        14
#            3       0.00      0.00      0.00        23
#
#     accuracy                           0.33        91
#    macro avg       0.22      0.24      0.20        91
# weighted avg       0.24      0.33      0.25        91

# %% [markdown]
# ## Previous Regression Task

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

class MLP_Regressor(nn.Module):
    def __init__(self, input_dim=768, output_dim=6):
        super(MLP_Regressor, self).__init__()
        self.model = nn.Sequential(
            nn.Linear(input_dim, 512),
            nn.GELU(),  # or nn.LeakyReLU(negative_slope=0.01)

            nn.Dropout(0.2),

            nn.Linear(512, 256),
            nn.GELU(),

            nn.Dropout(0.2),

            nn.Linear(256, 128),
            nn.GELU(),

            nn.Linear(128, output_dim)
        )

    def forward(self, x):
        return self.model(x)

# %%
model = MLP_Regressor()
criterion = nn.MSELoss()
optimizer = torch.optim.AdamW(model.parameters(), lr=1e-4, weight_decay=1e-4)

# %%
import torch
from torch.utils.data import TensorDataset, DataLoader
from sklearn.model_selection import train_test_split

# Split data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# Convert to PyTorch tensors
X_train_tensor = torch.tensor(X_train, dtype=torch.float32)
y_train_tensor = torch.tensor(y_train, dtype=torch.float32)

X_test_tensor = torch.tensor(X_test, dtype=torch.float32)
y_test_tensor = torch.tensor(y_test, dtype=torch.float32)

# Create TensorDatasets and DataLoaders
train_dataset = TensorDataset(X_train_tensor, y_train_tensor)
test_dataset = TensorDataset(X_test_tensor, y_test_tensor)

train_loader = DataLoader(train_dataset, batch_size=16, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=16)

# Training loop
for epoch in range(500):
    model.train()
    total_loss = 0
    for xb, yb in train_loader:
        optimizer.zero_grad()
        pred = model(xb)
        loss = criterion(pred, yb)
        loss.backward()
        optimizer.step()
        total_loss += loss.item()

    print(f"Epoch {epoch+1}: Train Loss = {total_loss:.4f}")

# Optional: evaluate on test set
model.eval()
test_loss = 0
with torch.no_grad():
    for xb, yb in test_loader:
        pred = model(xb)
        loss = criterion(pred, yb)
        test_loss += loss.item()
print(f"          Test Loss = {test_loss:.4f}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[41], line 6
#       3 from sklearn.model_selection import train_test_split
#       5 # Split data into train and test sets
# ----> 6 X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=42)
#       8 # Convert to PyTorch tensors
#       9 X_train_tensor = torch.tensor(X_train, dtype=torch.float32)
#
# File ~/anaconda3/envs/ml4rg_disease/lib/python3.12/site-packages/sklearn/utils/_param_validation.py:218, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     212 try:
#     213     with config_context(
#     214         skip_parameter_validation=(
#     215             prefer_skip_nested_validation or global_skip_validation
#     216         )
#     217     ):
# --> 218         return func(*args, **kwargs)
#     219 except InvalidParameterError as e:
#     220     # When the function is just a wrapper around an estimator, we allow
#     221     # the function to delegate validation to the estimator, but we replace
#     222     # the name of the estimator by the name of the function in the error
#     223     # message to avoid confusion.
#     224     msg = re.sub(
#     225         r"parameter of \w+ must be",
#     226         f"parameter of {func.__qualname__} must be",
#     227         str(e),
#     228     )
#
# File ~/anaconda3/envs/ml4rg_disease/lib/python3.12/site-packages/sklearn/model_selection/_split.py:2916, in train_test_split(test_size, train_size, random_state, shuffle, stratify, *arrays)
#    2913 if n_arrays == 0:
#    2914     raise ValueError("At least one array required as input")
# -> 2916 arrays = indexable(*arrays)
#    2918 n_samples = _num_samples(arrays[0])
#    2919 n_train, n_test = _validate_shuffle_split(
#    2920     n_samples, test_size, train_size, default_test_size=0.25
#    2921 )
#
# File ~/anaconda3/envs/ml4rg_disease/lib/python3.12/site-packages/sklearn/utils/validation.py:530, in indexable(*iterables)
#     500 """Make arrays indexable for cross-validation.
#     501
#     502 Checks consistent length, passes through None, and ensures that everything
#    (...)    526 [[1, 2, 3], array([2, 3, 4]), None, <...Sparse...dtype 'int64'...shape (3, 1)>]
#     527 """
#     529 result = [_make_indexable(X) for X in iterables]
# --> 530 check_consistent_length(*result)
#     531 return result
#
# File ~/anaconda3/envs/ml4rg_disease/lib/python3.12/site-packages/sklearn/utils/validation.py:473, in check_consistent_length(*arrays)
#     471 lengths = [_num_samples(X) for X in arrays if X is not None]
#     472 if len(set(lengths)) > 1:
# --> 473     raise ValueError(
#     474         "Found input variables with inconsistent numbers of samples: %r"
#     475         % [int(l) for l in lengths]
#     476     )
#
# ValueError: Found input variables with inconsistent numbers of samples: [451, 452]

# %%
import torch.nn as nn

class FDRPredictor(nn.Module):
    def __init__(self):
        super(FDRPredictor, self).__init__()
        self.model = nn.Sequential(
            nn.Linear(128, 64),     # from 128 to hidden layer
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(64, 32),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(32, 6)        # 6 FDR outputs
        )

    def forward(self, x):
        return self.model(x)

# %%
model = FDRPredictor()
criterion = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)

# %%
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset, random_split
from sklearn.metrics import f1_score, precision_score, recall_score, accuracy_score
import numpy as np

# Split proportions
train_ratio, val_ratio, test_ratio = 0.7, 0.15, 0.15
patience = 20

# Assuming X and Y are numpy arrays
X_tensor = torch.tensor(X, dtype=torch.float32)
Y_tensor = torch.tensor(Y, dtype=torch.float32)

# Create dataset and split
dataset = TensorDataset(X_tensor, Y_tensor)
total_size = len(dataset)
train_size = int(train_ratio * total_size)
val_size = int(val_ratio * total_size)
test_size = total_size - train_size - val_size

train_set, val_set, test_set = random_split(dataset, [train_size, val_size, test_size])

train_loader = DataLoader(train_set, batch_size=16, shuffle=True)
val_loader = DataLoader(val_set, batch_size=16)
test_loader = DataLoader(test_set, batch_size=16)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[39], line 16
#      13 Y_tensor = torch.tensor(Y, dtype=torch.float32)
#      15 # Create dataset and split
# ---> 16 dataset = TensorDataset(X_tensor, Y_tensor)
#      17 total_size = len(dataset)
#      18 train_size = int(train_ratio * total_size)
#
# File ~/anaconda3/envs/ml4rg_disease/lib/python3.12/site-packages/torch/utils/data/dataset.py:201, in TensorDataset.__init__(self, *tensors)
#     200 def __init__(self, *tensors: Tensor) -> None:
# --> 201     assert all(
#     202         tensors[0].size(0) == tensor.size(0) for tensor in tensors
#     203     ), "Size mismatch between tensors"
#     204     self.tensors = tensors
#
# AssertionError: Size mismatch between tensors

# %%
best_val_loss = float('inf')
patience_counter = 0
best_model_path = 'best_fdr_model.pt'

for epoch in range(500):
    # Training
    model.train()
    train_loss = 0
    for xb, yb in train_loader:
        optimizer.zero_grad()
        pred = model(xb)
        loss = criterion(pred, yb)
        loss.backward()
        optimizer.step()
        train_loss += loss.item()

    # Validation
    model.eval()
    val_loss = 0
    with torch.no_grad():
        for xb, yb in val_loader:
            pred = model(xb)
            loss = criterion(pred, yb)
            val_loss += loss.item()

    print(f"Epoch {epoch+1} | Train Loss: {train_loss:.4f} | Val Loss: {val_loss:.4f}")

    # Early stopping
    if val_loss < best_val_loss:
        best_val_loss = val_loss
        patience_counter = 0
        torch.save(model.state_dict(), best_model_path)
    else:
        patience_counter += 1
        if patience_counter >= patience:
            print("Early stopping triggered.")
            break
# Out:
# Epoch 1 | Train Loss: 9.7027 | Val Loss: 0.7218
# Epoch 2 | Train Loss: 3.7446 | Val Loss: 0.1142
# Epoch 3 | Train Loss: 2.5741 | Val Loss: 0.1232
# Epoch 4 | Train Loss: 1.9821 | Val Loss: 0.1123
# Epoch 5 | Train Loss: 1.9033 | Val Loss: 0.1336
# Epoch 6 | Train Loss: 1.6060 | Val Loss: 0.0472
# Epoch 7 | Train Loss: 1.3139 | Val Loss: 0.0562
# Epoch 8 | Train Loss: 1.2077 | Val Loss: 0.0471
# Epoch 9 | Train Loss: 1.2957 | Val Loss: 0.0558
# Epoch 10 | Train Loss: 0.9910 | Val Loss: 0.0523
# Epoch 11 | Train Loss: 1.0572 | Val Loss: 0.0603
# Epoch 12 | Train Loss: 0.9806 | Val Loss: 0.0587
# Epoch 13 | Train Loss: 0.9163 | Val Loss: 0.0575
# Epoch 14 | Train Loss: 0.7225 | Val Loss: 0.0743
# Epoch 15 | Train Loss: 0.9236 | Val Loss: 0.0569
# Epoch 16 | Train Loss: 0.8438 | Val Loss: 0.0425
# Epoch 17 | Train Loss: 0.7169 | Val Loss: 0.0552
# Epoch 18 | Train Loss: 0.7995 | Val Loss: 0.0938
# Epoch 19 | Train Loss: 0.6790 | Val Loss: 0.0412
# Epoch 20 | Train Loss: 0.6676 | Val Loss: 0.0520
# Epoch 21 | Train Loss: 0.6126 | Val Loss: 0.0470
# Epoch 22 | Train Loss: 0.6423 | Val Loss: 0.0491
# Epoch 23 | Train Loss: 0.6490 | Val Loss: 0.0351
# Epoch 24 | Train Loss: 0.5788 | Val Loss: 0.0407
# Epoch 25 | Train Loss: 0.6137 | Val Loss: 0.0346
# Epoch 26 | Train Loss: 0.4926 | Val Loss: 0.0627
# Epoch 27 | Train Loss: 0.5476 | Val Loss: 0.0406
# Epoch 28 | Train Loss: 0.4776 | Val Loss: 0.0333
# Epoch 29 | Train Loss: 0.4992 | Val Loss: 0.0455
# Epoch 30 | Train Loss: 0.4657 | Val Loss: 0.0324
# Epoch 31 | Train Loss: 0.4704 | Val Loss: 0.0464
# Epoch 32 | Train Loss: 0.3847 | Val Loss: 0.0315
# Epoch 33 | Train Loss: 0.4410 | Val Loss: 0.0293
# Epoch 34 | Train Loss: 0.4102 | Val Loss: 0.0303
# Epoch 35 | Train Loss: 0.3943 | Val Loss: 0.0319
# Epoch 36 | Train Loss: 0.4503 | Val Loss: 0.0425
# Epoch 37 | Train Loss: 0.4271 | Val Loss: 0.0306
# Epoch 38 | Train Loss: 0.3954 | Val Loss: 0.0320
# Epoch 39 | Train Loss: 0.4132 | Val Loss: 0.0375
# Epoch 40 | Train Loss: 0.3442 | Val Loss: 0.0319
# Epoch 41 | Train Loss: 0.3637 | Val Loss: 0.0323
# Epoch 42 | Train Loss: 0.3685 | Val Loss: 0.0296
# Epoch 43 | Train Loss: 0.3680 | Val Loss: 0.0350
# Epoch 44 | Train Loss: 0.3727 | Val Loss: 0.0271
# Epoch 45 | Train Loss: 0.3162 | Val Loss: 0.0292
# Epoch 46 | Train Loss: 0.3430 | Val Loss: 0.0269
# Epoch 47 | Train Loss: 0.3224 | Val Loss: 0.0293
# Epoch 48 | Train Loss: 0.2925 | Val Loss: 0.0284
# Epoch 49 | Train Loss: 0.3466 | Val Loss: 0.0274
# Epoch 50 | Train Loss: 0.2882 | Val Loss: 0.0315
# Epoch 51 | Train Loss: 0.2814 | Val Loss: 0.0256
# Epoch 52 | Train Loss: 0.2659 | Val Loss: 0.0255
# Epoch 53 | Train Loss: 0.2814 | Val Loss: 0.0264
# Epoch 54 | Train Loss: 0.2701 | Val Loss: 0.0299
# Epoch 55 | Train Loss: 0.2615 | Val Loss: 0.0265
# Epoch 56 | Train Loss: 0.2978 | Val Loss: 0.0292
# Epoch 57 | Train Loss: 0.2626 | Val Loss: 0.0281
# Epoch 58 | Train Loss: 0.2822 | Val Loss: 0.0242
# Epoch 59 | Train Loss: 0.2403 | Val Loss: 0.0272
# Epoch 60 | Train Loss: 0.2809 | Val Loss: 0.0273
# Epoch 61 | Train Loss: 0.2419 | Val Loss: 0.0249
# Epoch 62 | Train Loss: 0.2787 | Val Loss: 0.0238
# Epoch 63 | Train Loss: 0.2716 | Val Loss: 0.0248
# Epoch 64 | Train Loss: 0.2294 | Val Loss: 0.0242
# Epoch 65 | Train Loss: 0.2257 | Val Loss: 0.0241
# Epoch 66 | Train Loss: 0.2281 | Val Loss: 0.0240
# Epoch 67 | Train Loss: 0.2107 | Val Loss: 0.0244
# Epoch 68 | Train Loss: 0.2246 | Val Loss: 0.0234
# Epoch 69 | Train Loss: 0.2205 | Val Loss: 0.0242
# Epoch 70 | Train Loss: 0.2140 | Val Loss: 0.0240
# Epoch 71 | Train Loss: 0.2134 | Val Loss: 0.0235
# Epoch 72 | Train Loss: 0.2498 | Val Loss: 0.0254
# Epoch 73 | Train Loss: 0.2156 | Val Loss: 0.0233
# Epoch 74 | Train Loss: 0.2028 | Val Loss: 0.0240
# Epoch 75 | Train Loss: 0.2113 | Val Loss: 0.0238
# Epoch 76 | Train Loss: 0.2026 | Val Loss: 0.0236
# Epoch 77 | Train Loss: 0.2055 | Val Loss: 0.0248
# Epoch 78 | Train Loss: 0.1885 | Val Loss: 0.0241
# Epoch 79 | Train Loss: 0.1850 | Val Loss: 0.0235
# Epoch 80 | Train Loss: 0.1671 | Val Loss: 0.0237
# Epoch 81 | Train Loss: 0.1818 | Val Loss: 0.0231
# Epoch 82 | Train Loss: 0.1893 | Val Loss: 0.0236
# Epoch 83 | Train Loss: 0.1775 | Val Loss: 0.0233
# Epoch 84 | Train Loss: 0.1886 | Val Loss: 0.0231
# Epoch 85 | Train Loss: 0.2065 | Val Loss: 0.0231
# Epoch 86 | Train Loss: 0.1942 | Val Loss: 0.0236
# Epoch 87 | Train Loss: 0.1865 | Val Loss: 0.0231
# Epoch 88 | Train Loss: 0.1763 | Val Loss: 0.0234
# Epoch 89 | Train Loss: 0.1685 | Val Loss: 0.0231
# Epoch 90 | Train Loss: 0.1590 | Val Loss: 0.0231
# Epoch 91 | Train Loss: 0.1758 | Val Loss: 0.0234
# Epoch 92 | Train Loss: 0.1666 | Val Loss: 0.0230
# Epoch 93 | Train Loss: 0.1661 | Val Loss: 0.0232
# Epoch 94 | Train Loss: 0.1585 | Val Loss: 0.0230
# Epoch 95 | Train Loss: 0.1544 | Val Loss: 0.0235
# Epoch 96 | Train Loss: 0.1601 | Val Loss: 0.0231
# Epoch 97 | Train Loss: 0.1779 | Val Loss: 0.0233
# Epoch 98 | Train Loss: 0.1654 | Val Loss: 0.0237
# Epoch 99 | Train Loss: 0.1565 | Val Loss: 0.0233
# Epoch 100 | Train Loss: 0.1665 | Val Loss: 0.0243
# Epoch 101 | Train Loss: 0.1486 | Val Loss: 0.0236
# Epoch 102 | Train Loss: 0.1647 | Val Loss: 0.0233
# Epoch 103 | Train Loss: 0.1354 | Val Loss: 0.0244
# Epoch 104 | Train Loss: 0.1645 | Val Loss: 0.0237
# Epoch 105 | Train Loss: 0.1572 | Val Loss: 0.0259
# Epoch 106 | Train Loss: 0.1391 | Val Loss: 0.0239
# Epoch 107 | Train Loss: 0.1473 | Val Loss: 0.0237
# Epoch 108 | Train Loss: 0.1382 | Val Loss: 0.0238
# Epoch 109 | Train Loss: 0.1387 | Val Loss: 0.0237
# Epoch 110 | Train Loss: 0.1564 | Val Loss: 0.0234
# Epoch 111 | Train Loss: 0.1453 | Val Loss: 0.0236
# Epoch 112 | Train Loss: 0.1341 | Val Loss: 0.0235
# Early stopping triggered.

# %%
# Optional: evaluate on test set
model.load_state_dict(torch.load(best_model_path))
model.eval()
test_loss = 0
with torch.no_grad():
    for xb, yb in test_loader:
        pred = model(xb)
        loss = criterion(pred, yb)
        test_loss += loss.item()
print(f"          Test Loss = {test_loss:.4f}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[40], line 2
#       1 # Optional: evaluate on test set
# ----> 2 model.load_state_dict(torch.load(best_model_path))
#       3 model.eval()
#       4 test_loss = 0
#
# NameError: name 'best_model_path' is not defined

# %%
# Load best model
model.load_state_dict(torch.load(best_model_path))
model.eval()

all_preds = []
all_labels = []

with torch.no_grad():
    for xb, yb in test_loader:
        pred = model(xb)
        all_preds.append(pred)
        all_labels.append(yb)

all_preds = torch.cat(all_preds).cpu().numpy()
all_labels = torch.cat(all_labels).cpu().numpy()

# Threshold for classification (FDR < 0.05 -> "significant" == 1)
y_true = (all_labels < 0.5).astype(int)
y_pred = (all_preds < 0.5).astype(int)

# Flatten all predictions and labels for global scores
y_true_flat = y_true.flatten()
y_pred_flat = y_pred.flatten()

print("\n Test Set Evaluation Metrics (FDR < 0.05 considered positive):")
print(f"Accuracy:  {accuracy_score(y_true_flat, y_pred_flat):.4f}")
print(f"F1 Score:  {f1_score(y_true_flat, y_pred_flat):.4f}")
print(f"Recall:    {recall_score(y_true_flat, y_pred_flat):.4f}")
print(f"Precision: {precision_score(y_true_flat, y_pred_flat):.4f}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[36], line 2
#       1 # Load best model
# ----> 2 model.load_state_dict(torch.load(best_model_path))
#       3 model.eval()
#       5 all_preds = []
#
# NameError: name 'best_model_path' is not defined

# %% [markdown]
# ## Binary Classification

# %%
import numpy as np

# Assuming Y is already defined and is a numpy array of shape (num_samples, 6)
# Each column represents one FDR value: [LN18, LN229, A549, NCIH460, KP4, MIAPACA2]
fdr_column_names = ["LN18", "LN229", "A549", "NCIH460", "KP4", "MIAPACA2"]

# Compute mean of each column
fdr_means = np.mean(Y, axis=0)

# Create a dictionary with names and means
fdr_mean_dict = dict(zip(fdr_column_names, fdr_means))
fdr_mean_dict
# Out:
# {'LN18': 0.9857440203160229,
#  'LN229': 0.9881136862302473,
#  'A549': 0.9921015417607255,
#  'NCIH460': 0.9918748216704208,
#  'KP4': 0.9899481106094885,
#  'MIAPACA2': 0.9952328668171507}

# %%
import numpy as np
from collections import Counter

FDR_threshold = 0.90
column_names = ['LN18', 'LN229', 'A549', 'NCIH460', 'KP4', 'MIAPACA2']

# Binarize Y using threshold
Y_binary = (Y > FDR_threshold).astype(int)

# Print class distribution per column
for i, name in enumerate(column_names):
    counts = Counter(Y_binary[:, i])
    print(f"{name} class distribution (FDR_threshold={FDR_threshold}): {dict(counts)}")
# Out:
# LN18 class distribution (FDR_threshold=0.9): {1: 431, 0: 12}
# LN229 class distribution (FDR_threshold=0.9): {1: 433, 0: 10}
# A549 class distribution (FDR_threshold=0.9): {1: 437, 0: 6}
# NCIH460 class distribution (FDR_threshold=0.9): {1: 437, 0: 6}
# KP4 class distribution (FDR_threshold=0.9): {1: 435, 0: 8}
# MIAPACA2 class distribution (FDR_threshold=0.9): {1: 439, 0: 4}

# %%
import torch

# Class distributions you provided
fdr_class_counts = {
    'LN18': {1: 431, 0: 12},
    'LN229': {1: 433, 0: 10},
    'A549': {1: 437, 0: 6},
    'NCIH460': {1: 437, 0: 6},
    'KP4': {1: 435, 0: 8},
    'MIAPACA2': {1: 439, 0: 4}
}

# Calculate pos_weight = (num_neg / num_pos) for each label
pos_weights = []
for cell_line, counts in fdr_class_counts.items():
    num_pos = counts[1]
    num_neg = counts[0]
    weight = num_neg / num_pos
    pos_weights.append(weight)

# Convert to PyTorch tensor
pos_weight_tensor = torch.tensor(pos_weights, dtype=torch.float32)
pos_weight_tensor
# Out:
# tensor([0.0278, 0.0231, 0.0137, 0.0137, 0.0184, 0.0091])

# %%
import torch.nn as nn

#pos_weight_tensor = torch.tensor([0.0278, 0.0231, 0.0137, 0.0137, 0.0184, 0.0091])
criterion = nn.BCEWithLogitsLoss(pos_weight=pos_weight_tensor)
